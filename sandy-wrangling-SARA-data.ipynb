# %% [markdown]
# # SARA	Data
# #### Water Quality Data
# - Water quality data taken at set sampling locations along the San Antonio river and its tributaries. Parameters include observational data, organics, bacteria, etc. 22.79Mb
# ./data/sara-water-quality-bexar.csv
# link for more info:
# https://sara-tx.maps.arcgis.com/apps/MapSeries/index.html?appid=3a4ca132222e41589e6f41eebfe6d36d
#
#
# #### San Antonio River Authority - Index of Elevation Contours with Download Links - Four Counties	SARA
# - High resolution terrain contours of Bexar, Wilson, Karnes, and Goliad counties.
# Only available via website:
# https://sara-tx.maps.arcgis.com/home/item.html?id=c8d366e2680242fbae437006a3e8a3d2
#
# #### Rainfall
# - 5 minute interval rainfall amounts for locations around Bexar county. 2.56Mb
# ./data/sara-rainfall-detail.csv
#
# - Daily total rainfall amounts for locations around Bexar county. 800.73Kb
# ./data/sara-rainfall-summary.csv
#
# #### Flood stage levels
# - Surface water levels at four locations along SA river within Mission Reach area. 109.96Kb
# ./data/sara-riverstage-daily-average.csv
#
#
# #### Impervious coverage (GIS data)
# - GIS shape files detailing the impervious cover within Brooks City Base area 21.27Mb
# ./data/brooks_ic/brooks_ic.cpg
# ./data/brooks_ic/brooks_ic.dbf
# ./data/brooks_ic/brooks_ic.prj
# ./data/brooks_ic/brooks_ic.sbn
# ./data/brooks_ic/brooks_ic.sbx
# ./data/brooks_ic/brooks_ic.shp
# ./data/brooks_ic/brooks_ic.shp.xml
# ./data/brooks_ic/brooks_ic.shx
#
# - GIS shape files detailing the impervious cover within TAMUS areas. 1.7Mb
# ./data/tamusa_ic/tamusa_ic.cpg
# ./data/tamusa_ic/tamusa_ic.dbf
# ./data/tamusa_ic/tamusa_ic.prj
# ./data/tamusa_ic/tamusa_ic.sbn
# ./data/tamusa_ic/tamusa_ic.sbx
# ./data/tamusa_ic/tamusa_ic.shp
# ./data/tamusa_ic/tamusa_ic.shp.xml
# ./data/tamusa_ic/tamusa_ic.shx

# %%
import os
import acquire
import pandas as pd

# data visualization 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import statsmodels.api as sm

from datetime import timedelta, datetime
from pylab import rcParams

import pyspark
import pandas as pd
from pyspark.sql import SparkSession
import pyspark.sql.types as T

# %% [markdown]
# # Acquire

# %%
saws = acquire.read_data('saws-ssos.csv')
saws.head()
# Out:
#    SSO_ID   INSPKEY  SERVNO REPORTDATE  SPILL_ADDRESS     SPILL_ST_NAME  \
# 0    6582  567722.0     NaN    3/10/19           3200  THOUSAND OAKS DR
# 1    6583  567723.0     NaN    3/10/19           6804       S FLORES ST
# 2    6581  567714.0     NaN     3/9/19            215   AUDREY ALENE DR
# 3    6584  567713.0     NaN     3/9/19           3602    SE MILITARY DR
# 4    6580  567432.0     NaN     3/6/19            100          PANSY LN
#
#    TOTAL_GAL  GALSRET     GAL           SPILL_START  ...  Root_Cause  \
# 0       2100   2100.0  2100.0  3/10/2019 1:16:00 PM  ...         NaN
# 1         80      0.0    80.0  3/10/2019 2:25:00 PM  ...         NaN
# 2         79      0.0    10.0   3/9/2019 6:00:00 PM  ...         NaN
# 3         83      0.0    83.0   3/9/2019 3:37:00 PM  ...         NaN
# 4         75      0.0    75.0   3/6/2019 9:40:00 AM  ...         NaN
#
#    STEPS_TO_PREVENT     SPILL_START_2      SPILL_STOP_2 HRS_2 GAL_2  \
# 0               NaN               NaN               NaN  0.00   0.0
# 1               NaN               NaN               NaN  0.00   0.0
# 2               NaN  03/10/2019 09:36  03/10/2019 10:45  1.15  69.0
# 3               NaN               NaN               NaN  0.00   0.0
# 4               NaN               NaN               NaN  0.00   0.0
#
#   SPILL_START_3 SPILL_STOP_3 HRS_3 GAL_3
# 0           NaN          NaN   0.0   0.0
# 1           NaN          NaN   0.0   0.0
# 2           NaN          NaN   0.0   0.0
# 3           NaN          NaN   0.0   0.0
# 4           NaN          NaN   0.0   0.0
#
# [5 rows x 57 columns]

# %%
spark = SparkSession.builder.master("local").appName("read").\
    enableHiveSupport().\
    getOrCreate()

# %% [markdown]
# # ./data/sara-water-quality-bexar.csv

# %%
sara_water_quality = spark.read.format("csv").\
    option("sep", ",").\
    option("header", True).\
    option("inferSchema", True).\
    load("./data/sara-water-quality-bexar.csv")

sara_water_quality.printSchema()
# Out:
# root
#  |-- Station ID: integer (nullable = true)
#  |-- Station Description: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- End Date: timestamp (nullable = true)
#  |-- Tag ID: string (nullable = true)
#  |-- End Time: string (nullable = true)
#  |-- End Depth: double (nullable = true)
#  |-- Sample Type: string (nullable = true)
#  |-- Program Code: string (nullable = true)
#  |-- TEMPERATURE, WATER (DEGREES CENTIGRADE) (00010): string (nullable = true)
#  |-- RESERVOIR STAGE (FEET ABOVE MEAN SEA LEVEL) (00052): string (nullable = true)
#  |-- RESERVOIR PERCENT FULL (00053): string (nullable = true)
#  |-- FLOW  STREAM, INSTANTANEOUS (CUBIC FEET PER SEC) (00061): string (nullable = true)
#  |-- DEPTH, MAXIMUM, OF SAMPLE (FEET) (00068): string (nullable = true)
#  |-- TRANSPARENCY, SECCHI DISC (METERS) (00078): string (nullable = true)
#  |-- SPECIFIC CONDUCTANCE,FIELD (US/CM @ 25C) (00094): string (nullable = true)
#  |-- TEMPERATURE, WATER (DEGREES CENTIGRADE), 24HR AVG (00209): string (nullable = true)
#  |-- WATER TEMPERATURE, DEGREES CENTIGRADE, 24HR MAX (00210): string (nullable = true)
#  |-- TEMPERATURE, WATER (DEGREES CENTIGRADE) 24HR MIN (00211): string (nullable = true)
#  |-- SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR AVG (00212): string (nullable = true)
#  |-- SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR MAX (00213): string (nullable = true)
#  |-- SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR MIN (00214): string (nullable = true)
#  |-- PH, S.U., 24HR MAXIMUM VALUE (00215): string (nullable = true)
#  |-- PH, S.U., 24HR, MINIMUM VALUE (00216): string (nullable = true)
#  |-- WATER TEMPERATURE, # OF MEASUREMENTS IN 24-HRS (00221): string (nullable = true)
#  |-- SPECIFIC CONDUCTANCE, # OF MEASUREMENTS IN 24-HR (00222): string (nullable = true)
#  |-- pH, # OF MEASUREMENTS IN 24-HRS (00223): string (nullable = true)
#  |-- OXYGEN, DISSOLVED (MG/L) (00300): string (nullable = true)
#  |-- BIOCHEMICAL OXYGEN DEMAND (MG/L, 5 DAY - 20DEG C (00310): string (nullable = true)
#  |-- CARBBIOCHEM OXY DM NIT INHB, TOT (MG/L, 5 DAY-20 (00314): string (nullable = true)
#  |-- CHEMICAL OXYGEN DEMAND, .025N K2CR2O7 (MG/L) (00335): string (nullable = true)
#  |-- PH (STANDARD UNITS) (00400): string (nullable = true)
#  |-- PH (STANDARD UNITS) LAB (00403): string (nullable = true)
#  |-- ALKALINITY, TOTAL (MG/L AS CACO3) (00410): string (nullable = true)
#  |-- RESIDUE, TOTAL NONFILTRABLE (MG/L) (00530): string (nullable = true)
#  |-- RESIDUE, VOLATILE NONFILTRABLE (MG/L) (00535): string (nullable = true)
#  |-- NITROGEN, AMMONIA, TOTAL (MG/L AS N) (00610): string (nullable = true)
#  |-- NITRITE NITROGEN, TOTAL (MG/L AS N) (00615): string (nullable = true)
#  |-- NITRATE NITROGEN, TOTAL (MG/L AS N) (00620): string (nullable = true)
#  |-- NITROGEN, KJELDAHL, TOTAL (MG/L AS N) (00625): string (nullable = true)
#  |-- PHOSPHORUS, TOTAL, WET METHOD (MG/L AS P) (00665): string (nullable = true)
#  |-- ORTHOPHOSPHATE PHOSPHORUS,DISS,MG/L,FLDFILT<15MIN (00671): string (nullable = true)
#  |-- CARBON, TOTAL ORGANIC, NPOC (TOC), MG/L (00680): string (nullable = true)
#  |-- CARBON, DISSOLVED ORGANIC, DNPC (DOC), MG/L (00681): string (nullable = true)
#  |-- HARDNESS, TOTAL (MG/L AS CACO3) (00900): string (nullable = true)
#  |-- CALCIUM, DISSOLVED (MG/L AS CA) (00915): string (nullable = true)
#  |-- CALCIUM, TOTAL (MG/L AS CA) (00916): string (nullable = true)
#  |-- MAGNESIUM, TOTAL (MG/L AS MG) (00927): string (nullable = true)
#  |-- SODIUM, TOTAL (MG/L AS NA) (00929): string (nullable = true)
#  |-- POTASSIUM, TOTAL (MG/L AS  K) (00937): string (nullable = true)
#  |-- CHLORIDE (MG/L AS CL) (00940): string (nullable = true)
#  |-- SULFATE (MG/L AS SO4) (00945): string (nullable = true)
#  |-- FLUORIDE, TOTAL (MG/L AS F) (00951): string (nullable = true)
#  |-- ARSENIC, DISSOLVED  (UG/L AS AS) (01000): string (nullable = true)
#  |-- ARSENIC, TOTAL (UG/L AS AS) (01002): string (nullable = true)
#  |-- ARSENIC, BOTTOM DEPOSITS (MG/KG AS AS DRY WT) (01003): string (nullable = true)
#  |-- BARIUM, TOTAL (UG/L AS BA) (01007): string (nullable = true)
#  |-- BARIUM, BOTTOM DEPOSITS (MG/KG AS BA DRY WT) (01008): string (nullable = true)
#  |-- CADMIUM, DISSOLVED (UG/L AS CD) (01025): string (nullable = true)
#  |-- CADMIUM, TOTAL (UG/L AS CD) (01027): string (nullable = true)
#  |-- CADMIUM,TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT) (01028): string (nullable = true)
#  |-- CHROMIUM,TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT (01029): string (nullable = true)
#  |-- CHROMIUM, DISSOLVED (UG/L AS CR) (01030): string (nullable = true)
#  |-- CHROMIUM, TOTAL (UG/L AS CR) (01034): string (nullable = true)
#  |-- COPPER, DISSOLVED (UG/L AS CU) (01040): string (nullable = true)
#  |-- COPPER, TOTAL (UG/L AS CU) (01042): string (nullable = true)
#  |-- COPPER, BOTTOM DEPOSITS (MG/KG AS CU DRY WT) (01043): string (nullable = true)
#  |-- IRON, DISSOLVED (UG/L) (01046): string (nullable = true)
#  |-- LEAD, DISSOLVED (UG/L AS PB) (01049): string (nullable = true)
#  |-- LEAD, TOTAL (UG/L AS PB) (01051): string (nullable = true)
#  |-- LEAD, BOTTOM DEPOSITS (MG/KG AS PB DRY WT) (01052): string (nullable = true)
#  |-- MANGANESE, BOTTOM DEPOSITS (MG/KG AS MN DRY WG (01053): string (nullable = true)
#  |-- MANGANESE, TOTAL (UG/L AS MN) (01055): string (nullable = true)
#  |-- MANGANESE, DISSOLVED (UG/L AS MN) (01056): string (nullable = true)
#  |-- MOLYBDENUM, DISSOLVED (UG/L AS MO) (01060): string (nullable = true)
#  |-- MOLYBDENUM, TOTAL (UG/L AS MO) (01062): string (nullable = true)
#  |-- NICKEL, DISSOLVED (UG/L AS NI) (01065): string (nullable = true)
#  |-- NICKEL, TOTAL (UG/L AS NI) (01067): string (nullable = true)
#  |-- NICKEL, TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT) (01068): string (nullable = true)
#  |-- SILVER, DISSOLVED (UG/L AS AG) (01075): string (nullable = true)
#  |-- SILVER, BOTTOM DEPOSITS (MG/KG AS AG DRY WT) (01078): string (nullable = true)
#  |-- ZINC, DISSOLVED (UG/L AS ZN) (01090): string (nullable = true)
#  |-- ZINC, TOTAL (UG/L AS ZN) (01092): string (nullable = true)
#  |-- ZINC, BOTTOM DEPOSITS (MG/KG AS ZN DRY WT) (01093): string (nullable = true)
#  |-- ANTIMONY, BOTTOM DEPOSITS (MG/KG AS SB DRY WT (01098): string (nullable = true)
#  |-- ALUMINUM, TOTAL (UG/L AS AL) (01105): string (nullable = true)
#  |-- ALUMINUM, DISSOLVED (UG/L AS AL) (01106): string (nullable = true)
#  |-- ALUMINUM, BOTTOM DEPOSITS (MG/KG AS AL DRY WT (01108): string (nullable = true)
#  |-- SELENIUM, TOTAL (UG/L AS SE) (01147): string (nullable = true)
#  |-- SELENIUM, BOTTOM DEPOSITS (MG/KG AS SE DRY WT) (01148): string (nullable = true)
#  |-- FLOW:1=No Flow,2=Low,3=Normal,4=Flood,5=High,6=Dry (01351): string (nullable = true)
#  |-- HARDNESS, DISSOLVED, TITRATED (MG/L AS CaCO3) (22413): string (nullable = true)
#  |-- COLIFORM,TOT,MEMBRANE FILTER,IMMED.M-ENDO, (31501): string (nullable = true)
#  |-- FECAL COLIFORM,MEMBR FILTER,M-FC BROTH, #/100ML (31616): string (nullable = true)
#  |-- E. COLI, MTEC, MF, #/100 ML (31648): string (nullable = true)
#  |-- ENTEROCOCCI, ME, MF, #/100ML (31649): string (nullable = true)
#  |-- FECAL STREPTOCOCCI, MBR FILT,KF AGAR,35C,48HR (31673): string (nullable = true)
#  |-- FECAL STREPTOCOCCI,MF M-ENTEROCOCCUS AGAR,35C,48 (31679): string (nullable = true)
#  |-- E. COLI, COLILERT, IDEXX METHOD, MPN/100ML (31699): string (nullable = true)
#  |-- E COLI,NA+MUG OR EA+MUG,24HRS, 35 DEGREE (#/100M (31700): string (nullable = true)
#  |-- E COLI, SEDIMENT, MPN/100G (31702): string (nullable = true)
#  |-- E.COLI, COLILERT, IDEXX, HOLDING TIME (31704): string (nullable = true)
#  |-- CHLOROPHYLL-A UG/L SPECTROPHOTOMETRIC ACID. METH (32211): string (nullable = true)
#  |-- PHEOPHYTIN-A UG/L SPECTROPHOTOMETRIC ACID. METH. (32218): string (nullable = true)
#  |-- ETHION IN WHOLE WATER SAMPLE (UG/L) (39398): string (nullable = true)
#  |-- MALATHION IN WHOLE WATER SAMPLE (UG/L) (39530): string (nullable = true)
#  |-- PARATHION IN WHOLE WATER SAMPLE (UG/L) (39540): string (nullable = true)
#  |-- DEMETON IN WHOLE WATER SAMPLE (UG/L) (39560): string (nullable = true)
#  |-- DIAZINON IN WHOLE WATER SAMPLE (UG/L) (39570): string (nullable = true)
#  |-- GUTHION IN WHOLE WATER SAMPLE (UG/L) (39580): string (nullable = true)
#  |-- METHYL PARATHION IN WHOLE WATER SAMPLE (UG/L) (39600): string (nullable = true)
#  |-- RAINFALL (INCHES, GAUGE DATA) (46529): string (nullable = true)
#  |-- SOLIDS,TOTAL, DISS, ELECTRICAL-CONDUCTIVITY,MG/L (47004): string (nullable = true)
#  |-- RESIDUE, TOT DISS,UNSPEC CALC BASED ON COND (MG/ (70294): string (nullable = true)
#  |-- RESIDUE,TOTAL FILTRABLE (DRIED AT 180C) (MG/L) (70300): string (nullable = true)
#  |-- ORTHOPHOSPHATE PHOSPHORUS,DISS,MG/L,FILTER >15MIN (70507): string (nullable = true)
#  |-- MERCURY, TOTAL  (UG/L AS HG) (71900): string (nullable = true)
#  |-- MERCURY,TOT. IN BOT. DEPOS. (MG/KG) AS HG DRY WG (71921): string (nullable = true)
#  |-- STREAMBED SLOPE (M/KM) (72051): string (nullable = true)
#  |-- STREAMBED SLOPE (FT/FT) (72052): string (nullable = true)
#  |-- DAYS SINCE PRECIPITATION EVENT (DAYS) (72053): string (nullable = true)
#  |-- IRON, TOTAL, AS FE - (MG/L) (74010): string (nullable = true)
#  |-- STREAM FLOW ESTIMATE (CFS) (74069): string (nullable = true)
#  |-- DURSBAN(CHLOROPYRIFOS)WHOLE WATER SAMPLE (UG/L) (81403): string (nullable = true)
#  |-- TURBIDITY,LAB NEPHELOMETRIC TURBIDITY UNITS, NTU (82079): string (nullable = true)
#  |-- HARDNESS, TOTAL, CALCULATED (MG/L AS CaCO3) (82394): string (nullable = true)
#  |-- RAINFALL IN 1 DAY INCLUSIVE PRIOR TO SAMPLE (IN) (82553): string (nullable = true)
#  |-- DEPTH OF BOTTOM OF WATER BODY AT SAMPLE SITE (82903): string (nullable = true)
#  |-- AVERAGE PERCENTAGE INSTREAM COVER (84159): string (nullable = true)
#  |-- STREAM ORDER (84161): string (nullable = true)
#  |-- STREAM TYPE; 1=PERENNIAL 2=INTERMITTENT S/PERENNIAL POOLS 3=INTERMITTENT 4=UNKNO (89821): string (nullable = true)
#  |-- RIPARIAN VEGETATION %; LEFT BANK - TREES (89822): string (nullable = true)
#  |-- RIPARIAN VEGETATION %; RIGHT BANK - TREES (89823): string (nullable = true)
#  |-- RIPARIAN VEGETATION %; LEFT BANK SHRUBS (89824): string (nullable = true)
#  |-- RIPARIAN VEGETATION %; RIGHT BANK - SHRUBS (89825): string (nullable = true)
#  |-- RIPARIAN VEGETATION %: LEFT BANK - GRASSES OR FORBS (89826): string (nullable = true)
#  |-- RIPARIAN VEGETATION %; RIGHT BANK - GRASSES OR FORBS (89827): string (nullable = true)
#  |-- RIPARIAN VEGETATION %: LEFT BANK - CULTIVATED FIELDS (89828): string (nullable = true)
#  |-- RIPARIAN VEGETATION %: RIGHT BANK - CULTIVATED FIELDS (89829): string (nullable = true)
#  |-- RIPARIAN VEGETATION %: LEFT BANK - OTHER (89830): string (nullable = true)
#  |-- NUMBER OF LATERAL TRANSECTS MADE (89832): string (nullable = true)
#  |-- FLOW MTH 1=GAGE 2=ELEC 3=MECH 4=WEIR/FLU 5=DOPPLER (89835): string (nullable = true)
#  |-- TOTAL NUMBER OF STREAM BENDS (89839): string (nullable = true)
#  |-- NUMBER OF WELL DEFINED STREAM BENDS (89840): string (nullable = true)
#  |-- NUMBER OF MODERATELY DEFINED STREAM BENDS (89841): string (nullable = true)
#  |-- NUMBER OF POORLY DEFINED STREAM BENDS (89842): string (nullable = true)
#  |-- TOTAL NUMBER OF RIFFLES (89843): string (nullable = true)
#  |-- DOMINANT SUBSTRATE TYPE(1=CLAY,2=SILT,3=SAND,4=GRAVEL,5=COBBLE,6=BOULDER,7=BEDRO (89844): string (nullable = true)
#  |-- AVERAGE PERCENT OF SUBSTRATE GRAVEL SIZE OR LARGER (89845): string (nullable = true)
#  |-- AVERAGE STREAM BANK EROSION (%) (89846): string (nullable = true)
#  |-- AVERAGE STREAM BANK SLOPE (DEGREES) (89847): string (nullable = true)
#  |-- HABITAT FLOW STATUS, 1=NO FLOW, 2=LOW,3=MOD,4=HIGH (89848): string (nullable = true)
#  |-- AVERAGE PERCENT TREES AS RIPARIAN VEGETATION (89849): string (nullable = true)
#  |-- AVERAGE PERCENT SHRUBS AS RIPARIAN VEGETATION (89850): string (nullable = true)
#  |-- AVERAGE PERCENT GRASS AS RIPARIAN VEGETATION (89851): string (nullable = true)
#  |-- AVERAGE PERCENT CULTIVATED FIELDS AS RIPARIAN VEGETATION (89852): string (nullable = true)
#  |-- AVERAGE PERCENT OTHER AS RIPARIAN VEGETATION (89853): string (nullable = true)
#  |-- AVERAGE PERCENTAGE OF TREE CANOPY COVERAGE (89854): string (nullable = true)
#  |-- DISSOLVED OXYGEN, 24-HOUR MIN. (MG/L) MIN. 4 MEA (89855): string (nullable = true)
#  |-- DISSOLVED OXYGEN, 24-HOUR MAX. (MG/L) MIN. 4 MEA (89856): string (nullable = true)
#  |-- DISSOLVED OXYGEN, 24-HOUR AVG. (MG/L) MIN. 4 MEA (89857): string (nullable = true)
#  |-- DISSOLVED OXYGEN, # OF MEASUREMENTS IN 24-HRS (89858): string (nullable = true)
#  |-- DRAINAGE AREA ABOVE MOST DOWNSTREAM TRANSECT (89859): string (nullable = true)
#  |-- LENGTH OF STREAM EVALUATED (KM) (89860): string (nullable = true)
#  |-- AVERAGE STREAM WIDTH (METERS) (89861): string (nullable = true)
#  |-- AVERAGE STREAM DEPTH (METERS) (89862): string (nullable = true)
#  |-- MAXIMUM POOL WIDTH AT TIME OF STUDY (METERS) (89864): string (nullable = true)
#  |-- MAXIMUM POOL DEPTH AT TIME OF STUDY(METERS) (89865): string (nullable = true)
#  |-- AVERAGE WIDTH OF NATURAL RIPARIAN VEGETATION (M) (89866): string (nullable = true)
#  |-- AESTHETICS OF REACH(1=WILD 2=NAT. 3=COMM. 4=OFF.) (89867): string (nullable = true)
#  |-- POOL LENGTH, METERS (89869): string (nullable = true)
#  |-- RIPARIAN VEGETATION %: RIGHT BANK - OTHER (89871): string (nullable = true)
#  |-- AVERAGE WIDTH OF NATURAL RIPARIAN BUFFER ON LEFT BANK (M) (89872): string (nullable = true)
#  |-- AVERAGE WIDTH OF NATURAL RIPARIAN BUFFER ON RIGHT BANK (M) (89873): string (nullable = true)
#  |-- AVAILABLE INSTREAM COVER HQI SCORE: 4=ABUNDANT 3=COMMON 2=RARE 1=ABSENT (89874): string (nullable = true)
#  |-- BOTTOM SUBSTRATE STABILITY HQI SCORE: 4=STABLE 3=MODERATELY STABLE 2=MODERATELY  (89875): string (nullable = true)
#  |-- NUMBER OF RIFFLES HQI SCORE: 4=ABUNDANT 3=COMMON 2=RARE 1=ABSENT (89876): string (nullable = true)
#  |-- DIMENSIONS OF LARGEST POOL HQI SCORE: 4=LARGE 3=MODERATE 2=SMALL 1=ABSENT (89877): string (nullable = true)
#  |-- CHANNEL FLOW STATUS HQI SCORE: 3=HIGH 2=MODERATE 1=LOW 0=NO FLOW (89878): string (nullable = true)
#  |-- BANK STABILITY HQI SCORE: 3=STABLE 2=MODERATELY STABLE 1=MODERATELY UNSTABLE 0=U (89879): string (nullable = true)
#  |-- CHANNEL SINUOSITY HQI SCORE: 3=HIGH 2=MODERATE 1=LOW 0=NONE (89880): string (nullable = true)
#  |-- RIPARIAN BUFFER VEGETATION HQI SCORE: 3=EXTENSIVE 2=WIDE 1=MODERATE 0=NARROW (89881): string (nullable = true)
#  |-- AESTHETICS OF REACH HQI SCORE: 3=WILDERNESS 2=NATURAL AREA 1=COMMON SETTING 0=OF (89882): string (nullable = true)
#  |-- HQI TOTAL SCORE (89883): string (nullable = true)
#  |-- REACH LENGTH OF STREAM EVALUATED (M) (89884): string (nullable = true)
#  |-- BIOLOGICAL DATA (89888): string (nullable = true)
#  |-- BENTHIC DATA REPORTING UNITS (1=NUMBER OF INDIVIDUALS IN SUB-SAMPLE, 2=NUMBER OF (89899): string (nullable = true)
#  |-- KICKNET EFFORT,AREA KICKED (SQ.METER) (89903): string (nullable = true)
#  |-- KICKNET EFFORT,MINUTES KICKED (MIN.) (89904): string (nullable = true)
#  |-- NUMBER OF INDIVIDUALS IN BENTHIC SAMPLE (89906): string (nullable = true)
#  |-- UNDERCUT BANK AT COLLECTION POINT (%) (89921): string (nullable = true)
#  |-- OVERHANGING BRUSH AT COLLECTION POINT (%) (89922): string (nullable = true)
#  |-- GRAVEL BOTTOM AT COLLECTION POINT (%) (89923): string (nullable = true)
#  |-- SAND BOTTOM AT COLLECTION POINT (%) (89924): string (nullable = true)
#  |-- SOFT BOTTOM AT COLLECTION POINT (%) (89925): string (nullable = true)
#  |-- MACROPHYTE BED AT COLLECTION POINT (%) (89926): string (nullable = true)
#  |-- SNAGS AND BRUSH AT COLLECTION POINT (%) (89927): string (nullable = true)
#  |-- BEDROCK STREAMBED AT COLLECTION POINT (%) (89928): string (nullable = true)
#  |-- NUMBER OF STREAM COVER TYPES (89929): string (nullable = true)
#  |-- SEINE, MINIMUM MESH SIZE, AVERAGE BAR, NEKTON,IN (89930): string (nullable = true)
#  |-- SEINE, MAXIMUM MESH SIZE, AVG BAR, NEKTON,INCH (89931): string (nullable = true)
#  |-- NET LENGTH (METERS) (89941): string (nullable = true)
#  |-- ELECTROFISHING METHOD 1=BOAT 2=BACKPACK 3=TOTEBARGE (89943): string (nullable = true)
#  |-- ELECTROFISH EFFORT, DURATION OF SHOCKING (SEC) (89944): string (nullable = true)
#  |-- MESH SIZE, ANY NET OR SIEVE, AVERAGE BAR (CM) (89946): string (nullable = true)
#  |-- SEINING EFFORT (# OF SEINE HAULS) (89947): string (nullable = true)
#  |-- COMBINED LENGTH OF SEINE HAULS (METERS) (89948): string (nullable = true)
#  |-- SEINING EFFORT, DURATION (MINUTES) (89949): string (nullable = true)
#  |-- BENTHIC SAMPLE COLLECTION METHOD (1=SURBER, 2=EKMAN, 3=KICKNET, 4=PETERSON, 5=HE (89950): string (nullable = true)
#  |-- ECOREGION LEVEL III (TEXAS ECOREGION CODE) (89961): string (nullable = true)
#  |-- LAND DEVELOP IMPACT (1=UNIMP,2=LOW,3=MOD,4=HIGH) (89962): string (nullable = true)
#  |-- PRESENT WEATHER (1=CLEAR,2=PTCLDY,3=CLDY,4=RAIN,5=OTHER) (89966): string (nullable = true)
#  |-- WATER COLOR 1=BRWN 2=RED 3=GRN 4=BLCK 5=CLR 6=OT (89969): string (nullable = true)
#  |-- WATER ODOR (1=SEWAGE, 2=OILY/CHEMICAL, 3=ROTTEN EGGS, 4=MUSKY, 5=FISHY, 6=NONE,  (89971): string (nullable = true)
#  |-- AREA SEINED (SQ METERS) (89976): string (nullable = true)
#  |-- RECREATIONAL USE: 1 = PRIMARY CONTACT, OBSERVED ACTIVITY; 2 = SECONDARY CONTACT, (89978): string (nullable = true)
#  |-- EVIDENCE OF PRIMARY CONTACT RECREATION (1=OBSERVED, 0=NOT OBSERVED) (89979): string (nullable = true)
#  |-- HILSENHOFF BIOTIC INDEX (HBI) (90007): string (nullable = true)
#  |-- NUMBER OF EPT INDEX (90008): string (nullable = true)
#  |-- DOMINANT BENTHIC FUNCTIONAL FEEDING GRP, % OF INDIVIDUALS (90010): string (nullable = true)
#  |-- TOTAL # OF FAMILIES IN BENTHIC SAMPLE (90012): string (nullable = true)
#  |-- BENTHIC GATHERERS, PERCENT OF INDIVIDUALS (90025): string (nullable = true)
#  |-- BENTHIC PREDATORS, PERCENT OF INDIVIDUALS (90036): string (nullable = true)
#  |-- DOMINANT TAXON, BENTHOS PERCENT OF INDIVIDUALS (90042): string (nullable = true)
#  |-- RATIO OF INTOLERANT TO TOLERANT TAXA, BENTHOS (90050): string (nullable = true)
#  |-- NUMBER OF NON-INSECT TAXA (90052): string (nullable = true)
#  |-- ELMIDAE, PERCENT OF INDIVIDUALS (90054): string (nullable = true)
#  |-- TOTAL TAXA RICHNESS, BENTHOS (90055): string (nullable = true)
#  |-- CHIRONOMIDAE, PERCENT OF INDIVIDUALS (90062): string (nullable = true)
#  |-- PERCENT OF TOTAL TRICHOPTERA INDIVIDUALS AS HYDROPSYCHIDAE (90069): string (nullable = true)
#  |-- PLANARIIDAE (90074): string (nullable = true)
#  |-- DUGESIA (90075): string (nullable = true)
#  |-- RAPID BIOASSESSMENT PROTOCOLS BENTHIC MACROINVERTEBRATE IBI SCORE (90081): string (nullable = true)
#  |-- NEMATA (NEMATODA) (90196): string (nullable = true)
#  |-- NEMATOMORPHA(GORDIIDA) (90291): string (nullable = true)
#  |-- OLIGOCHAETA (90382): string (nullable = true)
#  |-- NAIDIDAE (90425): string (nullable = true)
#  |-- HIRUDINEA (90913): string (nullable = true)
#  |-- GLOSSIPHONIIDAE (90914): string (nullable = true)
#  |-- PISCICOLIDAE (90942): string (nullable = true)
#  |-- AMPHIPODA (91238): string (nullable = true)
#  |-- HYALELLA AZTECA (91241): string (nullable = true)
#  |-- GAMMARIDAE (91259): string (nullable = true)
#  |-- GAMMARUS (91265): string (nullable = true)
#  |-- DECAPODA (91378): string (nullable = true)
#  |-- PALAEMONETES (91397): string (nullable = true)
#  |-- HYDRACHNIDIA (91525): string (nullable = true)
#  |-- LEPTOPHLEBIIDAE (91549): string (nullable = true)
#  |-- PARALEPTOPHLEBIA (91550): string (nullable = true)
#  |-- TRAVERELLA (91552): string (nullable = true)
#  |-- THRAULODES (91562): string (nullable = true)
#  |-- LABIOBAETIS (91579): string (nullable = true)
#  |-- TRICORYTHIDAE (91583): string (nullable = true)
#  |-- OLIGONEURIIDAE (91585): string (nullable = true)
#  |-- ISONYCHIA (91590): string (nullable = true)
#  |-- TRICORYTHODES (91594): string (nullable = true)
#  |-- LEPTOHYPES (91596): string (nullable = true)
#  |-- BRACHYCERCUS (91598): string (nullable = true)
#  |-- CAENIS (91600): string (nullable = true)
#  |-- HEPTAGENIIDAE (91607): string (nullable = true)
#  |-- EPHEMERELLIDAE (91615): string (nullable = true)
#  |-- CAENIDAE (91617): string (nullable = true)
#  |-- STENACRON (91619): string (nullable = true)
#  |-- STENONEMA (91620): string (nullable = true)
#  |-- HEPTAGENIA (91633): string (nullable = true)
#  |-- BAETIDAE (91637): string (nullable = true)
#  |-- SIPHLONURIDAE (91639): string (nullable = true)
#  |-- BAETODES (91642): string (nullable = true)
#  |-- CENTROPTILUM (91644): string (nullable = true)
#  |-- BAETIS (91646): string (nullable = true)
#  |-- CAMELOBAETIDIUS (FORMERLY DACTYLOBAETIS) (91647): string (nullable = true)
#  |-- FARRODES TEXANUS (91661): string (nullable = true)
#  |-- CALOPTERYGIDAE (91666): string (nullable = true)
#  |-- CALOPTERYX (91667): string (nullable = true)
#  |-- HETAERINA (91669): string (nullable = true)
#  |-- ARCHILESTES (91672): string (nullable = true)
#  |-- AGRIONIDAE(CALOPTERYGIDAE) (91676): string (nullable = true)
#  |-- ARGIA (91683): string (nullable = true)
#  |-- CHROMAGRION (91685): string (nullable = true)
#  |-- ENALLAGMA (91687): string (nullable = true)
#  |-- GOMPHIDAE (91706): string (nullable = true)
#  |-- DROMOGOMPHUS (91711): string (nullable = true)
#  |-- ERPETOGOMPHUS (91713): string (nullable = true)
#  |-- GOMPHOIDES (91715): string (nullable = true)
#  |-- GOMPHUS (91718): string (nullable = true)
#  |-- HAGENIUS (91721): string (nullable = true)
#  |-- OPHIOGOMPHUS (91728): string (nullable = true)
#  |-- AESCHNIDAE (91740): string (nullable = true)
#  |-- NASIAESCHNA (91757): string (nullable = true)
#  |-- LIBELLULIDAE (91771): string (nullable = true)
#  |-- BRECHMORHOGA (91776): string (nullable = true)
#  |-- CORDULIIDAE (91785): string (nullable = true)
#  |-- LIBELLULA (91806): string (nullable = true)
#  |-- MIATHYRIA (91813): string (nullable = true)
#  |-- PERLIDAE (91876): string (nullable = true)
#  |-- PERLINELLA (91887): string (nullable = true)
#  |-- VELIIDAE (91918): string (nullable = true)
#  |-- MICROVELIA (91919): string (nullable = true)
#  |-- RHAGOVELIA (91923): string (nullable = true)
#  |-- GERRIDAE (91929): string (nullable = true)
#  |-- TREPOBATES (91946): string (nullable = true)
#  |-- RANATRA (92002): string (nullable = true)
#  |-- NAUCORIDAE (92053): string (nullable = true)
#  |-- CORYDALIDAE (92071): string (nullable = true)
#  |-- CORYDALUS CORNUTUS (92076): string (nullable = true)
#  |-- Sisyridae (92081): string (nullable = true)
#  |-- GYRINIDAE (92089): string (nullable = true)
#  |-- HALIPLIDAE (92095): string (nullable = true)
#  |-- PELTODYTES (92100): string (nullable = true)
#  |-- DYTISCIDAE (92105): string (nullable = true)
#  |-- HYDROPHILIDAE (92153): string (nullable = true)
#  |-- BEROSUS (92154): string (nullable = true)
#  |-- PARACYMUS (92179): string (nullable = true)
#  |-- HELODIDAE (92197): string (nullable = true)
#  |-- PSEPHENIDAE (92208): string (nullable = true)
#  |-- EUBRIANAX (92209): string (nullable = true)
#  |-- PSEPHENUS (92211): string (nullable = true)
#  |-- DRYOPIDAE (92214): string (nullable = true)
#  |-- HELICHUS (92217): string (nullable = true)
#  |-- ELMIDAE (92225): string (nullable = true)
#  |-- DUBIRAPHIA (92230): string (nullable = true)
#  |-- MACRELMIS (FORMERLY ELSIANUS) (92232): string (nullable = true)
#  |-- HETERELMIS (92233): string (nullable = true)
#  |-- HEXACYLLOEPUS (92235): string (nullable = true)
#  |-- MACRONYCHUS (92240): string (nullable = true)
#  |-- MICROCYLLOEPUS (92243): string (nullable = true)
#  |-- NARPUS (92244): string (nullable = true)
#  |-- NEOELMIS (92246): string (nullable = true)
#  |-- STENELMIS (92253): string (nullable = true)
#  |-- PHILOPOTAMIDAE (92267): string (nullable = true)
#  |-- CHIMARRA (92268): string (nullable = true)
#  |-- PSYCHOMYIIDAE (92273): string (nullable = true)
#  |-- NEURECLIPSIS (92278): string (nullable = true)
#  |-- POLYCENTROPODIDAE (92280): string (nullable = true)
#  |-- POLYCENTROPUS (92281): string (nullable = true)
#  |-- HYDROPSYCHIDAE (92289): string (nullable = true)
#  |-- CHEUMATOPSYCHE (92292): string (nullable = true)
#  |-- BRACHYCENTRUS (92293): string (nullable = true)
#  |-- HYDROPSYCHE (92296): string (nullable = true)
#  |-- NECTOPSYCHE (92304): string (nullable = true)
#  |-- POTAMYIA (92305): string (nullable = true)
#  |-- SMICRIDEA (92308): string (nullable = true)
#  |-- GLOSSOSOMATIDAE (92315): string (nullable = true)
#  |-- GLOSSOSOMA (92318): string (nullable = true)
#  |-- PROTOPTILA (92319): string (nullable = true)
#  |-- CYRNELLUS FRATERNUS (92320): string (nullable = true)
#  |-- HYDROPTILIDAE (92321): string (nullable = true)
#  |-- AGRAYLEA (92322): string (nullable = true)
#  |-- HYDROPTILA (92324): string (nullable = true)
#  |-- LEUCOTRICHA (92327): string (nullable = true)
#  |-- OCHROTRICHIA (92332): string (nullable = true)
#  |-- STACTOBIELLA (TASCOBIA) (92337): string (nullable = true)
#  |-- LIMNEPHILIDAE (92359): string (nullable = true)
#  |-- PYCNOPSYCHE (92371): string (nullable = true)
#  |-- HELICOPSYCHIDAE (92375): string (nullable = true)
#  |-- HELICOPSYCHE (92376): string (nullable = true)
#  |-- GOELDICHIRONOMUS PICTUS GR. (92382): string (nullable = true)
#  |-- LEPTOCERIDAE (92383): string (nullable = true)
#  |-- OECETIS (92391): string (nullable = true)
#  |-- TIPULIDAE (92420): string (nullable = true)
#  |-- HEXATOMA (92427): string (nullable = true)
#  |-- CHAOBORUS (92447): string (nullable = true)
#  |-- CULEX (92453): string (nullable = true)
#  |-- PSYCHODIDAE (92467): string (nullable = true)
#  |-- CERATOPOGONIDAE(HELEIDAE) (92474): string (nullable = true)
#  |-- BEZZIA (92478): string (nullable = true)
#  |-- DASYHELEA (92481): string (nullable = true)
#  |-- CHIRONOMIDAE (92491): string (nullable = true)
#  |-- TANYPUS (92493): string (nullable = true)
#  |-- ABLABESMYIA (92503): string (nullable = true)
#  |-- CHIRONOMINAE (92507): string (nullable = true)
#  |-- CHIRONOMUS (92508): string (nullable = true)
#  |-- PARACHIRONOMUS (92526): string (nullable = true)
#  |-- TANYTARSUS (92554): string (nullable = true)
#  |-- CNEPHIA (92564): string (nullable = true)
#  |-- CRICOTOPUS (92575): string (nullable = true)
#  |-- ORTHOCLADIUS (92584): string (nullable = true)
#  |-- SIMULIIDAE (92593): string (nullable = true)
#  |-- SIMULIUM (92596): string (nullable = true)
#  |-- STRATIOMYIDAE (92608): string (nullable = true)
#  |-- ODONTOMYIA (92613): string (nullable = true)
#  |-- TABANIDAE (92618): string (nullable = true)
#  |-- ATHERIX (92625): string (nullable = true)
#  |-- EMPIDIDAE (92627): string (nullable = true)
#  |-- HEMERODROMIA (92628): string (nullable = true)
#  |-- EPHYDRIDAE (92638): string (nullable = true)
#  |-- ATHERICIDAE (92656): string (nullable = true)
#  |-- PYRALIDAE (92662): string (nullable = true)
#  |-- DOLICHOPODIDAE (92673): string (nullable = true)
#  |-- PETROPHILA (92686): string (nullable = true)
#  |-- CRAMBUS (92726): string (nullable = true)
#  |-- VIVIPARIDAE (92754): string (nullable = true)
#  |-- CAMPELOMA (92756): string (nullable = true)
#  |-- VIVIPARUS (92757): string (nullable = true)
#  |-- PLEUROCERIDAE (92777): string (nullable = true)
#  |-- HYDROBIIDAE (92783): string (nullable = true)
#  |-- PHYSIDAE (92871): string (nullable = true)
#  |-- PHYSA (92874): string (nullable = true)
#  |-- LYMNAEIDAE (92876): string (nullable = true)
#  |-- PSEUDOSUCCINEA (92879): string (nullable = true)
#  |-- PLANORBIDAE (92881): string (nullable = true)
#  |-- PLANORBULA (92891): string (nullable = true)
#  |-- THIARA (MELANOIDES) TUBERCULATA (92898): string (nullable = true)
#  |-- ANCYLIDAE (92899): string (nullable = true)
#  |-- FERRISSIA (92900): string (nullable = true)
#  |-- SPHAERIIDAE (93024): string (nullable = true)
#  |-- PISIDIUM (93030): string (nullable = true)
#  |-- SPHAERIUM (93032): string (nullable = true)
#  |-- CORBICULIDAE (CYRENIDAE) (93035): string (nullable = true)
#  |-- CORBICULA FLUMINEA (93037): string (nullable = true)
#  |-- NUMBER OF SPECIES, FISH (98003): string (nullable = true)
#  |-- TOTAL NUMBER OF DARTER SPECIES (98004): string (nullable = true)
#  |-- NEKTON ORGANISMS-NONE PRESENT (98005): string (nullable = true)
#  |-- TOTAL NUMBER OF SUNFISH SPECIES (98008): string (nullable = true)
#  |-- TOTAL NUMBER OF SUCKER SPECIES (98009): string (nullable = true)
#  |-- TOTAL NUMBER OF INTOLERANT SPECIES, FISH (98010): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS AS TOLERANTS, FISH (98016): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS AS OMNIVORES, FISH (98017): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS AS INVERTIVORES, FISH (98021): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS AS PISCIVORES, FISH (98022): string (nullable = true)
#  |-- TOTAL NUMBER OF INDIVIDUALS IN SAMPLE, FISH (98023): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS AS HYBRIDS (98024): string (nullable = true)
#  |-- PERCENT OF INDIVIDUALS WITH DISEASE OR ANOMALY (98030): string (nullable = true)
#  |-- TOTAL NUMBER OF NATIVE CYPRINID SPECIES (98032): string (nullable = true)
#  |-- PERCENT INDIVIDUALS AS NON-NATIVE FISH SPECIES (% OF COMMUNITY) (98033): string (nullable = true)
#  |-- TOTAL NUMBER OF INDIVIDUALS SEINING (98039): string (nullable = true)
#  |-- TOTAL NUMBER OF INDIVIDUALS ELECTROFISHING (98040): string (nullable = true)
#  |-- TOTAL NUMBER OF BENTHIC INVERTIVORE SPECIES (98052): string (nullable = true)
#  |-- TOTAL NUMBER OF BENTHIC FISH SPECIES (98053): string (nullable = true)
#  |-- NUMBER OF INDIVIDUALS PER SEINE HAUL (98062): string (nullable = true)
#  |-- NUMBER OF INDIVIDUALS PER MINUTE ELECTROFISHING (98069): string (nullable = true)
#  |-- PERCENT INDIVIDUALS AS TOLERANT FISH SPECIES(EXCLUDING WESTERN MOSQUITOFISH) (98070): string (nullable = true)
#  |-- NEKTON TEXAS REGIONAL IBI SCORE (98123): string (nullable = true)
#  |-- LEPISOSTEUS OCULATUS (#/SAMPLE) (98340): string (nullable = true)
#  |-- LEPISOSTEUS OSSEUS (#/SAMPLE) (98341): string (nullable = true)
#  |-- ANGUILLA ROSTRATA (#/SAMPLE) (98361): string (nullable = true)
#  |-- DOROSOMA PETENENSE (#/SAMPLE) (98429): string (nullable = true)
#  |-- DOROSOMA CEPEDIANUM (#/SAMPLE) (98430): string (nullable = true)
#  |-- ASTYANAX MEXICANUS (#/SAMPLE) (98435): string (nullable = true)
#  |-- CYPRINUS CARPIO (#/SAMPLE) (98437): string (nullable = true)
#  |-- CARASSIUS AURATUS (#/SAMPLE) (98439): string (nullable = true)
#  |-- NOTEMIGONUS CRYSOLEUCAS (#/SAMPLE) (98441): string (nullable = true)
#  |-- MACRHYBOPSIS AESTIVALIS (#/SAMPLE)H.AESTIVALIS (98449): string (nullable = true)
#  |-- NOTROPIS AMABILIS (#/SAMPLE) (98459): string (nullable = true)
#  |-- NOTROPIS AMNIS (#/SAMPLE) (98460): string (nullable = true)
#  |-- NOTROPIS BUCHANANI (#/SAMPLE) (98467): string (nullable = true)
#  |-- LYTHRURUS FUMEUS (#/SAMPLE) NOTROPIS FUMEUS (98471): string (nullable = true)
#  |-- CYPRINELLA LUTRENSIS (# SAMPLE)NOTROPIS LUTRENSI (98474): string (nullable = true)
#  |-- NOTROPIS STRAMINEUS (#/SAMPLE) (98484): string (nullable = true)
#  |-- NOTROPIS TEXANUS (#/SAMPLE) (98485): string (nullable = true)
#  |-- CYPRINELLA VENUSTUS (#/SAMPLE) NOTROPIS VENUSTUS (98487): string (nullable = true)
#  |-- NOTROPIS VOLUCELLUS (#/SAMPLE) (98488): string (nullable = true)
#  |-- PIMEPHALES PROMELAS (#/SAMPLE) (98497): string (nullable = true)
#  |-- PIMEPHALES VIGILAX (#/SAMPLE) (98498): string (nullable = true)
#  |-- PIMEPHALES NOTATUS (#/SAMPLE) (98499): string (nullable = true)
#  |-- CAMPOSTOMA ANOMALUM (#/SAMPLE) (98502): string (nullable = true)
#  |-- ICTIOBUS BUBALUS (#/SAMPLE) (98507): string (nullable = true)
#  |-- MOXOSTOMA CONGESTUM (#/SAMPLE) (98513): string (nullable = true)
#  |-- HYPOSTOMUS PLECOSTOMUS (#/SAMPLE) (98553): string (nullable = true)
#  |-- ICTALURUS PUNCTATUS (#/SAMPLE) (98561): string (nullable = true)
#  |-- ICTALURUS FURCATUS (#/SAMPLE) (98562): string (nullable = true)
#  |-- AMEIURUS MELAS (#/SAMPLE) ICTALUARUS MELAS (98563): string (nullable = true)
#  |-- AMEIURUS NATALIS (#/SAMPLE) ICTALUARUS NATALIS (98564): string (nullable = true)
#  |-- TILAPIA MOSSAMBICA (#/SAMPLE) (98565): string (nullable = true)
#  |-- PYLODICTIS OLIVARIS (#/SAMPLE) (98570): string (nullable = true)
#  |-- NOTURUS GYRINUS (#/SAMPLE) (98574): string (nullable = true)
#  |-- TILAPIA AUREA, BLUE TILAPIA (#/SAMPLE) (98583): string (nullable = true)
#  |-- TILAPIA ZILLI (#/SAMPLE) (98584): string (nullable = true)
#  |-- MACHRYBOPSIS MARCONIS (#/SAMPLE) (98609): string (nullable = true)
#  |-- FUNDULUS NOTATUS (#/SAMPLE) (98677): string (nullable = true)
#  |-- GAMBUSIA AFFINIS (#/SAMPLE) (98713): string (nullable = true)
#  |-- POECILIA LATIPINNA (#/SAMPLE) (98724): string (nullable = true)
#  |-- POECILIA FORMOSA (#/SAMPLE) (98725): string (nullable = true)
#  |-- MENIDIA BERYLLINA (#/SAMPLE) (98728): string (nullable = true)
#  |-- XIPHOPHORUS HELLERI, NUMBER OF INDIVIDUALS (98743): string (nullable = true)
#  |-- PTERYGOPLICHTHYS (98748): string (nullable = true)
#  |-- PTERYGOPLICHTHYS MULTIRADIATUS, # OF INDIVIDUALS (98749): string (nullable = true)
#  |-- MUGIL CUREMA (#/SAMPLE) (98794): string (nullable = true)
#  |-- CICHLASOMA CYANOGUTTATUM (#/SAMPLE) (98953): string (nullable = true)
#  |-- PERCINA CARBONARIA (#/SAMPLE) (99060): string (nullable = true)
#  |-- PERCINA CAPRODES (#/SAMPLE) (99068): string (nullable = true)
#  |-- PERCINA MACROLEPIDA (#/SAMPLE) (99069): string (nullable = true)
#  |-- ETHEOSTOMA LEPIDUM (#/SAMPLE) (99081): string (nullable = true)
#  |-- ETHEOSTOMA SPECTABILE (#/SAMPLE) (99085): string (nullable = true)
#  |-- MICROPTERUS TRECULI (#/SAMPLE) (99086): string (nullable = true)
#  |-- MICROPTERUS PUNCTULATUS (#/SAMPLE) (99089): string (nullable = true)
#  |-- MICROPTERUS SALMOIDES (#/SAMPLE) (99090): string (nullable = true)
#  |-- MICROPTERUS DOLOMIEU (#/SAMPLE) M. DOLOMIEUI (99091): string (nullable = true)
#  |-- LEPOMIS AURITUS (#/SAMPLE) (99093): string (nullable = true)
#  |-- LEPOMIS CYANELLUS (#/SAMPLE) (99094): string (nullable = true)
#  |-- LEPOMIS GULOSUS (#/SAMPLE) (99095): string (nullable = true)
#  |-- LEPOMIS HUMILIS (#/SAMPLE) (99096): string (nullable = true)
#  |-- LEPOMIS MACROCHIRUS (#/SAMPLE) (99097): string (nullable = true)
#  |-- LEPOMIS MEGALOTIS (#/SAMPLE) (99099): string (nullable = true)
#  |-- LEPOMIS MICROLOPHUS (#/SAMPLE) (99100): string (nullable = true)
#  |-- LEPOMIS PUNCTATUS (#/SAMPLE) (99101): string (nullable = true)
#  |-- POMOXIS ANNULARIS (#/SAMPLE) (99108): string (nullable = true)
#  |-- PERCINA SHUMARDI (#/SAMPLE) (99168): string (nullable = true)
#  |-- Comment: string (nullable = true)

# %%
sara_water_quality.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------
#  Station ID                                                                               | 12689
#  Station Description                                                                      | ROSILLO CREEK 0.1 KM ABOVE SALADO CREEK CONFLUENCE
#  Latitude                                                                                 | 29.320101
#  Longitude                                                                                | -98.406263
#  End Date                                                                                 | 2008-09-18 00:00:00
#  Tag ID                                                                                   | SA10917T
#  End Time                                                                                 | 16:52
#  End Depth                                                                                | 0.28
#  Sample Type                                                                              | RT
#  Program Code                                                                             | IPSW
#  TEMPERATURE, WATER (DEGREES CENTIGRADE) (00010)                                          |  22.7
#  RESERVOIR STAGE (FEET ABOVE MEAN SEA LEVEL) (00052)                                      | -
#  RESERVOIR PERCENT FULL (00053)                                                           | -
#  FLOW  STREAM, INSTANTANEOUS (CUBIC FEET PER SEC) (00061)                                 |  0.03
#  DEPTH, MAXIMUM, OF SAMPLE (FEET) (00068)                                                 | -
#  TRANSPARENCY, SECCHI DISC (METERS) (00078)                                               | -
#  SPECIFIC CONDUCTANCE,FIELD (US/CM @ 25C) (00094)                                         |  603
#  TEMPERATURE, WATER (DEGREES CENTIGRADE), 24HR AVG (00209)                                | -
#  WATER TEMPERATURE, DEGREES CENTIGRADE, 24HR MAX (00210)                                  | -
#  TEMPERATURE, WATER (DEGREES CENTIGRADE) 24HR MIN (00211)                                 | -
#  SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR AVG (00212)                                     | -
#  SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR MAX (00213)                                     | -
#  SPECIFIC CONDUCTANCE, US/CM, FIELD, 24HR MIN (00214)                                     | -
#  PH, S.U., 24HR MAXIMUM VALUE (00215)                                                     | -
#  PH, S.U., 24HR, MINIMUM VALUE (00216)                                                    | -
#  WATER TEMPERATURE, # OF MEASUREMENTS IN 24-HRS (00221)                                   | -
#  SPECIFIC CONDUCTANCE, # OF MEASUREMENTS IN 24-HR (00222)                                 | -
#  pH, # OF MEASUREMENTS IN 24-HRS (00223)                                                  | -
#  OXYGEN, DISSOLVED (MG/L) (00300)                                                         |  8.2
#  BIOCHEMICAL OXYGEN DEMAND (MG/L, 5 DAY - 20DEG C (00310)                                 | -
#  CARBBIOCHEM OXY DM NIT INHB, TOT (MG/L, 5 DAY-20 (00314)                                 | -
#  CHEMICAL OXYGEN DEMAND, .025N K2CR2O7 (MG/L) (00335)                                     | -
#  PH (STANDARD UNITS) (00400)                                                              |  8.1
#  PH (STANDARD UNITS) LAB (00403)                                                          | -
#  ALKALINITY, TOTAL (MG/L AS CACO3) (00410)                                                | -
#  RESIDUE, TOTAL NONFILTRABLE (MG/L) (00530)                                               | -
#  RESIDUE, VOLATILE NONFILTRABLE (MG/L) (00535)                                            | -
#  NITROGEN, AMMONIA, TOTAL (MG/L AS N) (00610)                                             | -
#  NITRITE NITROGEN, TOTAL (MG/L AS N) (00615)                                              | -
#  NITRATE NITROGEN, TOTAL (MG/L AS N) (00620)                                              | -
#  NITROGEN, KJELDAHL, TOTAL (MG/L AS N) (00625)                                            | -
#  PHOSPHORUS, TOTAL, WET METHOD (MG/L AS P) (00665)                                        | -
#  ORTHOPHOSPHATE PHOSPHORUS,DISS,MG/L,FLDFILT<15MIN (00671)                                | -
#  CARBON, TOTAL ORGANIC, NPOC (TOC), MG/L (00680)                                          | -
#  CARBON, DISSOLVED ORGANIC, DNPC (DOC), MG/L (00681)                                      | -
#  HARDNESS, TOTAL (MG/L AS CACO3) (00900)                                                  | -
#  CALCIUM, DISSOLVED (MG/L AS CA) (00915)                                                  | -
#  CALCIUM, TOTAL (MG/L AS CA) (00916)                                                      | -
#  MAGNESIUM, TOTAL (MG/L AS MG) (00927)                                                    | -
#  SODIUM, TOTAL (MG/L AS NA) (00929)                                                       | -
#  POTASSIUM, TOTAL (MG/L AS  K) (00937)                                                    | -
#  CHLORIDE (MG/L AS CL) (00940)                                                            | -
#  SULFATE (MG/L AS SO4) (00945)                                                            | -
#  FLUORIDE, TOTAL (MG/L AS F) (00951)                                                      | -
#  ARSENIC, DISSOLVED  (UG/L AS AS) (01000)                                                 | -
#  ARSENIC, TOTAL (UG/L AS AS) (01002)                                                      | -
#  ARSENIC, BOTTOM DEPOSITS (MG/KG AS AS DRY WT) (01003)                                    | -
#  BARIUM, TOTAL (UG/L AS BA) (01007)                                                       | -
#  BARIUM, BOTTOM DEPOSITS (MG/KG AS BA DRY WT) (01008)                                     | -
#  CADMIUM, DISSOLVED (UG/L AS CD) (01025)                                                  | -
#  CADMIUM, TOTAL (UG/L AS CD) (01027)                                                      | -
#  CADMIUM,TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT) (01028)                                    | -
#  CHROMIUM,TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT (01029)                                    | -
#  CHROMIUM, DISSOLVED (UG/L AS CR) (01030)                                                 | -
#  CHROMIUM, TOTAL (UG/L AS CR) (01034)                                                     | -
#  COPPER, DISSOLVED (UG/L AS CU) (01040)                                                   | -
#  COPPER, TOTAL (UG/L AS CU) (01042)                                                       | -
#  COPPER, BOTTOM DEPOSITS (MG/KG AS CU DRY WT) (01043)                                     | -
#  IRON, DISSOLVED (UG/L) (01046)                                                           | -
#  LEAD, DISSOLVED (UG/L AS PB) (01049)                                                     | -
#  LEAD, TOTAL (UG/L AS PB) (01051)                                                         | -
#  LEAD, BOTTOM DEPOSITS (MG/KG AS PB DRY WT) (01052)                                       | -
#  MANGANESE, BOTTOM DEPOSITS (MG/KG AS MN DRY WG (01053)                                   | -
#  MANGANESE, TOTAL (UG/L AS MN) (01055)                                                    | -
#  MANGANESE, DISSOLVED (UG/L AS MN) (01056)                                                | -
#  MOLYBDENUM, DISSOLVED (UG/L AS MO) (01060)                                               | -
#  MOLYBDENUM, TOTAL (UG/L AS MO) (01062)                                                   | -
#  NICKEL, DISSOLVED (UG/L AS NI) (01065)                                                   | -
#  NICKEL, TOTAL (UG/L AS NI) (01067)                                                       | -
#  NICKEL, TOTAL, BOTTOM DEPOSITS (MG/KG,DRY WT) (01068)                                    | -
#  SILVER, DISSOLVED (UG/L AS AG) (01075)                                                   | -
#  SILVER, BOTTOM DEPOSITS (MG/KG AS AG DRY WT) (01078)                                     | -
#  ZINC, DISSOLVED (UG/L AS ZN) (01090)                                                     | -
#  ZINC, TOTAL (UG/L AS ZN) (01092)                                                         | -
#  ZINC, BOTTOM DEPOSITS (MG/KG AS ZN DRY WT) (01093)                                       | -
#  ANTIMONY, BOTTOM DEPOSITS (MG/KG AS SB DRY WT (01098)                                    | -
#  ALUMINUM, TOTAL (UG/L AS AL) (01105)                                                     | -
#  ALUMINUM, DISSOLVED (UG/L AS AL) (01106)                                                 | -
#  ALUMINUM, BOTTOM DEPOSITS (MG/KG AS AL DRY WT (01108)                                    | -
#  SELENIUM, TOTAL (UG/L AS SE) (01147)                                                     | -
#  SELENIUM, BOTTOM DEPOSITS (MG/KG AS SE DRY WT) (01148)                                   | -
#  FLOW:1=No Flow,2=Low,3=Normal,4=Flood,5=High,6=Dry (01351)                               |  3
#  HARDNESS, DISSOLVED, TITRATED (MG/L AS CaCO3) (22413)                                    | -
#  COLIFORM,TOT,MEMBRANE FILTER,IMMED.M-ENDO, (31501)                                       | -
#  FECAL COLIFORM,MEMBR FILTER,M-FC BROTH, #/100ML (31616)                                  | -
#  E. COLI, MTEC, MF, #/100 ML (31648)                                                      | -
#  ENTEROCOCCI, ME, MF, #/100ML (31649)                                                     | -
#  FECAL STREPTOCOCCI, MBR FILT,KF AGAR,35C,48HR (31673)                                    | -
#  FECAL STREPTOCOCCI,MF M-ENTEROCOCCUS AGAR,35C,48 (31679)                                 | -
#  E. COLI, COLILERT, IDEXX METHOD, MPN/100ML (31699)                                       |  120
#  E COLI,NA+MUG OR EA+MUG,24HRS, 35 DEGREE (#/100M (31700)                                 | -
#  E COLI, SEDIMENT, MPN/100G (31702)                                                       | -
#  E.COLI, COLILERT, IDEXX, HOLDING TIME (31704)                                            |  2.38
#  CHLOROPHYLL-A UG/L SPECTROPHOTOMETRIC ACID. METH (32211)                                 | -
#  PHEOPHYTIN-A UG/L SPECTROPHOTOMETRIC ACID. METH. (32218)                                 | -
#  ETHION IN WHOLE WATER SAMPLE (UG/L) (39398)                                              | -
#  MALATHION IN WHOLE WATER SAMPLE (UG/L) (39530)                                           | -
#  PARATHION IN WHOLE WATER SAMPLE (UG/L) (39540)                                           | -
#  DEMETON IN WHOLE WATER SAMPLE (UG/L) (39560)                                             | -
#  DIAZINON IN WHOLE WATER SAMPLE (UG/L) (39570)                                            | -
#  GUTHION IN WHOLE WATER SAMPLE (UG/L) (39580)                                             | -
#  METHYL PARATHION IN WHOLE WATER SAMPLE (UG/L) (39600)                                    | -
#  RAINFALL (INCHES, GAUGE DATA) (46529)                                                    | -
#  SOLIDS,TOTAL, DISS, ELECTRICAL-CONDUCTIVITY,MG/L (47004)                                 | -
#  RESIDUE, TOT DISS,UNSPEC CALC BASED ON COND (MG/ (70294)                                 | -
#  RESIDUE,TOTAL FILTRABLE (DRIED AT 180C) (MG/L) (70300)                                   | -
#  ORTHOPHOSPHATE PHOSPHORUS,DISS,MG/L,FILTER >15MIN (70507)                                | -
#  MERCURY, TOTAL  (UG/L AS HG) (71900)                                                     | -
#  MERCURY,TOT. IN BOT. DEPOS. (MG/KG) AS HG DRY WG (71921)                                 | -
#  STREAMBED SLOPE (M/KM) (72051)                                                           | -
#  STREAMBED SLOPE (FT/FT) (72052)                                                          | -
#  DAYS SINCE PRECIPITATION EVENT (DAYS) (72053)                                            |  5
#  IRON, TOTAL, AS FE - (MG/L) (74010)                                                      | -
#  STREAM FLOW ESTIMATE (CFS) (74069)                                                       | -
#  DURSBAN(CHLOROPYRIFOS)WHOLE WATER SAMPLE (UG/L) (81403)                                  | -
#  TURBIDITY,LAB NEPHELOMETRIC TURBIDITY UNITS, NTU (82079)                                 | -
#  HARDNESS, TOTAL, CALCULATED (MG/L AS CaCO3) (82394)                                      | -
#  RAINFALL IN 1 DAY INCLUSIVE PRIOR TO SAMPLE (IN) (82553)                                 | -
#  DEPTH OF BOTTOM OF WATER BODY AT SAMPLE SITE (82903)                                     | -
#  AVERAGE PERCENTAGE INSTREAM COVER (84159)                                                | -
#  STREAM ORDER (84161)                                                                     | -
#  STREAM TYPE; 1=PERENNIAL 2=INTERMITTENT S/PERENNIAL POOLS 3=INTERMITTENT 4=UNKNO (89821) | -
#  RIPARIAN VEGETATION %; LEFT BANK - TREES (89822)                                         | -
#  RIPARIAN VEGETATION %; RIGHT BANK - TREES (89823)                                        | -
#  RIPARIAN VEGETATION %; LEFT BANK SHRUBS (89824)                                          | -
#  RIPARIAN VEGETATION %; RIGHT BANK - SHRUBS (89825)                                       | -
#  RIPARIAN VEGETATION %: LEFT BANK - GRASSES OR FORBS (89826)                              | -
#  RIPARIAN VEGETATION %; RIGHT BANK - GRASSES OR FORBS (89827)                             | -
#  RIPARIAN VEGETATION %: LEFT BANK - CULTIVATED FIELDS (89828)                             | -
#  RIPARIAN VEGETATION %: RIGHT BANK - CULTIVATED FIELDS (89829)                            | -
#  RIPARIAN VEGETATION %: LEFT BANK - OTHER (89830)                                         | -
#  NUMBER OF LATERAL TRANSECTS MADE (89832)                                                 | -
#  FLOW MTH 1=GAGE 2=ELEC 3=MECH 4=WEIR/FLU 5=DOPPLER (89835)                               |  5
#  TOTAL NUMBER OF STREAM BENDS (89839)                                                     | -
#  NUMBER OF WELL DEFINED STREAM BENDS (89840)                                              | -
#  NUMBER OF MODERATELY DEFINED STREAM BENDS (89841)                                        | -
#  NUMBER OF POORLY DEFINED STREAM BENDS (89842)                                            | -
#  TOTAL NUMBER OF RIFFLES (89843)                                                          | -
#  DOMINANT SUBSTRATE TYPE(1=CLAY,2=SILT,3=SAND,4=GRAVEL,5=COBBLE,6=BOULDER,7=BEDRO (89844) | -
#  AVERAGE PERCENT OF SUBSTRATE GRAVEL SIZE OR LARGER (89845)                               | -
#  AVERAGE STREAM BANK EROSION (%) (89846)                                                  | -
#  AVERAGE STREAM BANK SLOPE (DEGREES) (89847)                                              | -
#  HABITAT FLOW STATUS, 1=NO FLOW, 2=LOW,3=MOD,4=HIGH (89848)                               | -
#  AVERAGE PERCENT TREES AS RIPARIAN VEGETATION (89849)                                     | -
#  AVERAGE PERCENT SHRUBS AS RIPARIAN VEGETATION (89850)                                    | -
#  AVERAGE PERCENT GRASS AS RIPARIAN VEGETATION (89851)                                     | -
#  AVERAGE PERCENT CULTIVATED FIELDS AS RIPARIAN VEGETATION (89852)                         | -
#  AVERAGE PERCENT OTHER AS RIPARIAN VEGETATION (89853)                                     | -
#  AVERAGE PERCENTAGE OF TREE CANOPY COVERAGE (89854)                                       | -
#  DISSOLVED OXYGEN, 24-HOUR MIN. (MG/L) MIN. 4 MEA (89855)                                 | -
#  DISSOLVED OXYGEN, 24-HOUR MAX. (MG/L) MIN. 4 MEA (89856)                                 | -
#  DISSOLVED OXYGEN, 24-HOUR AVG. (MG/L) MIN. 4 MEA (89857)                                 | -
#  DISSOLVED OXYGEN, # OF MEASUREMENTS IN 24-HRS (89858)                                    | -
#  DRAINAGE AREA ABOVE MOST DOWNSTREAM TRANSECT (89859)                                     | -
#  LENGTH OF STREAM EVALUATED (KM) (89860)                                                  | -
#  AVERAGE STREAM WIDTH (METERS) (89861)                                                    | -
#  AVERAGE STREAM DEPTH (METERS) (89862)                                                    | -
#  MAXIMUM POOL WIDTH AT TIME OF STUDY (METERS) (89864)                                     | -
#  MAXIMUM POOL DEPTH AT TIME OF STUDY(METERS) (89865)                                      | -
#  AVERAGE WIDTH OF NATURAL RIPARIAN VEGETATION (M) (89866)                                 | -
#  AESTHETICS OF REACH(1=WILD 2=NAT. 3=COMM. 4=OFF.) (89867)                                | -
#  POOL LENGTH, METERS (89869)                                                              | -
#  RIPARIAN VEGETATION %: RIGHT BANK - OTHER (89871)                                        | -
#  AVERAGE WIDTH OF NATURAL RIPARIAN BUFFER ON LEFT BANK (M) (89872)                        | -
#  AVERAGE WIDTH OF NATURAL RIPARIAN BUFFER ON RIGHT BANK (M) (89873)                       | -
#  AVAILABLE INSTREAM COVER HQI SCORE: 4=ABUNDANT 3=COMMON 2=RARE 1=ABSENT (89874)          | -
#  BOTTOM SUBSTRATE STABILITY HQI SCORE: 4=STABLE 3=MODERATELY STABLE 2=MODERATELY  (89875) | -
#  NUMBER OF RIFFLES HQI SCORE: 4=ABUNDANT 3=COMMON 2=RARE 1=ABSENT (89876)                 | -
#  DIMENSIONS OF LARGEST POOL HQI SCORE: 4=LARGE 3=MODERATE 2=SMALL 1=ABSENT (89877)        | -
#  CHANNEL FLOW STATUS HQI SCORE: 3=HIGH 2=MODERATE 1=LOW 0=NO FLOW (89878)                 | -
#  BANK STABILITY HQI SCORE: 3=STABLE 2=MODERATELY STABLE 1=MODERATELY UNSTABLE 0=U (89879) | -
#  CHANNEL SINUOSITY HQI SCORE: 3=HIGH 2=MODERATE 1=LOW 0=NONE (89880)                      | -
#  RIPARIAN BUFFER VEGETATION HQI SCORE: 3=EXTENSIVE 2=WIDE 1=MODERATE 0=NARROW (89881)     | -
#  AESTHETICS OF REACH HQI SCORE: 3=WILDERNESS 2=NATURAL AREA 1=COMMON SETTING 0=OF (89882) | -
#  HQI TOTAL SCORE (89883)                                                                  | -
#  REACH LENGTH OF STREAM EVALUATED (M) (89884)                                             | -
#  BIOLOGICAL DATA (89888)                                                                  | -
#  BENTHIC DATA REPORTING UNITS (1=NUMBER OF INDIVIDUALS IN SUB-SAMPLE, 2=NUMBER OF (89899) | -
#  KICKNET EFFORT,AREA KICKED (SQ.METER) (89903)                                            | -
#  KICKNET EFFORT,MINUTES KICKED (MIN.) (89904)                                             | -
#  NUMBER OF INDIVIDUALS IN BENTHIC SAMPLE (89906)                                          | -
#  UNDERCUT BANK AT COLLECTION POINT (%) (89921)                                            | -
#  OVERHANGING BRUSH AT COLLECTION POINT (%) (89922)                                        | -
#  GRAVEL BOTTOM AT COLLECTION POINT (%) (89923)                                            | -
#  SAND BOTTOM AT COLLECTION POINT (%) (89924)                                              | -
#  SOFT BOTTOM AT COLLECTION POINT (%) (89925)                                              | -
#  MACROPHYTE BED AT COLLECTION POINT (%) (89926)                                           | -
#  SNAGS AND BRUSH AT COLLECTION POINT (%) (89927)                                          | -
#  BEDROCK STREAMBED AT COLLECTION POINT (%) (89928)                                        | -
#  NUMBER OF STREAM COVER TYPES (89929)                                                     | -
#  SEINE, MINIMUM MESH SIZE, AVERAGE BAR, NEKTON,IN (89930)                                 | -
#  SEINE, MAXIMUM MESH SIZE, AVG BAR, NEKTON,INCH (89931)                                   | -
#  NET LENGTH (METERS) (89941)                                                              | -
#  ELECTROFISHING METHOD 1=BOAT 2=BACKPACK 3=TOTEBARGE (89943)                              | -
#  ELECTROFISH EFFORT, DURATION OF SHOCKING (SEC) (89944)                                   | -
#  MESH SIZE, ANY NET OR SIEVE, AVERAGE BAR (CM) (89946)                                    | -
#  SEINING EFFORT (# OF SEINE HAULS) (89947)                                                | -
#  COMBINED LENGTH OF SEINE HAULS (METERS) (89948)                                          | -
#  SEINING EFFORT, DURATION (MINUTES) (89949)                                               | -
#  BENTHIC SAMPLE COLLECTION METHOD (1=SURBER, 2=EKMAN, 3=KICKNET, 4=PETERSON, 5=HE (89950) | -
#  ECOREGION LEVEL III (TEXAS ECOREGION CODE) (89961)                                       | -
#  LAND DEVELOP IMPACT (1=UNIMP,2=LOW,3=MOD,4=HIGH) (89962)                                 | -
#  PRESENT WEATHER (1=CLEAR,2=PTCLDY,3=CLDY,4=RAIN,5=OTHER) (89966)                         |  2
#  WATER COLOR 1=BRWN 2=RED 3=GRN 4=BLCK 5=CLR 6=OT (89969)                                 |  3
#  WATER ODOR (1=SEWAGE, 2=OILY/CHEMICAL, 3=ROTTEN EGGS, 4=MUSKY, 5=FISHY, 6=NONE,  (89971) |  6
#  AREA SEINED (SQ METERS) (89976)                                                          | -
#  RECREATIONAL USE: 1 = PRIMARY CONTACT, OBSERVED ACTIVITY; 2 = SECONDARY CONTACT, (89978) | -
#  EVIDENCE OF PRIMARY CONTACT RECREATION (1=OBSERVED, 0=NOT OBSERVED) (89979)              | -
#  HILSENHOFF BIOTIC INDEX (HBI) (90007)                                                    | -
#  NUMBER OF EPT INDEX (90008)                                                              | -
#  DOMINANT BENTHIC FUNCTIONAL FEEDING GRP, % OF INDIVIDUALS (90010)                        | -
#  TOTAL # OF FAMILIES IN BENTHIC SAMPLE (90012)                                            | -
#  BENTHIC GATHERERS, PERCENT OF INDIVIDUALS (90025)                                        | -
#  BENTHIC PREDATORS, PERCENT OF INDIVIDUALS (90036)                                        | -
#  DOMINANT TAXON, BENTHOS PERCENT OF INDIVIDUALS (90042)                                   | -
#  RATIO OF INTOLERANT TO TOLERANT TAXA, BENTHOS (90050)                                    | -
#  NUMBER OF NON-INSECT TAXA (90052)                                                        | -
#  ELMIDAE, PERCENT OF INDIVIDUALS (90054)                                                  | -
#  TOTAL TAXA RICHNESS, BENTHOS (90055)                                                     | -
#  CHIRONOMIDAE, PERCENT OF INDIVIDUALS (90062)                                             | -
#  PERCENT OF TOTAL TRICHOPTERA INDIVIDUALS AS HYDROPSYCHIDAE (90069)                       | -
#  PLANARIIDAE (90074)                                                                      | -
#  DUGESIA (90075)                                                                          | -
#  RAPID BIOASSESSMENT PROTOCOLS BENTHIC MACROINVERTEBRATE IBI SCORE (90081)                | -
#  NEMATA (NEMATODA) (90196)                                                                | -
#  NEMATOMORPHA(GORDIIDA) (90291)                                                           | -
#  OLIGOCHAETA (90382)                                                                      | -
#  NAIDIDAE (90425)                                                                         | -
#  HIRUDINEA (90913)                                                                        | -
#  GLOSSIPHONIIDAE (90914)                                                                  | -
#  PISCICOLIDAE (90942)                                                                     | -
#  AMPHIPODA (91238)                                                                        | -
#  HYALELLA AZTECA (91241)                                                                  | -
#  GAMMARIDAE (91259)                                                                       | -
#  GAMMARUS (91265)                                                                         | -
#  DECAPODA (91378)                                                                         | -
#  PALAEMONETES (91397)                                                                     | -
#  HYDRACHNIDIA (91525)                                                                     | -
#  LEPTOPHLEBIIDAE (91549)                                                                  | -
#  PARALEPTOPHLEBIA (91550)                                                                 | -
#  TRAVERELLA (91552)                                                                       | -
#  THRAULODES (91562)                                                                       | -
#  LABIOBAETIS (91579)                                                                      | -
#  TRICORYTHIDAE (91583)                                                                    | -
#  OLIGONEURIIDAE (91585)                                                                   | -
#  ISONYCHIA (91590)                                                                        | -
#  TRICORYTHODES (91594)                                                                    | -
#  LEPTOHYPES (91596)                                                                       | -
#  BRACHYCERCUS (91598)                                                                     | -
#  CAENIS (91600)                                                                           | -
#  HEPTAGENIIDAE (91607)                                                                    | -
#  EPHEMERELLIDAE (91615)                                                                   | -
#  CAENIDAE (91617)                                                                         | -
#  STENACRON (91619)                                                                        | -
#  STENONEMA (91620)                                                                        | -
#  HEPTAGENIA (91633)                                                                       | -
#  BAETIDAE (91637)                                                                         | -
#  SIPHLONURIDAE (91639)                                                                    | -
#  BAETODES (91642)                                                                         | -
#  CENTROPTILUM (91644)                                                                     | -
#  BAETIS (91646)                                                                           | -
#  CAMELOBAETIDIUS (FORMERLY DACTYLOBAETIS) (91647)                                         | -
#  FARRODES TEXANUS (91661)                                                                 | -
#  CALOPTERYGIDAE (91666)                                                                   | -
#  CALOPTERYX (91667)                                                                       | -
#  HETAERINA (91669)                                                                        | -
#  ARCHILESTES (91672)                                                                      | -
#  AGRIONIDAE(CALOPTERYGIDAE) (91676)                                                       | -
#  ARGIA (91683)                                                                            | -
#  CHROMAGRION (91685)                                                                      | -
#  ENALLAGMA (91687)                                                                        | -
#  GOMPHIDAE (91706)                                                                        | -
#  DROMOGOMPHUS (91711)                                                                     | -
#  ERPETOGOMPHUS (91713)                                                                    | -
#  GOMPHOIDES (91715)                                                                       | -
#  GOMPHUS (91718)                                                                          | -
#  HAGENIUS (91721)                                                                         | -
#  OPHIOGOMPHUS (91728)                                                                     | -
#  AESCHNIDAE (91740)                                                                       | -
#  NASIAESCHNA (91757)                                                                      | -
#  LIBELLULIDAE (91771)                                                                     | -
#  BRECHMORHOGA (91776)                                                                     | -
#  CORDULIIDAE (91785)                                                                      | -
#  LIBELLULA (91806)                                                                        | -
#  MIATHYRIA (91813)                                                                        | -
#  PERLIDAE (91876)                                                                         | -
#  PERLINELLA (91887)                                                                       | -
#  VELIIDAE (91918)                                                                         | -
#  MICROVELIA (91919)                                                                       | -
#  RHAGOVELIA (91923)                                                                       | -
#  GERRIDAE (91929)                                                                         | -
#  TREPOBATES (91946)                                                                       | -
#  RANATRA (92002)                                                                          | -
#  NAUCORIDAE (92053)                                                                       | -
#  CORYDALIDAE (92071)                                                                      | -
#  CORYDALUS CORNUTUS (92076)                                                               | -
#  Sisyridae (92081)                                                                        | -
#  GYRINIDAE (92089)                                                                        | -
#  HALIPLIDAE (92095)                                                                       | -
#  PELTODYTES (92100)                                                                       | -
#  DYTISCIDAE (92105)                                                                       | -
#  HYDROPHILIDAE (92153)                                                                    | -
#  BEROSUS (92154)                                                                          | -
#  PARACYMUS (92179)                                                                        | -
#  HELODIDAE (92197)                                                                        | -
#  PSEPHENIDAE (92208)                                                                      | -
#  EUBRIANAX (92209)                                                                        | -
#  PSEPHENUS (92211)                                                                        | -
#  DRYOPIDAE (92214)                                                                        | -
#  HELICHUS (92217)                                                                         | -
#  ELMIDAE (92225)                                                                          | -
#  DUBIRAPHIA (92230)                                                                       | -
#  MACRELMIS (FORMERLY ELSIANUS) (92232)                                                    | -
#  HETERELMIS (92233)                                                                       | -
#  HEXACYLLOEPUS (92235)                                                                    | -
#  MACRONYCHUS (92240)                                                                      | -
#  MICROCYLLOEPUS (92243)                                                                   | -
#  NARPUS (92244)                                                                           | -
#  NEOELMIS (92246)                                                                         | -
#  STENELMIS (92253)                                                                        | -
#  PHILOPOTAMIDAE (92267)                                                                   | -
#  CHIMARRA (92268)                                                                         | -
# ...
#  PETROPHILA (92686)                                                                       | -
#  CRAMBUS (92726)                                                                          | -
#  VIVIPARIDAE (92754)                                                                      | -
#  CAMPELOMA (92756)                                                                        | -
#  VIVIPARUS (92757)                                                                        | -
#  PLEUROCERIDAE (92777)                                                                    | -
#  HYDROBIIDAE (92783)                                                                      | -
#  PHYSIDAE (92871)                                                                         | -
#  PHYSA (92874)                                                                            | -
#  LYMNAEIDAE (92876)                                                                       | -
#  PSEUDOSUCCINEA (92879)                                                                   | -
#  PLANORBIDAE (92881)                                                                      | -
#  PLANORBULA (92891)                                                                       | -
#  THIARA (MELANOIDES) TUBERCULATA (92898)                                                  | -
#  ANCYLIDAE (92899)                                                                        | -
#  FERRISSIA (92900)                                                                        | -
#  SPHAERIIDAE (93024)                                                                      | -
#  PISIDIUM (93030)                                                                         | -
#  SPHAERIUM (93032)                                                                        | -
#  CORBICULIDAE (CYRENIDAE) (93035)                                                         | -
#  CORBICULA FLUMINEA (93037)                                                               | -
#  NUMBER OF SPECIES, FISH (98003)                                                          | -
#  TOTAL NUMBER OF DARTER SPECIES (98004)                                                   | -
#  NEKTON ORGANISMS-NONE PRESENT (98005)                                                    | -
#  TOTAL NUMBER OF SUNFISH SPECIES (98008)                                                  | -
#  TOTAL NUMBER OF SUCKER SPECIES (98009)                                                   | -
#  TOTAL NUMBER OF INTOLERANT SPECIES, FISH (98010)                                         | -
#  PERCENT OF INDIVIDUALS AS TOLERANTS, FISH (98016)                                        | -
#  PERCENT OF INDIVIDUALS AS OMNIVORES, FISH (98017)                                        | -
#  PERCENT OF INDIVIDUALS AS INVERTIVORES, FISH (98021)                                     | -
#  PERCENT OF INDIVIDUALS AS PISCIVORES, FISH (98022)                                       | -
#  TOTAL NUMBER OF INDIVIDUALS IN SAMPLE, FISH (98023)                                      | -
#  PERCENT OF INDIVIDUALS AS HYBRIDS (98024)                                                | -
#  PERCENT OF INDIVIDUALS WITH DISEASE OR ANOMALY (98030)                                   | -
#  TOTAL NUMBER OF NATIVE CYPRINID SPECIES (98032)                                          | -
#  PERCENT INDIVIDUALS AS NON-NATIVE FISH SPECIES (% OF COMMUNITY) (98033)                  | -
#  TOTAL NUMBER OF INDIVIDUALS SEINING (98039)                                              | -
#  TOTAL NUMBER OF INDIVIDUALS ELECTROFISHING (98040)                                       | -
#  TOTAL NUMBER OF BENTHIC INVERTIVORE SPECIES (98052)                                      | -
#  TOTAL NUMBER OF BENTHIC FISH SPECIES (98053)                                             | -
#  NUMBER OF INDIVIDUALS PER SEINE HAUL (98062)                                             | -
#  NUMBER OF INDIVIDUALS PER MINUTE ELECTROFISHING (98069)                                  | -
#  PERCENT INDIVIDUALS AS TOLERANT FISH SPECIES(EXCLUDING WESTERN MOSQUITOFISH) (98070)     | -
#  NEKTON TEXAS REGIONAL IBI SCORE (98123)                                                  | -
#  LEPISOSTEUS OCULATUS (#/SAMPLE) (98340)                                                  | -
#  LEPISOSTEUS OSSEUS (#/SAMPLE) (98341)                                                    | -
#  ANGUILLA ROSTRATA (#/SAMPLE) (98361)                                                     | -
#  DOROSOMA PETENENSE (#/SAMPLE) (98429)                                                    | -
#  DOROSOMA CEPEDIANUM (#/SAMPLE) (98430)                                                   | -
#  ASTYANAX MEXICANUS (#/SAMPLE) (98435)                                                    | -
#  CYPRINUS CARPIO (#/SAMPLE) (98437)                                                       | -
#  CARASSIUS AURATUS (#/SAMPLE) (98439)                                                     | -
#  NOTEMIGONUS CRYSOLEUCAS (#/SAMPLE) (98441)                                               | -
#  MACRHYBOPSIS AESTIVALIS (#/SAMPLE)H.AESTIVALIS (98449)                                   | -
#  NOTROPIS AMABILIS (#/SAMPLE) (98459)                                                     | -
#  NOTROPIS AMNIS (#/SAMPLE) (98460)                                                        | -
#  NOTROPIS BUCHANANI (#/SAMPLE) (98467)                                                    | -
#  LYTHRURUS FUMEUS (#/SAMPLE) NOTROPIS FUMEUS (98471)                                      | -
#  CYPRINELLA LUTRENSIS (# SAMPLE)NOTROPIS LUTRENSI (98474)                                 | -
#  NOTROPIS STRAMINEUS (#/SAMPLE) (98484)                                                   | -
#  NOTROPIS TEXANUS (#/SAMPLE) (98485)                                                      | -
#  CYPRINELLA VENUSTUS (#/SAMPLE) NOTROPIS VENUSTUS (98487)                                 | -
#  NOTROPIS VOLUCELLUS (#/SAMPLE) (98488)                                                   | -
#  PIMEPHALES PROMELAS (#/SAMPLE) (98497)                                                   | -
#  PIMEPHALES VIGILAX (#/SAMPLE) (98498)                                                    | -
#  PIMEPHALES NOTATUS (#/SAMPLE) (98499)                                                    | -
#  CAMPOSTOMA ANOMALUM (#/SAMPLE) (98502)                                                   | -
#  ICTIOBUS BUBALUS (#/SAMPLE) (98507)                                                      | -
#  MOXOSTOMA CONGESTUM (#/SAMPLE) (98513)                                                   | -
#  HYPOSTOMUS PLECOSTOMUS (#/SAMPLE) (98553)                                                | -
#  ICTALURUS PUNCTATUS (#/SAMPLE) (98561)                                                   | -
#  ICTALURUS FURCATUS (#/SAMPLE) (98562)                                                    | -
#  AMEIURUS MELAS (#/SAMPLE) ICTALUARUS MELAS (98563)                                       | -
#  AMEIURUS NATALIS (#/SAMPLE) ICTALUARUS NATALIS (98564)                                   | -
#  TILAPIA MOSSAMBICA (#/SAMPLE) (98565)                                                    | -
#  PYLODICTIS OLIVARIS (#/SAMPLE) (98570)                                                   | -
#  NOTURUS GYRINUS (#/SAMPLE) (98574)                                                       | -
#  TILAPIA AUREA, BLUE TILAPIA (#/SAMPLE) (98583)                                           | -
#  TILAPIA ZILLI (#/SAMPLE) (98584)                                                         | -
#  MACHRYBOPSIS MARCONIS (#/SAMPLE) (98609)                                                 | -
#  FUNDULUS NOTATUS (#/SAMPLE) (98677)                                                      | -
#  GAMBUSIA AFFINIS (#/SAMPLE) (98713)                                                      | -
#  POECILIA LATIPINNA (#/SAMPLE) (98724)                                                    | -
#  POECILIA FORMOSA (#/SAMPLE) (98725)                                                      | -
#  MENIDIA BERYLLINA (#/SAMPLE) (98728)                                                     | -
#  XIPHOPHORUS HELLERI, NUMBER OF INDIVIDUALS (98743)                                       | -
#  PTERYGOPLICHTHYS (98748)                                                                 | -
#  PTERYGOPLICHTHYS MULTIRADIATUS, # OF INDIVIDUALS (98749)                                 | -
#  MUGIL CUREMA (#/SAMPLE) (98794)                                                          | -
#  CICHLASOMA CYANOGUTTATUM (#/SAMPLE) (98953)                                              | -
#  PERCINA CARBONARIA (#/SAMPLE) (99060)                                                    | -
#  PERCINA CAPRODES (#/SAMPLE) (99068)                                                      | -
#  PERCINA MACROLEPIDA (#/SAMPLE) (99069)                                                   | -
#  ETHEOSTOMA LEPIDUM (#/SAMPLE) (99081)                                                    | -
#  ETHEOSTOMA SPECTABILE (#/SAMPLE) (99085)                                                 | -
#  MICROPTERUS TRECULI (#/SAMPLE) (99086)                                                   | -
#  MICROPTERUS PUNCTULATUS (#/SAMPLE) (99089)                                               | -
#  MICROPTERUS SALMOIDES (#/SAMPLE) (99090)                                                 | -
#  MICROPTERUS DOLOMIEU (#/SAMPLE) M. DOLOMIEUI (99091)                                     | -
#  LEPOMIS AURITUS (#/SAMPLE) (99093)                                                       | -
#  LEPOMIS CYANELLUS (#/SAMPLE) (99094)                                                     | -
#  LEPOMIS GULOSUS (#/SAMPLE) (99095)                                                       | -
#  LEPOMIS HUMILIS (#/SAMPLE) (99096)                                                       | -
#  LEPOMIS MACROCHIRUS (#/SAMPLE) (99097)                                                   | -
#  LEPOMIS MEGALOTIS (#/SAMPLE) (99099)                                                     | -
#  LEPOMIS MICROLOPHUS (#/SAMPLE) (99100)                                                   | -
#  LEPOMIS PUNCTATUS (#/SAMPLE) (99101)                                                     | -
#  POMOXIS ANNULARIS (#/SAMPLE) (99108)                                                     | -
#  PERCINA SHUMARDI (#/SAMPLE) (99168)                                                      | -
#  Comment                                                                                  | Abundant algae
# only showing top 1 row

# %%
shape= sara_water_quality.count(), len(sara_water_quality.columns)
shape
# Out:
# (10884, 500)

# %%
sara_water_quality.select('End Date') \
                  .sort('End Date', ascending=False) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-----------------------
#  End Date | 2019-02-27 00:00:00
# -RECORD 1-----------------------
#  End Date | 2019-02-27 00:00:00
# -RECORD 2-----------------------
#  End Date | 2019-02-20 00:00:00
# only showing top 3 rows

# %%
sara_water_quality.select('End Date') \
                  .sort('End Date', ascending=True) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-----------------------
#  End Date | 1998-01-05 00:00:00
# -RECORD 1-----------------------
#  End Date | 1998-01-05 00:00:00
# -RECORD 2-----------------------
#  End Date | 1998-01-08 00:00:00
# only showing top 3 rows

# %% [markdown]
# # ./data/sara-rainfall-summary.csv

# %%
sara_rainfall_summary = spark.read.format("csv").\
    option("sep", ",").\
    option("header", True).\
    option("inferSchema", True).\
    load("./data/sara-rainfall-summary.csv")

sara_rainfall_summary.printSchema()
# Out:
# root
#  |-- location_name: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- daily_rainfall_total_inches: double (nullable = true)

# %%
sara_rainfall_summary.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------------------
#  location_name               | Blanco Road Dam
#  latitude                    | 29.6248
#  longitude                   | -98.52135
#  date                        | 2018-01-01 00:00:00
#  daily_rainfall_total_inches | 0.01
# only showing top 1 row

# %%
shape= sara_rainfall_summary.count(), len(sara_rainfall_summary.columns)
shape
# Out:
# (13395, 5)

# %%
sara_rainfall_summary.select('date') \
                  .sort('date', ascending=False) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------
#  date | 2019-04-08 00:00:00
# -RECORD 1-------------------
#  date | 2019-04-08 00:00:00
# -RECORD 2-------------------
#  date | 2019-04-08 00:00:00
# only showing top 3 rows

# %%
sara_rainfall_summary.select('date') \
                  .sort('date', ascending=True) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------
#  date | 2018-01-01 00:00:00
# -RECORD 1-------------------
#  date | 2018-01-01 00:00:00
# -RECORD 2-------------------
#  date | 2018-01-01 00:00:00
# only showing top 3 rows

# %%
sara_rainfall_summary.select('daily_rainfall_total_inches') \
                  .sort('daily_rainfall_total_inches', ascending=False) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0----------------------------
#  daily_rainfall_total_inches | 12.66
# -RECORD 1----------------------------
#  daily_rainfall_total_inches | 7.75
# -RECORD 2----------------------------
#  daily_rainfall_total_inches | 6.76
# only showing top 3 rows

# %%
sara_rainfall_summary.select('daily_rainfall_total_inches') \
                  .sort('daily_rainfall_total_inches', ascending=True) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0--------------------------
#  daily_rainfall_total_inches | 0.0
# -RECORD 1--------------------------
#  daily_rainfall_total_inches | 0.0
# -RECORD 2--------------------------
#  daily_rainfall_total_inches | 0.0
# only showing top 3 rows

# %% [markdown]
# # ./data/sara-riverstage-daily-average.csv

# %%
sara_riverstage_daily_avg = spark.read.format("csv").\
    option("sep", ",").\
    option("header", True).\
    option("inferSchema", True).\
    load("./data/sara-riverstage-daily-average.csv")

sara_riverstage_daily_avg.printSchema()
# Out:
# root
#  |-- location_name: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- daily_average_stage: double (nullable = true)
#  |-- tranducer_elevation: double (nullable = true)

# %%
sara_riverstage_daily_avg.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0----------------------------------
#  location_name       | SAR 01 (Lonestar)
#  latitude            | 29.4019
#  longitude           | -98.48849
#  date                | 2018-06-20 00:00:00
#  daily_average_stage | 1.12641791
#  tranducer_elevation | 602.3
# only showing top 1 row

# %%
shape= sara_riverstage_daily_avg.count(), len(sara_riverstage_daily_avg.columns)
shape
# Out:
# (1470, 6)

# %%
sara_riverstage_daily_avg.select('date') \
                  .sort('date', ascending=False) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------
#  date | 2019-04-09 00:00:00
# -RECORD 1-------------------
#  date | 2019-04-09 00:00:00
# -RECORD 2-------------------
#  date | 2019-04-09 00:00:00
# only showing top 3 rows

# %%
sara_riverstage_daily_avg.select('date') \
                  .sort('date', ascending=True) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------
#  date | 2018-06-20 00:00:00
# -RECORD 1-------------------
#  date | 2018-06-20 00:00:00
# -RECORD 2-------------------
#  date | 2018-06-20 00:00:00
# only showing top 3 rows

# %%
sara_riverstage_daily_avg.select('daily_average_stage') \
                  .sort('daily_average_stage', ascending=False) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------
#  daily_average_stage | 6.37479167
# -RECORD 1-------------------------
#  daily_average_stage | 5.89284722
# -RECORD 2-------------------------
#  daily_average_stage | 5.25489583
# only showing top 3 rows

# %%
sara_riverstage_daily_avg.select('daily_average_stage') \
                  .sort('daily_average_stage', ascending=True) \
                  .show(3, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------
#  daily_average_stage | 0.2159375
# -RECORD 1-------------------------
#  daily_average_stage | 0.21989583
# -RECORD 2-------------------------
#  daily_average_stage | 0.22291228
# only showing top 3 rows

# %%
spark.stop()
