# %% [markdown]
# # ENVIRONMENT

# %%
import os
import acquire
import pandas as pd

# data visualization 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import statsmodels.api as sm

from datetime import timedelta, datetime
from pylab import rcParams

# %% [markdown]
# # ACQUIRE

# %% [markdown]
# _Let's read in the data from the csv file and take a peek at te first five records._

# %%
df = acquire.read_data('saws-ssos.csv')

# %%
df.head()
# Out:
#    SSO_ID   INSPKEY  SERVNO REPORTDATE  SPILL_ADDRESS     SPILL_ST_NAME  \
# 0    6582  567722.0     NaN    3/10/19           3200  THOUSAND OAKS DR
# 1    6583  567723.0     NaN    3/10/19           6804       S FLORES ST
# 2    6581  567714.0     NaN     3/9/19            215   AUDREY ALENE DR
# 3    6584  567713.0     NaN     3/9/19           3602    SE MILITARY DR
# 4    6580  567432.0     NaN     3/6/19            100          PANSY LN
#
#    TOTAL_GAL  GALSRET     GAL           SPILL_START  ...  Root_Cause  \
# 0       2100   2100.0  2100.0  3/10/2019 1:16:00 PM  ...         NaN
# 1         80      0.0    80.0  3/10/2019 2:25:00 PM  ...         NaN
# 2         79      0.0    10.0   3/9/2019 6:00:00 PM  ...         NaN
# 3         83      0.0    83.0   3/9/2019 3:37:00 PM  ...         NaN
# 4         75      0.0    75.0   3/6/2019 9:40:00 AM  ...         NaN
#
#    STEPS_TO_PREVENT     SPILL_START_2      SPILL_STOP_2 HRS_2 GAL_2  \
# 0               NaN               NaN               NaN  0.00   0.0
# 1               NaN               NaN               NaN  0.00   0.0
# 2               NaN  03/10/2019 09:36  03/10/2019 10:45  1.15  69.0
# 3               NaN               NaN               NaN  0.00   0.0
# 4               NaN               NaN               NaN  0.00   0.0
#
#   SPILL_START_3 SPILL_STOP_3 HRS_3 GAL_3
# 0           NaN          NaN   0.0   0.0
# 1           NaN          NaN   0.0   0.0
# 2           NaN          NaN   0.0   0.0
# 3           NaN          NaN   0.0   0.0
# 4           NaN          NaN   0.0   0.0
#
# [5 rows x 57 columns]

# %% [markdown]
# # PREPARE

# %%
def missing_values_col(df):
    """
    This functions returns the total missing values and
    the percent missing values by column.
    """
    null_count = df.isnull().sum()
    null_percentage = (null_count / df.shape[0]) * 100
    empty_count = pd.Series(((df == ' ') | (df == '')).sum())
    empty_percentage = (empty_count / df.shape[0]) * 100
    nan_count = pd.Series(((df == 'nan') | (df == 'NaN')).sum())
    nan_percentage = (nan_count / df.shape[0]) * 100
    return pd.DataFrame({'num_missing': null_count, 'missing_percentage': null_percentage,
                         'num_empty': empty_count, 'empty_percentage': empty_percentage,
                         'nan_count': nan_count, 'nan_percentage': nan_percentage})


def missing_values_row(df):
    """
    This functions returns the total missing values and
    the percent missing values by row.
    """
    null_count = df.isnull().sum(axis=1)
    null_percentage = (null_count / df.shape[1]) * 100
    return pd.DataFrame({'num_missing': null_count, 'percentage': null_percentage})


def handle_missing_threshold(df, prop_required_column = .3, prop_required_row = .9):
    """
    This functions removes columns and rows whose
    count of missing values exceeds threshold.
    """
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    return df


def count_values(df):
    """
    This function counts the value of columns in a dataframe.
    """
    for col in df.columns:
        n = df[col].unique().shape[0]
        col_bins = min(n, 10)
        print(f"{col}:")
        if df[col].dtype in ['int64', 'float64'] and n > 10:
            print(df[col].value_counts(bins=col_bins, sort=False))
        else:
            print(df[col].value_counts())
        print("\n")

def remove_columns(df, columns):
    return df.drop(columns=columns)

def fill_with_zeroes(df, *cols):
    """
    This functions returns the column names as input and
    return the dataframe with the
    null values in those columns replace by 0.
    """
    for col in cols:
        df[col] = df[col].fillna(0)
    return df


def fill_with_median(df, *cols):
    """
    This function fills the NaN values with
    respective median values.
    """
    for col in cols:
        df[col] = df[col].fillna(df[col].median())
    return df


def fill_with_none(df, *cols):
    """
    This function fills the NaN values with
    'None' string value.
    """
    for col in cols:
        df[col] = df[col].fillna('None')
    return df

def fill_with_unknown(df, *cols):
    """
    This functions fills the NaN values with
    'Unknown' string value.
    """
    for col in cols:
        df[col] = df[col].fillna('Unknown')
    return df

# %% [markdown]
# _Let's convert the column to lowercase to make them easier to work with._

# %%
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#    sso_id   inspkey  servno reportdate  spill_address     spill_st_name  \
# 0    6582  567722.0     NaN    3/10/19           3200  THOUSAND OAKS DR
# 1    6583  567723.0     NaN    3/10/19           6804       S FLORES ST
# 2    6581  567714.0     NaN     3/9/19            215   AUDREY ALENE DR
# 3    6584  567713.0     NaN     3/9/19           3602    SE MILITARY DR
# 4    6580  567432.0     NaN     3/6/19            100          PANSY LN
#
#    total_gal  galsret     gal           spill_start  ...  root_cause  \
# 0       2100   2100.0  2100.0  3/10/2019 1:16:00 PM  ...         NaN
# 1         80      0.0    80.0  3/10/2019 2:25:00 PM  ...         NaN
# 2         79      0.0    10.0   3/9/2019 6:00:00 PM  ...         NaN
# 3         83      0.0    83.0   3/9/2019 3:37:00 PM  ...         NaN
# 4         75      0.0    75.0   3/6/2019 9:40:00 AM  ...         NaN
#
#    steps_to_prevent     spill_start_2      spill_stop_2 hrs_2 gal_2  \
# 0               NaN               NaN               NaN  0.00   0.0
# 1               NaN               NaN               NaN  0.00   0.0
# 2               NaN  03/10/2019 09:36  03/10/2019 10:45  1.15  69.0
# 3               NaN               NaN               NaN  0.00   0.0
# 4               NaN               NaN               NaN  0.00   0.0
#
#   spill_start_3 spill_stop_3 hrs_3 gal_3
# 0           NaN          NaN   0.0   0.0
# 1           NaN          NaN   0.0   0.0
# 2           NaN          NaN   0.0   0.0
# 3           NaN          NaN   0.0   0.0
# 4           NaN          NaN   0.0   0.0
#
# [5 rows x 57 columns]

# %% [markdown]
# _Let's take a look at the missing values._

# %%
missing_values_col(df)
# Out:
#                     num_missing  missing_percentage  num_empty  \
# sso_id                        0            0.000000          0
# inspkey                     797           25.039271          0
# servno                     2715           85.296890          0
# reportdate                    0            0.000000          0
# spill_address                 0            0.000000          0
# spill_st_name                 0            0.000000          0
# total_gal                     0            0.000000          0
# galsret                     475           14.923029          0
# gal                           0            0.000000          0
# spill_start                   0            0.000000          0
# spill_stop                    0            0.000000          0
# hrs                           3            0.094251          0
# cause                         0            0.000000          0
# comments                    533           16.745209          0
# actions                       8            0.251335          0
# watershed                     0            0.000000          0
# unitid                        4            0.125668          0
# unitid2                     244            7.665724          0
# discharge_to                  4            0.125668          0
# discharge_route             827           25.981778          0
# council_district            322           10.116243          0
# ferguson                     30            0.942507          0
# month                         0            0.000000          0
# year                          0            0.000000          0
# week                          0            0.000000          0
# earz_zone                  1318           41.407477          0
# expr1029                      7            0.219918          0
# pipediam                    190            5.969211          0
# pipelen                     190            5.969211          0
# pipetype                    190            5.969211         47
# instyear                    118            3.707194          0
# dwndpth                    3183          100.000000          0
# upsdpth                    3183          100.000000          0
# inches_no                   487           15.300031          0
# rainfall_less3              542           17.027961          0
# spill address                43            1.350927          0
# sewerassetexp              3026           95.067546          0
# num_spills_compkey            0            0.000000          0
# num_spills_24mos           1677           52.686145          0
# prevspill_24mos            2582           81.118442          0
# unittype                     17            0.534087          9
# assettype                     2            0.062834          0
# lastclnd                   2082           65.409991          0
# responsetime               1934           60.760289          0
# responsedttm               1934           60.760289          0
# public notice                 0            0.000000          0
# timeint                    2393           75.180647          0
# root_cause                    7            0.219918          0
# steps_to_prevent           1737           54.571159          0
# spill_start_2              3097           97.298146          0
# spill_stop_2               3097           97.298146          0
# hrs_2                      1874           58.875275          0
# gal_2                      1873           58.843858          0
# spill_start_3              3169           99.560163          0
# spill_stop_3               3169           99.560163          0
# hrs_3                      1878           59.000943          0
# gal_3                      1878           59.000943          0
#
#                     empty_percentage  nan_count  nan_percentage
# sso_id                      0.000000          0             0.0
# inspkey                     0.000000          0             0.0
# servno                      0.000000          0             0.0
# reportdate                  0.000000          0             0.0
# spill_address               0.000000          0             0.0
# spill_st_name               0.000000          0             0.0
# total_gal                   0.000000          0             0.0
# galsret                     0.000000          0             0.0
# gal                         0.000000          0             0.0
# spill_start                 0.000000          0             0.0
# spill_stop                  0.000000          0             0.0
# hrs                         0.000000          0             0.0
# cause                       0.000000          0             0.0
# comments                    0.000000          0             0.0
# actions                     0.000000          0             0.0
# watershed                   0.000000          0             0.0
# unitid                      0.000000          0             0.0
# unitid2                     0.000000          0             0.0
# discharge_to                0.000000          0             0.0
# discharge_route             0.000000          0             0.0
# council_district            0.000000          0             0.0
# ferguson                    0.000000          0             0.0
# month                       0.000000          0             0.0
# year                        0.000000          0             0.0
# week                        0.000000          0             0.0
# earz_zone                   0.000000          0             0.0
# expr1029                    0.000000          0             0.0
# pipediam                    0.000000          0             0.0
# pipelen                     0.000000          0             0.0
# pipetype                    1.476594          0             0.0
# instyear                    0.000000          0             0.0
# dwndpth                     0.000000          0             0.0
# upsdpth                     0.000000          0             0.0
# inches_no                   0.000000          0             0.0
# rainfall_less3              0.000000          0             0.0
# spill address               0.000000          0             0.0
# sewerassetexp               0.000000          0             0.0
# num_spills_compkey          0.000000          0             0.0
# num_spills_24mos            0.000000          0             0.0
# prevspill_24mos             0.000000          0             0.0
# unittype                    0.282752          0             0.0
# assettype                   0.000000          0             0.0
# lastclnd                    0.000000          0             0.0
# responsetime                0.000000          0             0.0
# responsedttm                0.000000          0             0.0
# public notice               0.000000          0             0.0
# timeint                     0.000000          0             0.0
# root_cause                  0.000000          0             0.0
# steps_to_prevent            0.000000          0             0.0
# spill_start_2               0.000000          0             0.0
# spill_stop_2                0.000000          0             0.0
# hrs_2                       0.000000          0             0.0
# gal_2                       0.000000          0             0.0
# spill_start_3               0.000000          0             0.0
# spill_stop_3                0.000000          0             0.0
# hrs_3                       0.000000          0             0.0
# gal_3                       0.000000          0             0.0

# %% [markdown]
# _Let's look at a few of the rows._

# %%
df.head(7).T
# Out:
#                                                                     0  \
# sso_id                                                           6582
# inspkey                                                        567722
# servno                                                            NaN
# reportdate                                                    3/10/19
# spill_address                                                    3200
# spill_st_name                                        THOUSAND OAKS DR
# total_gal                                                        2100
# galsret                                                          2100
# gal                                                              2100
# spill_start                                      3/10/2019 1:16:00 PM
# spill_stop                                       3/10/2019 2:40:00 PM
# hrs                                                               1.4
# cause                                                          Grease
# comments            Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                  CLEANED MAIN
# watershed                                                SALADO CREEK
# unitid                                                          66918
# unitid2                                                         66917
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                  NaN
# ferguson                                                        172A2
# month                                                               3
# year                                                             2019
# week                                                               11
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                         16.55
# pipetype                                                          PVC
# instyear                                                         1997
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                   3200 THOUSAND OAKS DR
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.45
# responsedttm                                                10-Mar-19
# public notice                                                   False
# timeint                                                            24
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                               1  \
# sso_id                                                     6583
# inspkey                                                  567723
# servno                                                      NaN
# reportdate                                              3/10/19
# spill_address                                              6804
# spill_st_name                                       S FLORES ST
# total_gal                                                    80
# galsret                                                       0
# gal                                                          80
# spill_start                                3/10/2019 2:25:00 PM
# spill_stop                                 3/10/2019 3:45:00 PM
# hrs                                                     1.33333
# cause                                                    Grease
# comments            Spill ContainedArea Cleaned and Disinfected
# actions                                            CLEANED MAIN
# watershed                                              DOS RIOS
# unitid                                                    24250
# unitid2                                                   24193
# discharge_to                                         STORMDRAIN
# discharge_route                                            None
# council_district                                              3
# ferguson                                                  251A3
# month                                                         3
# year                                                       2019
# week                                                         11
# earz_zone                                                     0
# expr1029                                                    NaN
# pipediam                                                      8
# pipelen                                                     157
# pipetype                                                    PVC
# instyear                                                   1988
# dwndpth                                                     NaN
# upsdpth                                                     NaN
# inches_no                                                   NaN
# rainfall_less3                                              NaN
# spill address                                     6804 S FLORES
# sewerassetexp                                               NaN
# num_spills_compkey                                            1
# num_spills_24mos                                              1
# prevspill_24mos                                             NaN
# unittype                                                GRAVITY
# assettype                                            Sewer Main
# lastclnd                                                    NaN
# responsetime                                               1.08
# responsedttm                                          10-Mar-19
# public notice                                             False
# timeint                                                     120
# root_cause                                                  NaN
# steps_to_prevent                                            NaN
# spill_start_2                                               NaN
# spill_stop_2                                                NaN
# hrs_2                                                         0
# gal_2                                                         0
# spill_start_3                                               NaN
# spill_stop_3                                                NaN
# hrs_3                                                         0
# gal_3                                                         0
#
#                                                                     2  \
# sso_id                                                           6581
# inspkey                                                        567714
# servno                                                            NaN
# reportdate                                                     3/9/19
# spill_address                                                     215
# spill_st_name                                         AUDREY ALENE DR
# total_gal                                                          79
# galsret                                                             0
# gal                                                                10
# spill_start                                       3/9/2019 6:00:00 PM
# spill_stop                                        3/9/2019 7:30:00 PM
# hrs                                                               1.5
# cause                                                      Structural
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                    DOS RIOS
# unitid                                                           2822
# unitid2                                                          3351
# discharge_to                                                    ALLEY
# discharge_route                                                  None
# council_district                                                    1
# ferguson                                                        190E4
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                           350
# pipetype                                                           CP
# instyear                                                         1955
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     215 Audrey Alene Dr
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     1.00
# responsedttm                                                09-Mar-19
# public notice                                                   False
# timeint                                                            24
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                        03/10/2019 09:36
# spill_stop_2                                         03/10/2019 10:45
# hrs_2                                                            1.15
# gal_2                                                              69
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     3  \
# sso_id                                                           6584
# inspkey                                                        567713
# servno                                                            NaN
# reportdate                                                     3/9/19
# spill_address                                                    3602
# spill_st_name                                          SE MILITARY DR
# total_gal                                                          83
# galsret                                                             0
# gal                                                                83
# spill_start                                       3/9/2019 3:37:00 PM
# spill_stop                                        3/9/2019 5:00:00 PM
# hrs                                                           1.38333
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                           NaN
# watershed                                                SALADO CREEK
# unitid                                                          92804
# unitid2                                                         92805
# discharge_to                                                 EASEMENT
# discharge_route                                                  None
# council_district                                                    3
# ferguson                                                        252C3
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                        213.91
# pipetype                                                          PVC
# instyear                                                         1983
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     3602 SE MILITARY DR
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.55
# responsedttm                                                09-Mar-19
# public notice                                                   False
# timeint                                                           120
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     4  \
# sso_id                                                           6580
# inspkey                                                        567432
# servno                                                            NaN
# reportdate                                                     3/6/19
# spill_address                                                     100
# spill_st_name                                                PANSY LN
# total_gal                                                          75
# galsret                                                             0
# gal                                                                75
# spill_start                                       3/6/2019 9:40:00 AM
# spill_stop                                        3/6/2019 9:55:00 AM
# hrs                                                              0.25
# cause                                                      Structural
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                SALADO CREEK
# unitid                                                          61141
# unitid2                                                         49543
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                    2
# ferguson                                                        192A7
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                           12
# pipelen                                                         291.9
# pipetype                                                           CP
# instyear                                                         1952
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                            100 PANSY LN
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  2
# num_spills_24mos                                                    2
# prevspill_24mos                                             15-Dec-18
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.00
# responsedttm                                                06-Mar-19
# public notice                                                   False
# timeint                                                             3
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     5  \
# sso_id                                                           6579
# inspkey                                                        567274
# servno                                                            NaN
# reportdate                                                     3/5/19
# spill_address                                                    3200
# spill_st_name                                          S HACKBERRY ST
# total_gal                                                         250
# galsret                                                             0
# gal                                                               250
# spill_start                                       3/5/2019 2:22:00 PM
# spill_stop                                        3/5/2019 2:32:00 PM
# hrs                                                          0.166667
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                    DOS RIOS
# unitid                                                          38907
# unitid2                                                         26117
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                    3
# ferguson                                                        231C6
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                           315
# pipetype                                                           RL
# instyear                                                         1992
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     3200 S Hackberry St
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  2
# num_spills_24mos                                                    2
# prevspill_24mos                                             11-Apr-17
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.00
# responsedttm                                                05-Mar-19
# public notice                                                   False
# timeint                                                            12
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     6
# sso_id                                                           6577
# inspkey                                                        567046
# servno                                                            NaN
# reportdate                                                     3/2/19
# spill_address                                                    9910
# spill_st_name                                            SUGARLOAF DR
# total_gal                                                          73
# galsret                                                             0
# gal                                                                73
# spill_start                                       3/2/2019 1:42:00 PM
# spill_stop                                        3/2/2019 2:55:00 PM
# hrs                                                           1.21667
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                 MEDIO CREEK
# unitid                                                          85120
# unitid2                                                         85363
# discharge_to                                         DRAINAGE CULVERT
# discharge_route                                                  None
# council_district                                                    4
# ferguson                                                        207A6
# month                                                               3
# year                                                             2019
# week                                                                9
# earz_zone                                                           0
# expr1029                                                       GREASE
# pipediam                                                            8
# pipelen                                                        264.47
# pipetype                                                          PVC
# instyear                                                         1985
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                       9910 Sugarloaf Dr
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.73
# responsedttm                                                02-Mar-19
# public notice                                                   False
# timeint                                                           120
# root_cause                                                     GREASE
# steps_to_prevent                                       Increase FCS,
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0

# %% [markdown]
# _Now let's take a peek into the value counts of the columns._

# %%
count_values(df)
# Out:
# sso_id:
# (-5.5840000000000005, 659.3]    310
# (659.3, 1317.6]                  38
# (1317.6, 1975.9]                326
# (1975.9, 2634.2]                644
# (2634.2, 3292.5]                587
# (3292.5, 3950.8]                464
# (3950.8, 4609.1]                  0
# (4609.1, 5267.4]                  6
# (5267.4, 5925.7]                157
# (5925.7, 6584.0]                651
# Name: sso_id, dtype: int64
#
#
# inspkey:
# (3724.564, 60631.5]     541
# (60631.5, 116975.0]     372
# (116975.0, 173318.5]    392
# (173318.5, 229662.0]    246
# (229662.0, 286005.5]    134
# (286005.5, 342349.0]    174
# (342349.0, 398692.5]    118
# (398692.5, 455036.0]    125
# (455036.0, 511379.5]    151
# (511379.5, 567723.0]    133
# Name: inspkey, dtype: int64
#
#
# servno:
# (274101.378, 515352.1]     18
# (515352.1, 754214.2]       14
# (754214.2, 993076.3]       72
# (993076.3, 1231938.4]      38
# (1231938.4, 1470800.5]    101
# (1470800.5, 1709662.6]     62
# (1709662.6, 1948524.7]     20
# (1948524.7, 2187386.8]     17
# (2187386.8, 2426248.9]     31
# (2426248.9, 2665111.0]     95
# Name: servno, dtype: int64
#
#
# reportdate:
# 5/25/13     27
# 5/19/16     23
# 9/26/16     22
# 6/2/16      20
# 2/3/10      17
# 9/8/10      16
# 12/3/16     15
# 8/7/17      13
# 10/24/15    10
# 3/28/18     10
# 9/7/10       9
# 1/15/10      8
# 5/16/16      8
# 9/9/18       8
# 4/17/10      8
# 5/23/15      8
# 4/25/15      8
# 3/20/12      7
# 2/4/10       7
# 2/20/17      7
# 5/24/15      7
# 5/17/15      7
# 6/14/15      7
# 9/16/18      7
# 6/25/14      7
# 1/16/10      6
# 7/9/18       6
# 4/18/16      6
# 9/22/18      6
# 3/4/10       6
#             ..
# 5/24/13      1
# 12/30/17     1
# 1/23/17      1
# 5/20/11      1
# 1/15/15      1
# 1/16/09      1
# 3/8/10       1
# 4/17/13      1
# 3/28/10      1
# 11/14/12     1
# 11/2/16      1
# 5/10/17      1
# 4/30/15      1
# 3/23/12      1
# 11/26/18     1
# 8/12/10      1
# 12/6/14      1
# 7/14/14      1
# 8/16/09      1
# 10/8/10      1
# 11/28/11     1
# 1/10/10      1
# 10/10/15     1
# 4/7/16       1
# 2/2/09       1
# 11/8/10      1
# 12/31/17     1
# 9/23/11      1
# 10/5/11      1
# 6/14/17      1
# Name: reportdate, Length: 1878, dtype: int64
#
#
# spill_address:
# (-29.622, 2962.1]     1693
# (2962.1, 5924.2]       551
# (5924.2, 8886.3]       476
# (8886.3, 11848.4]      243
# (11848.4, 14810.5]     128
# (14810.5, 17772.6]      31
# (17772.6, 20734.7]      13
# (20734.7, 23696.8]      32
# (23696.8, 26658.9]      12
# (26658.9, 29621.0]       4
# Name: spill_address, dtype: int64
#
#
# spill_st_name:
# HOLBROOK                42
# CAGNON RD               27
# CHAPPIE JAMES WAY       25
# SWISS OAKS              24
# AUSTIN HWY              23
# IH 10 W                 23
# NACOGDOCHES RD          21
# CULEBRA RD              20
# THOUSAND OAKS           20
# DONALDSON AVE           18
# BANDERA RD              17
# ENTRANCE RD NE          17
# HARRY WURZBACH          17
# LOOP 410 NW             17
# PLEASANTON RD           16
# MISSION RD              15
# JONES MALTSBERGER RD    15
# AVONDALE AVE            15
# WURZBACH RD             15
# YOLANDA                 14
# MARBACH RD              14
# FLORES ST S             14
# COMMERCE ST W           13
# PIEDMONT AVE            13
# NEER AVE                13
# US HWY 281 N            12
# BLANCO RD               12
# MILITARY DR W           11
# US HWY 90 W             11
# VANCE JACKSON           11
#                         ..
# CAMINO REAL              1
# SHADY RILL               1
# WALKING GAIT DR          1
# OAKLAWN                  1
# VALLEY HI DRIVE          1
# ESSEX ST                 1
# FREEMAN DR               1
# MORDRED RD               1
# RAINTREE FOREST          1
# FM 1560 N                1
# FAIRS GATE               1
# STORY LN                 1
# SADDLEWOOD               1
# SWITCHGRASS              1
# WYANOKE                  1
# JUNG RD                  1
# SERVICE CENTER DR        1
# ALAMOSA                  1
# BAILEY FOREST            1
# FLINTSTONE CT            1
# TIMBERBRIAR              1
# FORDHAM                  1
# BUFFALO ST               1
# WIND TALKER              1
# BARCLAY                  1
# ELM RDG                  1
# LOOP 1604 W S            1
# BERMAN RD                1
# ROSITA                   1
# MARE COUNTRY             1
# Name: spill_st_name, Length: 1509, dtype: int64
#
#
# total_gal:
# (-13303.550000000001, 1330455.9]    3169
# (1330455.9, 2660910.8]                 9
# (2660910.8, 3991365.7]                 2
# (3991365.7, 5321820.6]                 1
# (5321820.6, 6652275.5]                 1
# (6652275.5, 7982730.4]                 0
# (7982730.4, 9313185.3]                 0
# (9313185.3, 10643640.2]                0
# (10643640.2, 11974095.1]               0
# (11974095.1, 13304550.0]               1
# Name: total_gal, dtype: int64
#
#
# galsret:
# (-2385.1510000000003, 238515.0]    2698
# (238515.0, 477030.0]                  5
# (477030.0, 715545.0]                  3
# (715545.0, 954060.0]                  0
# (954060.0, 1192575.0]                 0
# (1192575.0, 1431090.0]                1
# (1431090.0, 1669605.0]                0
# (1669605.0, 1908120.0]                0
# (1908120.0, 2146635.0]                0
# (2146635.0, 2385150.0]                1
# Name: galsret, dtype: int64
#
#
# gal:
# (-13303.550000000001, 1330455.9]    3175
# (1330455.9, 2660910.8]                 3
# (2660910.8, 3991365.7]                 2
# (3991365.7, 5321820.6]                 1
# (5321820.6, 6652275.5]                 1
# (6652275.5, 7982730.4]                 0
# (7982730.4, 9313185.3]                 0
# (9313185.3, 10643640.2]                0
# (10643640.2, 11974095.1]               0
# (11974095.1, 13304550.0]               1
# Name: gal, dtype: int64
#
#
# spill_start:
# 3/25/2010 9:30:00 AM     2
# 2/25/2010 3:00:00 PM     2
# 5/11/2009 3:00:00 PM     2
# 6/28/2010 11:00:00 AM    2
# 6/2/2016 6:30:00 AM      2
# 5/25/2013 1:00:00 PM     2
# 9/22/2010 1:30:00 PM     2
# 2/3/2010 3:00:00 PM      2
# 5/25/2013 7:00:00 AM     2
# 9/8/2010 6:58:00 AM      2
# 4/17/2010 11:30:00 AM    2
# 4/10/2010 1:00:00 PM     2
# 2/3/2010 10:00:00 AM     2
# 5/19/2016 11:00:00 AM    2
# 5/16/2010 9:00:00 PM     2
# 8/7/2017 9:30:00 AM      2
# 9/10/2018 4:20:00 PM     2
# 6/2/2016 5:15:00 AM      2
# 5/25/2013 12:00:00 PM    2
# 4/29/2010 9:00:00 PM     2
# 2/1/2012 1:30:00 PM      2
# 7/9/2018 3:00:00 PM      2
# 7/17/2009 7:55:00 PM     2
# 7/1/2011 12:30:00 PM     2
# 9/26/2016 8:00:00 AM     2
# 2/20/2009 2:30:00 PM     2
# 8/7/2017 1:30:00 PM      2
# 9/8/2010 11:00:00 AM     2
# 2/13/2011 11:30:00 AM    2
# 9/8/2010 4:00:00 AM      2
#                         ..
# 8/1/2018 7:12:00 AM      1
# 5/19/2016 2:30:00 PM     1
# 10/2/2014 7:07:00 PM     1
# 1/12/2011 2:30:00 PM     1
# 7/2/2015 9:30:00 AM      1
# 5/13/2014 1:25:00 AM     1
# 4/25/2017 4:08:00 PM     1
# 1/23/2009 11:30:00 AM    1
# 1/15/2010 6:00:00 AM     1
# 9/20/2016 6:49:00 PM     1
# 1/29/2017 9:57:00 PM     1
# 2/7/2010 10:30:00 AM     1
# 2/2/2009 9:00:00 AM      1
# 5/24/2017 5:40:00 PM     1
# 6/22/2015 5:42:00 PM     1
# 6/16/2013 6:59:00 PM     1
# 10/24/2015 2:15:00 PM    1
# 2/16/2009 6:15:00 PM     1
# 11/19/2009 7:30:00 AM    1
# 3/3/2009 4:00:00 PM      1
# 1/13/2009 1:00:00 PM     1
# 7/20/2012 3:28:00 PM     1
# 6/27/2011 11:00:00 AM    1
# 7/26/2013 9:31:00 AM     1
# 6/30/2015 1:40:00 PM     1
# 5/28/2014 5:21:00 PM     1
# 7/13/2010 4:00:00 PM     1
# 2/10/2009 10:45:00 AM    1
# 7/26/2012 1:38:00 PM     1
# 2/15/2010 12:30:00 PM    1
# Name: spill_start, Length: 3152, dtype: int64
#
#
# spill_stop:
# 9/26/2016 11:00:00 AM     4
# 5/25/2013 3:30:00 PM      4
# 9/26/2016 3:45:00 PM      3
# 5/24/2015 2:45:00 AM      3
# 9/8/2010 11:30:00 AM      3
# 1/27/2010 11:00:00 AM     2
# 9/26/2016 5:00:00 PM      2
# 1/24/2011 5:00:00 PM      2
# 7/30/2009 3:30:00 PM      2
# 1/26/2010 10:00:00 PM     2
# 6/6/2010 8:00:00 PM       2
# 9/8/2010 5:30:00 AM       2
# 5/19/2016 3:15:00 PM      2
# 12/4/2016 12:01:00 AM     2
# 2/20/2017 8:30:00 AM      2
# 9/26/2016 1:00:00 PM      2
# 5/25/2013 12:30:00 PM     2
# 3/21/2012 11:15:00 AM     2
# 1/16/2010 1:00:00 PM      2
# 4/24/2015 4:00:00 PM      2
# 4/22/2016 11:00:00 PM     2
# 12/1/2010 10:30:00 PM     2
# 10/30/2011 1:45:00 PM     2
# 9/26/2016 10:30:00 AM     2
# 2/14/2011 1:30:00 PM      2
# 7/11/2012 12:15:00 PM     2
# 5/11/2016 8:00:00 AM      2
# 1/13/2011 9:00:00 AM      2
# 10/25/2011 11:00:00 AM    2
# 5/26/2010 10:00:00 PM     2
#                          ..
# 4/4/2009 1:15:00 PM       1
# 1/15/2010 5:15:00 PM      1
# 3/25/2009 3:00:00 PM      1
# 1/25/2012 2:18:00 PM      1
# 4/20/2012 10:00:00 AM     1
# 6/21/2016 9:35:00 PM      1
# 5/16/2014 9:30:00 PM      1
# 3/7/2018 1:00:00 PM       1
# 8/8/2017 8:10:00 AM       1
# 3/27/2017 12:15:00 PM     1
# 4/7/2009 9:30:00 PM       1
# 1/11/2012 5:30:00 PM      1
# 6/14/2010 2:30:00 PM      1
# 9/9/2018 10:50:00 AM      1
# 1/6/2011 1:45:00 PM       1
# 8/27/2012 9:00:00 AM      1
# 7/26/2011 9:30:00 PM      1
# 9/20/2016 11:16:00 AM     1
# 8/14/2018 5:00:00 PM      1
# 3/11/2011 10:00:00 AM     1
# 1/19/2010 4:00:00 PM      1
# 1/21/2014 6:18:00 PM      1
# 5/12/2010 9:00:00 PM      1
# 2/4/2019 9:30:00 PM       1
# 4/16/2011 8:00:00 PM      1
# 12/3/2016 9:30:00 PM      1
# 9/16/2010 3:30:00 PM      1
# 1/22/2011 7:30:00 PM      1
# 11/6/2013 6:00:00 PM      1
# 2/15/2010 12:30:00 PM     1
# Name: spill_stop, Length: 3133, dtype: int64
#
#
# hrs:
# (-1.797, 179.6]     3176
# (179.6, 359.2]         1
# (359.2, 538.8]         0
# (538.8, 718.4]         1
# (718.4, 898.0]         1
# (898.0, 1077.6]        0
# (1077.6, 1257.2]       0
# (1257.2, 1436.8]       0
# (1436.8, 1616.4]       0
# (1616.4, 1796.0]       1
# Name: hrs, dtype: int64
#
#
# cause:
# Grease                                                  956
# Debris                                                  479
# I/I                                                     465
# Debris/Rock                                             254
# Structural                                              244
# Rags                                                    236
# Break In Main                                           164
# Contractor                                               91
# Break in Main                                            68
# Lift Station                                             42
# Vandalism                                                38
# Lift Station Power Out                                   29
# Other                                                    29
# Roots                                                    28
# Lift Station Pump Out                                    21
# Equipment Failure                                         5
# Other - Capacity                                          5
# Plug In Main                                              4
# Break In By-Pass Line                                     3
# By-pass Pump Failure                                      3
# Human Error                                               2
# By-Pass Equip Failure                                     2
# Other - Cleanout Cap Broken By Vehicular Traffic          1
# Contractor - Contractor Damaged 8 inch Force Main         1
# Broken ARV                                                1
# By-Pass Pump Failure                                      1
# Other - Cause To Be Determined                            1
# Other - Obstruction In Main                               1
# Under Investigation                                       1
# Structural - Broken Force Main                            1
# Other - Mechanical                                        1
# Other - Gate Valve                                        1
# Lateral Repair                                            1
# Lift Station - Due To Power Failure And I/I               1
# Structural - Spilled From Broken Lateral                  1
# Other - Spill Was Caused By A Surcharging Sewer Main      1
# Protruding Lateral                                        1
# Name: cause, dtype: int64
#
#
# comments:
#  APPLIED  HTH                                                                                                          518
# APPLIED HTH                                                                                                            513
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                                      391
# Area cleaned and disinfected                                                                                           112
# Spill ContainedReturned to SystemArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                    106
# CLEANED MAIN                                                                                                            84
# REPAIRED MAIN - HTH                                                                                                     80
#  APPLIED  HTH, REPAIRED MAIN                                                                                            64
# Spill ContainedArea Cleaned and Disinfected                                                                             54
# Area Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                                                      49
# AREA CLEANED AND DISINFECTED                                                                                            49
# Area Cleaned and Disinfected                                                                                            46
# REPAIRED MAIN                                                                                                           28
# Spill ContainedReturned to SystemArea Cleaned and Disinfected                                                           24
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O,                                                       22
# MONITORED AREA - HTH                                                                                                    21
# Spill Contained                                                                                                         21
# MONITORED AREA                                                                                                          20
# CLEANED AREA                                                                                                            19
# Spill ContainedReturned to System                                                                                       13
#  AREA CLEANED AND DISINFECTED                                                                                           11
# Diluted by heavy rain water                                                                                             10
# Spill ContainedFlushed Area with H2O, Unstopped Main,                                                                    8
# SPILL CONTAINED                                                                                                          6
# Spill ContainedReturned to SystemArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main, Unstopped Main,       6
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main, Unstopped Main,                         6
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main,                                         5
#  AREA CLEANED AND DISINFECTED, REPAIRED MAIN                                                                             4
# DILUTED BY HEAVY RAIN WATER                                                                                              4
# APPLIED  HTH                                                                                                             4
#                                                                                                                       ...
# MONITORED AREA - HTH LS 192                                                                                              1
# RESTORED POWER TO L/S 209 - HTH                                                                                          1
# Motor was removed and a second pump was installed. L/S # 121                                                             1
# RESTORED POWER TO L/S 199 - HTH                                                                                          1
# Spill Contained, Area Cleaned and Disinfected, Flushed Area with H2O,                                                    1
# REPAIRED MAIN/APPLIED HTH                                                                                                1
# RE-DIRECTED BY-PASS TUBING                                                                                               1
# CPS RESTORED POWER TO L/S 205                                                                                            1
# PUT A BY-PASS PUMP - REPAIRED MAIN                                                                                       1
# Replaced Pump #6. L/S# 11 - Area Cleaned and Disinfected                                                                 1
# 2nd start Time:6/6/12 7:15 to 6/6/12 15:45-Spilled into Huebner Crk - Large rocks                                        1
# REVISED BY-PASS PUMP PROCEDURES                                                                                          1
# REPLACE PIPE                                                                                                             1
# APPLIED HTH AND REPAIRED MAIN                                                                                            1
#  APPLIED  HTH-BUILT DAM                                                                                                  1
# REPAIRED PIPE ON HEADER AT L/S #187                                                                                      1
# REPAIRED LATERAL                                                                                                         1
# HTH - REPLACED 22' OF 15' PIPE                                                                                           1
# Repaired main, 10" sewer main                                                                                            1
# Lift station 192 overflow due to heavy rain                                                                              1
# Area Cleaned and Disinfected/Repaired main                                                                               1
# REPLACED TRANSFORMER AT L/S 187                                                                                          1
# AREA CLEANED                                                                                                             1
# PUMP MALFUNCTIONED AT @ LIFT STATION # 200                                                                               1
# Spill ContainedReturned to SystemArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main                       1
# Area Cleaned and Disinfected/ Lateral to be replaced.                                                                    1
# RESTORED POWER L/S #201 HTH                                                                                              1
# REPLACED PUMPS AT LS 188                                                                                                 1
# FIXED ELECTRICAL CONNECTION LS 201                                                                                       1
# SPILL CAUSED BY BROKEN SEWER LATERAL                                                                                     1
# Name: comments, Length: 331, dtype: int64
#
#
# actions:
# CLEANED MAIN                                                                                  1927
# REPAIRED MAIN                                                                                  307
# DILUTED BY HEAVY RAIN WATER                                                                    116
# MONITORED AREA                                                                                  93
# APPLIED HTH                                                                                     71
# DILUTED BY HEAVY RAINWATER                                                                      66
# CLEANED AREA                                                                                    52
# REPAIRED LATERAL                                                                                41
# CLEANED LATERAL                                                                                 37
# RESTORED POWER                                                                                  32
# DILUTED BY RAIN WATER                                                                           30
# REPAIRED PUMP                                                                                   27
# Diluted By Heavy Rainwater                                                                      24
# Cleaned Main                                                                                    24
# REPAIRED FORCE MAIN                                                                             23
# Diluted By Heavy Rain Water                                                                     19
# Diluted by Heavy Rainwater                                                                      15
# UNSTOPPED MAIN                                                                                  13
# SET BARRICADES                                                                                  12
# REPAIRED BROKEN MAIN                                                                            11
# REPAIRED HYDRORANGER                                                                            10
# DILUTED BY HEAVY RAINFALL                                                                        9
# REPAIRED A/R VALVE                                                                               8
#  CLEANED MAIN                                                                                    7
# WORK ORDER TO REPAIR MAIN                                                                        7
# Diluted by Heavy Rain Water                                                                      7
# DILUTED WITH RAIN WATER                                                                          7
# REPAIRED COLLAPSED MAIN                                                                          6
# REPAIRED BY-PASS LINE                                                                            6
# Cleaned Area                                                                                     5
#                                                                                               ...
# DILUTED BY RAINWATER                                                                             1
#  DILUTED BY HEAVY RAIN WATER                                                                     1
# Unstopped Lateral                                                                                1
# REPAIRED PUMP ON BY PASS                                                                         1
# Lift Station Pump Failure L/S 199 - Repaired Pumps                                               1
# WILL REPLACE LATERAL                                                                             1
# Replaced Broken Discharge Pipe on Gravity Line                                                   1
# Cleanup In Progress                                                                              1
# REPAIRED BY PASS MAIN                                                                            1
# REPLACE TWIN 54" SIPHONS                                                                         1
# REPLACED DEFECTIVE ARV                                                                           1
# FLUSHED AREA                                                                                     1
# REPAIRED FORCE MAIN- LIFT STATION #252                                                           1
# APPLIED HTH - 200 GAL INTO OLMOS CRK                                                             1
# INSTALLED CLAMP ON FORCE MAIN                                                                    1
# MONITORED PUMPS                                                                                  1
# Lift Station Honeywagon removed several loads from the wet well                                  1
# CONNECTED CNTRL SWITCH@LIFT STATION                                                              1
# AREA CLEANED AND DISIINFECTED                                                                    1
# CLEANUP IS ONGOING                                                                               1
# REPLACED PLUG ON BY PASS                                                                         1
# Cleanup is on-going and fresh soil is being placed to bring the area back to natural grade       1
# CPS RESTORED POWER                                                                               1
# Honeywagon Pumped and Hauled Until Flow Receded                                                  1
# The Area Will Be Cleaned And Disinfected After The Flood Waters Recede                           1
#  Diluted By Heavy Rainwater                                                                      1
# RESET BYPASS PUMP                                                                                1
# Diluted by Fresh Water From Water Main Break                                                     1
# REPAIRED BROKEN FORCE MAIN                                                                       1
# MONITORED LIFT STATION                                                                           1
# Name: actions, Length: 148, dtype: int64
#
#
# watershed:
# DOS RIOS             1572
# SALADO CREEK          790
# LEON CREEK            668
# MEDIO CREEK           146
# CCMA (Subscriber)       4
# Dos Rios                1
# Salado Creek            1
# Leon Creek              1
# Name: watershed, dtype: int64
#
#
# unitid:
# 52470     15
# LS200     14
# 1187      13
# 903059    12
# LS199     12
# 47822     10
# LS188     10
# 62085     10
# 1210      10
# 903060    10
# LS201      8
# 424896     8
# 29988      8
# 11989      8
# 499638     7
# 14942      7
# LS011      7
# 31744      7
# 1465       7
# 46546      7
# LS191      7
# LS192      7
# LS225      7
# 48128      6
# 31088      6
# 79943      6
# 9566       6
# 70014      6
# 47312      6
# 47427      6
#           ..
# 965057     1
# 4141       1
# 31851      1
# 48426      1
# 32797      1
# 50606      1
# 13029      1
# 6778       1
# 28250      1
# 24150      1
# 9986       1
# 87840      1
# 97711      1
# 51452      1
# 3795       1
# 985995     1
# 47324      1
# 8472       1
# 69700      1
# 2292       1
# 71071      1
# 465834     1
# 71217      1
# 947677     1
# 2967       1
# 5370       1
# 100348     1
# 20304      1
# 92671      1
# 34340      1
# Name: unitid, Length: 2399, dtype: int64
#
#
# unitid2:
# 52677     13
# 1074      13
# 71380     12
# 903059    10
# 46546      9
# 922726     9
# 62088      9
# 499663     8
# 16276      8
# 424898     8
# 79942      8
# 1464       7
# 47428      7
# 13724      7
# 69866      6
# 46257      6
# 8715       6
# 27616      6
# 48236      6
# 50379      6
# 14332      6
# 42319      6
# 48516      6
# 47824      5
# 34495      5
# 0          5
# 47427      5
# 59375      5
# 15795      5
# 64405      5
#           ..
# 24102      1
# 52679      1
# 917322     1
# 1210       1
# 3397       1
# 42303      1
# 418588     1
# 1939       1
# 2251       1
# 25780      1
# 23129      1
# 52963      1
# 52402      1
# 90323      1
# 30942      1
# 14849      1
# 16678      1
# 89476      1
# 480890     1
# 18312      1
# 53123      1
# 931131     1
# 84234      1
# 505018     1
# 72217      1
# 33536      1
# 83153      1
# 85793      1
# 85596      1
# 81871      1
# Name: unitid2, Length: 2247, dtype: int64
#
#
# discharge_to:
# STREET                                                                                         805
# DRAINAGE CULVERT                                                                               564
# GROUND                                                                                         536
# STORMDRAIN                                                                                     433
# CREEK BED                                                                                      240
# ALLEY                                                                                          177
# EASEMENT                                                                                        71
# CREEK BED - Spilled Into Leon Creek                                                             50
# CREEK BED - Spilled Into Salado Creek                                                           31
# CREEK BED - SPILLED INTO SALADO CREEK                                                           15
# CREEK BED - Spilled into Salado Creek                                                           12
# DRAINAGE CULVERT - Over The Edwards Aquifer Transition Zone                                      9
# GROUND - Over The Edwards Aquifer Recharge Zone                                                  9
# CREEK BED - Spilled into Leon Creek                                                              6
# CREEK BED ( Spilled into Salado Creek )                                                          6
# DRAINAGE CULVERT - Over The Edwards Aquifer Recharge Zone                                        6
# CREEK BED - Spilled Into Alazan Creek                                                            5
# CREEK BED - SPILLED INTO LEON CREEK                                                              5
# CREEK BED-SALADO CRK                                                                             4
# CREEK BED ( Spilled Into Salado Creek )                                                          4
# CREEK BED  ( Spilled into Salado Creek )                                                         4
# CREEK BED - Spilled Into Indian Creek                                                            4
# CREEK BED - Spilled Into Leon Creek - Over The Edwards Aquifer Contributing Zone                 4
# CREEK BED - Spilled Into San Pedro Creek                                                         3
# GROUND - Over The Edwards Aquifer Transition Zone                                                3
# STORMDRAIN - Over The Edwards Aquifer Transition Zone                                            3
# GROUND - Over The Edwards Aquifer Contributing Zone                                              3
# CREEK BED  ( Spilled into Alazan Creek )                                                         3
# STREET - Over The Edwards Aquifer Recharge Zone                                                  3
# STORMDRAIN - Over The Edwards Aquifer Contributing Zone                                          3
#                                                                                               ...
# STREET - Spilled Into Woodlawn Lake                                                              1
# STREET - Discharge Route To Nearby Pond                                                          1
# CREEK BED - ROSSILLO CREEK                                                                       1
# CREEK BED - Spilled Into San Antonio River                                                       1
# CREEK BED ( SPILLED INO LEON CREEK )                                                             1
# GROUND - Over The EARZ                                                                           1
# DRAINAGE CULVERT - Spilled Into Walzem Creek                                                     1
# CREEK BED-BEITEL CRK                                                                             1
# CREEK BED - INDIAN CREEK                                                                         1
# STREET-ZARZAMORA CRK                                                                             1
# CREEK BED - Spilled Into Olmos Creek - Over The Edwards Aquifer Transition Zone                  1
# CREEK BED ( Spilled into Zarzamora Creek )                                                       1
# DRAINAGE CULVERT - SPILLED INTO A POND VIA CULVERT                                               1
# DRAINAGE CULVERT ( OVER EDWARDS AQUIFER RECHARGE ZONE )                                          1
# DRAINAGE CULVERT -  Over The Edwards Aquifer Transition Zone                                     1
# CREEK BED - ( Spilled into Salado Creek )                                                        1
# CREEK BED - Spilled Into Mudd Creek                                                              1
# CREEK BED ( Spilled into Indian Creek)                                                           1
# STORMDRAIN - Spilled Into San Antonio River Via A Stormdrain                                     1
# CREEK BED -  Spilled Into Panthers Springs Creek - Over The Edwards Aquifer Transition Zone      1
# DRY VAULT- Over The Edwards Aquifer Recharge Zone                                                1
# GROUND (Spilled Over Edwards Aquifer Transition Zone )                                           1
# DRAINAGE CULVERT ( OVER EDWARDS AQUIFER CONTRIBUTING ZONE )                                      1
# CREEK BED ( SPILLED INTO OLMOS CREEK )                                                           1
# CREEK BED ( Spilled into Dry Mudd Creek )                                                        1
# CREEK BED - INDIAN CRK                                                                           1
# DRAINAGE CULVERT - Over The Edwards Aquifer Contributing Zone Within The Transition Zone         1
# CREEK BED ( SPILLED INTO LEON CREEK )                                                            1
# DRAINAGE CULVERT - Spilled Into Huebner Creek                                                    1
# GROUND - SPILLED INTO ALAZAN CREEK                                                               1
# Name: discharge_to, Length: 171, dtype: int64
#
#
# discharge_route:
# None                         1527
# NONE                          406
# SALADO CREEK                  117
# LEON CREEK                     94
# ALAZAN CREEK                   31
# ZARZAMORA CREEK                21
# SAN ANTONIO RIVER              20
# INDIAN CREEK                   18
# HUEBNER CREEK                  11
# MUDD CREEK                     10
# ROSILLO CREEK                  10
# OLMOS CREEK                     9
# MARTINEZ CREEK                  8
# SAN PEDRO CREEK                 7
# WALZEM CREEK                    7
# WOODLAWN LAKE                   6
# DRAINAGE CREEK                  6
# APACHE CREEK                    5
# HARLANDALE CREEK                5
# BEITEL CREEK                    5
# SIX MILE CREEK                  5
# ELM CREEK                       4
# MEDIO CREEK                     2
# CULEBRA CREEK                   2
# RITTIMAN CREEK                  2
# PANTHER SPRINGS CREEK           2
# POTRANCO CREEK                  2
# LORENCE CREEK                   2
# SELMA CREEK                     2
# SALADO CREEK-SALADO CREEK       1
# WEST ELM CREEK                  1
# SALADO CREEK TRIBUTARY          1
# EL DORADO LAKE                  1
# ELMENDORF LAKE                  1
# MEDINA RIVER                    1
# ELM WATERHOLE CREEK             1
# COMANCHE CREEK                  1
# MAYBERRY CREEK                  1
# MILLERS POND                    1
# Name: discharge_route, dtype: int64
#
#
# council_district:
# (-0.011, 1.0]    477
# (1.0, 2.0]       335
# (2.0, 3.0]       329
# (3.0, 4.0]       273
# (4.0, 5.0]       214
# (5.0, 6.0]       210
# (6.0, 7.0]       287
# (7.0, 8.0]       223
# (8.0, 9.0]       232
# (9.0, 10.0]      281
# Name: council_district, dtype: int64
#
#
# ferguson:
# 208B8    22
# 651B4    19
# 192C4    19
# 581C7    18
# 615D2    17
# 210A5    16
# 171E6    16
# 192D7    15
# 582D8    15
# 616A2    15
# 209D2    14
# 582B5    14
# 228D6    12
# 228E6    12
# 192E7    12
# 582B6    12
# 646B5    12
# 209A5    12
# 248C3    12
# 192A8    12
# 651B5    12
# 231E8    11
# 584D3    11
# 583E6    11
# 581F4    11
# 171B5    10
# 171E5    10
# 210B5    10
# 231C7    10
# 227D7     9
#          ..
# 612F8     1
# 584E5     1
# 614F3     1
# 208A8     1
# 186E1     1
# 207C8     1
# 549A6     1
# 583E4     1
# 251E4     1
# 171B6     1
# 516C7     1
# 248A1     1
# 479F3     1
# 479F5     1
# 518A6     1
# 583B1     1
# 230B6     1
# 192E1     1
# 651C7     1
# 169F2     1
# 519C4     1
# 210E7     1
# 252D1     1
# 151B4     1
# 515D3     1
# 148E8     1
# 210C8     1
# 245E2     1
# 683F3     1
# 187D7     1
# Name: ferguson, Length: 1400, dtype: int64
#
#
# month:
# (0.988, 2.1]    683
# (2.1, 3.2]      253
# (3.2, 4.3]      240
# (4.3, 5.4]      333
# (5.4, 6.5]      245
# (6.5, 7.6]      159
# (7.6, 8.7]      209
# (8.7, 9.8]      305
# (9.8, 10.9]     264
# (10.9, 12.0]    492
# Name: month, dtype: int64
#
#
# year:
# (2008.989, 2010.0]    921
# (2010.0, 2011.0]      354
# (2011.0, 2012.0]      374
# (2012.0, 2013.0]      282
# (2013.0, 2014.0]      196
# (2014.0, 2015.0]      263
# (2015.0, 2016.0]      304
# (2016.0, 2017.0]      193
# (2017.0, 2018.0]      259
# (2018.0, 2019.0]       37
# Name: year, dtype: int64
#
#
# week:
# (0.947, 6.2]    459
# (6.2, 11.4]     333
# (11.4, 16.6]    276
# (16.6, 21.8]    365
# (21.8, 27.0]    344
# (27.0, 32.2]    204
# (32.2, 37.4]    274
# (37.4, 42.6]    311
# (42.6, 47.8]    279
# (47.8, 53.0]    338
# Name: week, dtype: int64
#
#
# earz_zone:
# 0.0    1747
# 5.0      67
# 1.0      16
# 3.0      16
# 4.0      12
# 2.0       7
# Name: earz_zone, dtype: int64
#
#
# expr1029:
# STRUCTURAL           1237
# GREASE                610
# DEBRIS                443
# RAIN EVENT            353
# CONTRACTOR            164
# LIFT STATION          125
# OTHER                  61
# RAIN EVENT             48
# VANDALISM              48
# VANDALISM              24
# ROOTS                  22
# LIFT STATION           15
# I/I                    12
# CONTRACTOR              8
# BY PASS PUMP LEAK       3
# OTHER                   1
# Grease                  1
# Debris                  1
# Name: expr1029, dtype: int64
#
#
# pipediam:
# (-0.067, 6.6]     187
# (6.6, 13.2]      2411
# (13.2, 19.8]      115
# (19.8, 26.4]       78
# (26.4, 33.0]       26
# (33.0, 39.6]       24
# (39.6, 46.2]       36
# (46.2, 52.8]       53
# (52.8, 59.4]       45
# (59.4, 66.0]       18
# Name: pipediam, dtype: int64
#
#
# pipelen:
# (-11.69, 1168.935]       2944
# (1168.935, 2337.87]        31
# (2337.87, 3506.805]         8
# (3506.805, 4675.74]         5
# (4675.74, 5844.675]         1
# (5844.675, 7013.61]         1
# (7013.61, 8182.545]         0
# (8182.545, 9351.48]         1
# (9351.48, 10520.415]        0
# (10520.415, 11689.35]       2
# Name: pipelen, dtype: int64
#
#
# pipetype:
# PVC         968
# VCP         908
# CT          280
# HDPE        215
# CP          191
# RCP         162
# CAS          68
# DIP          63
#              47
# RL           35
# FRP          26
# CSC          14
# XXX           7
# AC            5
# SMARTLID      2
# PICK BAR      1
# BR            1
# Name: pipetype, dtype: int64
#
#
# instyear:
# (1890.8990000000001, 2709.0]    3049
# (2709.0, 3519.0]                   0
# (3519.0, 4329.0]                   0
# (4329.0, 5139.0]                   0
# (5139.0, 5949.0]                   0
# (5949.0, 6759.0]                   0
# (6759.0, 7569.0]                   0
# (7569.0, 8379.0]                   0
# (8379.0, 9189.0]                   0
# (9189.0, 9999.0]                  16
# Name: instyear, dtype: int64
#
#
# dwndpth:
# Series([], Name: dwndpth, dtype: int64)
#
#
# upsdpth:
# Series([], Name: upsdpth, dtype: int64)
#
#
# inches_no:
# (-0.010870000000000001, 0.987]    2301
# (0.987, 1.974]                     149
# (1.974, 2.961]                     128
# (2.961, 3.948]                      58
# (3.948, 4.935]                      32
# (4.935, 5.922]                       0
# (5.922, 6.909]                       1
# (6.909, 7.896]                       0
# (7.896, 8.883]                       0
# (8.883, 9.87]                       27
# Name: inches_no, dtype: int64
#
#
# rainfall_less3:
# (-0.0133, 1.227]    2232
# (1.227, 2.454]       247
# (2.454, 3.681]       106
# (3.681, 4.908]        33
# (4.908, 6.135]        11
# (6.135, 7.362]         5
# (7.362, 8.589]         0
# (8.589, 9.816]         0
# (9.816, 11.043]        2
# (11.043, 12.27]        5
# Name: rainfall_less3, dtype: int64
#
#
# spill address:
# SWISS OAKS 06606                                                  19
# CHAPPIE JAMES WAY 00108                                           15
# HOLBROOK 00668                                                    10
# HARRY WURZBACH 01427                                               9
# MOREY RD 05410                                                     8
# THOUSAND OAKS 03947                                                7
# CHAPPIE JAMES WAY 00100                                            7
# STARCREST DR 114/1                                                 7
# CAGNON RD 055/1                                                    7
# YOLANDA 00111                                                      7
# CAGNON RD 06785                                                    7
# NEW VALLEY HI DR 00874                                             6
# US HWY 90 W 10102                                                  6
# HOLBROOK 00700                                                     6
# IRA LEE RD 00302                                                   6
# AVONDALE AVE 00755                                                 5
# CULEBRA RD 02627                                                   5
# POTRANCO RD 09765                                                  5
# CAGNON RD 067/1                                                    5
# KIM VALLEY DR 05802                                                5
# FIVE IRON 11335                                                    5
# MARTINEZ LOSOYA 01612                                              5
# CENTO DR 00642                                                     5
# CAGNON RD 06305                                                    5
# QUINTANA RD 07703                                                  5
# ENTRANCE RD NE 10800                                               4
# ROSE VALLEY 06102                                                  4
# MANOR DR 00908                                                     4
# NEW VALLEY HI DR 008/1                                             4
# YOLANDA 00107                                                      4
#                                                                   ..
# 7402 Stampede                                                      1
# 7136 TOURANT RD                                                    1
# 10419 Old Prue Rd. - Over The Edwards Aquifer Transition Zone      1
# 100 Quill Dr E                                                     1
# 5818 Lubbers Way                                                   1
# 5247 Village Row                                                   1
# 114 Eureka Dr                                                      1
# 702 MASON ST                                                       1
# the front of 1603 Santa Barbara                                    1
# 7902 Dueling Oaks                                                  1
# 15000 country morning                                              1
# 11330 EXPO BLVD (OVER THE EDWARDS AQUIFER TRANSITION ZONE)         1
# 603 Oblate                                                         1
# BEAR SPRINGS DR 03014                                              1
# 327 Sandalwood                                                     1
# 82 Griggs Ave                                                      1
# 300 CATALINA                                                       1
# 21700 ANGOSTURA BLVD                                               1
# 2428 Clower St                                                     1
# 1602 basse rd.                                                     1
# 7019 John Marshall                                                 1
# 3487 Fredericksburg Rd                                             1
# 5631 BABCOCK RD                                                    1
# DONALDSON AVE 01602                                                1
# 1100 W. CRAIG PLACE                                                1
# 3603 BOB BILLA                                                     1
# 3200 Woodclife Dr-Edwards Aquifer Transition Zone                  1
# 16100 U S HWY 281 N ( Over the Edwards Aquifer Recharge Zone )     1
# 1106 VANCE JACKSON                                                 1
# 3200 S Hackberry St                                                1
# Name: spill address, Length: 2800, dtype: int64
#
#
# sewerassetexp:
# 04-Feb-13    38
# 28-May-13    14
# 18-Nov-11    12
# 13-May-13    11
# 12-Aug-13    10
# 15-Apr-13     9
# 20-May-13     8
# 07-Jun-13     7
# 01-Mar-11     7
# 09-Oct-09     6
# 25-Mar-13     6
# 03-Nov-11     4
# 17-Jun-13     4
# 22-Jul-13     3
# 24-Jun-13     3
# 15-May-13     3
# 25-Oct-11     2
# 08-Jul-13     1
# 01-Jul-13     1
# 28-Jun-11     1
# 09-Sep-13     1
# 28-Aug-12     1
# 18-Aug-11     1
# 12-Mar-13     1
# 19-Jul-13     1
# 27-Jun-13     1
# 13-Feb-13     1
# Name: sewerassetexp, dtype: int64
#
#
# num_spills_compkey:
# (0.979, 3.0]    2840
# (3.0, 5.0]       179
# (5.0, 7.0]        80
# (7.0, 9.0]        35
# (9.0, 11.0]        9
# (11.0, 13.0]      28
# (13.0, 15.0]       0
# (15.0, 17.0]       2
# (17.0, 19.0]       4
# (19.0, 21.0]       6
# Name: num_spills_compkey, dtype: int64
#
#
# num_spills_24mos:
# (0.987, 2.2]    1325
# (2.2, 3.4]        75
# (3.4, 4.6]        32
# (4.6, 5.8]        27
# (5.8, 7.0]        31
# (7.0, 8.2]         7
# (8.2, 9.4]         5
# (9.4, 10.6]        1
# (10.6, 11.8]       1
# (11.8, 13.0]       2
# Name: num_spills_24mos, dtype: int64
#
#
# prevspill_24mos:
# 26-Sep-16    11
# 19-May-16    10
# 25-May-13     7
# 02-Jun-16     6
# 16-May-16     6
# 17-May-15     6
# 03-Dec-16     5
# 17-Apr-10     5
# 28-Mar-18     5
# 20-Feb-17     5
# 11-May-16     5
# 09-Jul-18     5
# 25-Apr-15     5
# 08-Sep-10     4
# 22-Sep-18     4
# 07-Aug-17     4
# 24-Oct-15     3
# 05-Dec-16     3
# 07-Sep-10     3
# 19-Aug-12     3
# 09-Oct-11     3
# 19-Jun-15     3
# 04-Nov-14     3
# 15-Aug-16     3
# 31-May-16     3
# 26-Oct-09     3
# 15-Jan-10     3
# 25-Jun-14     3
# 23-May-15     3
# 11-Jul-12     3
#              ..
# 15-Feb-17     1
# 05-Apr-13     1
# 09-Nov-12     1
# 20-Feb-12     1
# 03-Jun-16     1
# 31-May-11     1
# 22-Jun-15     1
# 09-Aug-08     1
# 26-Sep-12     1
# 28-Jun-09     1
# 16-Sep-08     1
# 18-Jun-09     1
# 02-Feb-10     1
# 09-Sep-11     1
# 16-Mar-11     1
# 05-May-13     1
# 27-Sep-08     1
# 10-Nov-10     1
# 09-Jun-09     1
# 02-Dec-09     1
# 09-Nov-16     1
# 23-Jan-10     1
# 03-Nov-08     1
# 10-Mar-09     1
# 08-Dec-08     1
# 17-Sep-17     1
# 31-Oct-13     1
# 10-Feb-09     1
# 08-Apr-09     1
# 06-Aug-09     1
# Name: prevspill_24mos, Length: 442, dtype: int64
#
#
# unittype:
# GRAVITY       2508
# OUTFALL        222
# SIPHON         144
# ABOVE           83
# LATERAL         57
# SUBMERSED       51
# FORCE           44
# STANDARD        29
#                  9
# A/R              6
# JUNCTION         2
# TANKHOLDIN       2
# PMPCENTSP        2
# OUT SIPHON       2
# IN SIPHON        2
# PMPSUBM          1
# SLUDGE           1
# OTHER            1
# Name: unittype, dtype: int64
#
#
# assettype:
# Sewer Main               2925
# Sewer Lift Station        108
# Sewer Service Line         62
# Sewer Manhole              34
# Sewer Liftstation          30
# Sewer Valve                 7
# Sewer Pump                  3
# Sewer Treatment Plant       3
# Sewer Node                  3
# Plant Equipment             2
# Sewer Miscellaneous         1
# Bypass                      1
# BYPASS LINE                 1
# Sewer Force Main            1
# Name: assettype, dtype: int64
#
#
# lastclnd:
# 23-Sep-09    6
# 22-Oct-09    5
# 11-May-12    5
# 22-Aug-09    5
# 19-Jun-13    4
# 07-Jan-10    4
# 07-Dec-09    4
# 23-Nov-09    4
# 28-Dec-09    4
# 01-Jun-10    4
# 29-Feb-12    4
# 20-Oct-09    4
# 25-Nov-09    4
# 18-Apr-09    4
# 03-Oct-11    3
# 17-Dec-09    3
# 27-Aug-10    3
# 10-Nov-11    3
# 21-Sep-10    3
# 10-Oct-09    3
# 24-Jun-09    3
# 07-Dec-11    3
# 05-Feb-10    3
# 17-Mar-09    3
# 07-Oct-10    3
# 12-Feb-11    3
# 25-Mar-11    3
# 08-Apr-10    3
# 29-Aug-09    3
# 01-May-09    3
#             ..
# 29-Aug-12    1
# 07-Jul-13    1
# 22-Aug-12    1
# 23-Jul-12    1
# 11-Apr-11    1
# 13-Apr-12    1
# 25-Jan-13    1
# 20-Mar-13    1
# 09-Oct-09    1
# 18-Feb-12    1
# 04-Jul-11    1
# 11-Oct-11    1
# 15-Dec-10    1
# 25-Jul-13    1
# 04-Dec-13    1
# 09-Apr-09    1
# 29-Jan-13    1
# 04-Jan-12    1
# 03-Jun-14    1
# 27-Apr-12    1
# 04-Jun-12    1
# 28-Jan-10    1
# 28-Nov-09    1
# 11-May-09    1
# 19-Apr-12    1
# 26-Apr-10    1
# 24-Mar-13    1
# 16-Sep-12    1
# 08-May-10    1
# 26-Jan-13    1
# Name: lastclnd, Length: 796, dtype: int64
#
#
# responsetime:
# 0.00      374
# 0.50       19
# 0.78       17
# 0.60       17
# 0.58       16
# 0.45       16
# 0.43       16
# 0.55       15
# 0.42       15
# 0.25       15
# 0.62       14
# 0.53       14
# 0.67       13
# 0.65       13
# 0.85       13
# 0.40       12
# 0.37       12
# 0.57       12
# 0.83       12
# 0.63       12
# 0.28       12
# 0.70       12
# 0.68       12
# 0.23       11
# 0.47       11
# 0.52       11
# 0.48       11
# 0.75       11
# 0.33       10
# 0.12       10
#          ...
# 6.68        1
# 1.72        1
# -16.05      1
# 7.38        1
# 2.43        1
# 2.77        1
# 3.83        1
# 4.30        1
# 1.65        1
# 3.90        1
# 3.77        1
# 3.93        1
# 2.18        1
# 7.50        1
# 6.75        1
# 3.68        1
# 1.98        1
# 3.95        1
# -0.17       1
# 4.72        1
# -4.00       1
# 3.78        1
# 7.10        1
# 1.90        1
# 7.00        1
# 3.28        1
# -8.70       1
# 1.60        1
# 2.13        1
# 4.33        1
# Name: responsetime, Length: 209, dtype: int64
#
#
# responsedttm:
# 19-May-16    23
# 26-Sep-16    23
# 02-Jun-16    20
# 03-Dec-16    15
# 07-Aug-17    13
# 28-Mar-18    10
# 24-Oct-15    10
# 14-Jun-15     9
# 24-May-15     8
# 23-May-15     8
# 16-May-16     8
# 17-May-15     8
# 09-Sep-18     8
# 25-Apr-15     8
# 16-Sep-18     7
# 20-Feb-17     7
# 22-Sep-18     6
# 21-Aug-16     6
# 18-Apr-16     6
# 15-Sep-18     6
# 25-Jun-14     6
# 09-Jul-18     6
# 10-Mar-15     5
# 11-May-16     5
# 04-Sep-18     5
# 10-Sep-18     5
# 19-Jun-15     5
# 31-May-16     5
# 03-Jun-16     5
# 15-Oct-14     4
#              ..
# 11-Aug-18     1
# 26-Nov-18     1
# 17-May-16     1
# 08-May-16     1
# 16-Nov-14     1
# 19-Mar-14     1
# 07-Jun-16     1
# 10-Dec-15     1
# 05-Sep-15     1
# 10-Sep-14     1
# 20-Apr-15     1
# 30-Nov-15     1
# 07-Apr-15     1
# 22-Feb-18     1
# 25-Nov-17     1
# 09-Jul-14     1
# 29-Nov-14     1
# 21-Oct-14     1
# 13-Jul-16     1
# 16-Jul-17     1
# 29-Apr-14     1
# 10-Mar-17     1
# 11-Jun-15     1
# 09-Jun-14     1
# 25-Jun-15     1
# 12-Nov-17     1
# 20-Jan-16     1
# 29-Apr-18     1
# 22-Nov-14     1
# 18-Oct-15     1
# Name: responsedttm, Length: 780, dtype: int64
#
#
# public notice:
# False    3031
# True      152
# Name: public notice, dtype: int64
#
#
# timeint:
# 120.0    321
# 12.0     169
# 24.0     165
# 6.0       63
# 3.0       37
# 60.0      23
# 1.0       12
# Name: timeint, dtype: int64
#
#
# root_cause:
# STRUCTURAL           1237
# GREASE                610
# DEBRIS                443
# RAIN EVENT            353
# CONTRACTOR            164
# LIFT STATION          125
# OTHER                  61
# RAIN EVENT             48
# VANDALISM              48
# VANDALISM              24
# ROOTS                  22
# LIFT STATION           15
# I/I                    12
# CONTRACTOR              8
# BY PASS PUMP LEAK       3
# OTHER                   1
# Grease                  1
# Debris                  1
# Name: root_cause, dtype: int64
#
#
# steps_to_prevent:
# Increase FCS,         470
# Point Repair,         280
# Design Request,       201
# Other                 195
# I/I Inv,              144
# Capacity Project,     114
# Bolt down,             24
# ED/COM,                11
# RPC,                    7
# Name: steps_to_prevent, dtype: int64
#
#
# spill_start_2:
# 06/02/2016 20:00    2
# 06/02/2018 09:18    1
# 06/02/2016 23:41    1
# 05/31/2015 16:00    1
# 03/28/2018 21:45    1
# 08/26/2016 09:40    1
# 04/25/2015 15:24    1
# 01/17/2016 13:52    1
# 09/05/2018 11:45    1
# 12/06/2015 16:45    1
# 03/05/2017 16:05    1
# 05/16/2016 13:30    1
# 09/23/2018 14:42    1
# 04/25/2017 10:45    1
# 11/30/2018 11:35    1
# 10/24/2015 09:35    1
# 08/01/2018 09:43    1
# 06/02/2016 08:40    1
# 04/07/2018 09:17    1
# 04/26/2016 19:19    1
# 09/30/2012 13:00    1
# 06/03/2016 19:26    1
# 12/08/2018 17:45    1
# 01/10/2016 13:20    1
# 02/23/2018 12:37    1
# 09/23/2018 10:51    1
# 01/03/2016 12:45    1
# 12/05/2016 09:30    1
# 06/06/2012 07:15    1
# 03/10/2019 09:36    1
#                    ..
# 10/24/2018 17:10    1
# 06/01/2016 14:30    1
# 12/24/2015 16:30    1
# 12/04/2016 14:00    1
# 09/16/2018 08:03    1
# 05/19/2015 08:30    1
# 05/26/2013 11:45    1
# 05/15/2012 09:35    1
# 02/18/2018 11:10    1
# 05/19/2016 11:21    1
# 12/27/2015 17:57    1
# 04/25/2015 12:10    1
# 10/31/2015 07:45    1
# 03/28/2018 10:00    1
# 10/11/2018 15:08    1
# 03/20/2012 09:00    1
# 12/11/2018 09:45    1
# 10/21/2018 14:15    1
# 01/24/2016 13:37    1
# 08/28/2012 07:30    1
# 11/07/2014 08:30    1
# 12/07/2018 21:00    1
# 06/03/2016 14:05    1
# 01/31/2016 22:45    1
# 03/28/2018 18:28    1
# 09/26/2016 22:15    1
# 03/25/2014 16:15    1
# 01/04/2016 10:05    1
# 05/18/2016 06:55    1
# 11/28/2015 14:45    1
# Name: spill_start_2, Length: 85, dtype: int64
#
#
# spill_stop_2:
# 01/24/2016 16:30    1
# 10/22/2018 03:00    1
# 09/17/2018 04:00    1
# 06/03/2016 01:30    1
# 01/18/2017 14:25    1
# 03/29/2018 03:00    1
# 10/12/2018 05:00    1
# 05/26/2013 18:00    1
# 04/25/2015 11:41    1
# 06/03/2016 14:10    1
# 08/26/2016 10:30    1
# 03/10/2019 10:45    1
# 11/30/2015 01:40    1
# 05/19/2016 18:45    1
# 02/23/2018 21:40    1
# 10/16/2018 03:00    1
# 10/17/2018 08:50    1
# 04/25/2017 15:00    1
# 07/24/2018 14:30    1
# 11/21/2014 19:30    1
# 11/01/2015 00:42    1
# 01/31/2016 23:56    1
# 11/28/2015 21:30    1
# 01/11/2016 00:32    1
# 03/25/2014 17:50    1
# 05/12/2016 07:15    1
# 09/24/2018 05:00    1
# 06/04/2016 00:00    1
# 06/01/2016 07:20    1
# 05/16/2016 12:00    1
#                    ..
# 12/20/2015 16:45    1
# 06/03/2016 11:23    1
# 06/02/2016 15:45    1
# 06/07/2013 18:30    1
# 09/23/2018 22:57    1
# 10/29/2018 03:30    1
# 08/01/2018 10:05    1
# 12/24/2015 20:00    1
# 03/29/2018 02:45    1
# 10/25/2018 05:20    1
# 05/16/2016 14:40    1
# 05/15/2012 10:15    1
# 06/06/2016 12:30    1
# 06/03/2016 04:22    1
# 12/27/2015 18:30    1
# 04/26/2016 20:10    1
# 12/09/2018 03:30    1
# 10/24/2015 12:15    1
# 09/16/2018 20:00    1
# 09/06/2018 04:20    1
# 12/06/2016 08:05    1
# 06/02/2016 23:30    1
# 11/07/2014 10:05    1
# 12/06/2015 17:00    1
# 12/06/2016 03:40    1
# 11/09/2016 13:00    1
# 05/20/2016 14:30    1
# 03/28/2018 15:30    1
# 01/17/2016 16:26    1
# 09/21/2018 21:45    1
# Name: spill_stop_2, Length: 86, dtype: int64
#
#
# hrs_2:
# (-0.119, 11.8]    1291
# (11.8, 23.6]        15
# (23.6, 35.4]         0
# (35.4, 47.2]         1
# (47.2, 59.0]         1
# (59.0, 70.8]         0
# (70.8, 82.6]         0
# (82.6, 94.4]         0
# (94.4, 106.2]        0
# (106.2, 118.0]       1
# Name: hrs_2, dtype: int64
#
#
# gal_2:
# (-2377.351, 237735.0]     1300
# (237735.0, 475470.0]         5
# (475470.0, 713205.0]         1
# (713205.0, 950940.0]         0
# (950940.0, 1188675.0]        1
# (1188675.0, 1426410.0]       2
# (1426410.0, 1664145.0]       0
# (1664145.0, 1901880.0]       0
# (1901880.0, 2139615.0]       0
# (2139615.0, 2377350.0]       1
# Name: gal_2, dtype: int64
#
#
# spill_start_3:
# 12/06/2016 15:28    1
# 10/12/2018 08:00    1
# 01/24/2016 22:10    1
# 01/04/2016 16:55    1
# 06/02/2016 12:00    1
# 09/27/2016 13:30    1
# 12/09/2018 14:09    1
# 11/22/2014 22:05    1
# 06/10/2013 11:30    1
# 10/29/2018 21:20    1
# 06/03/2016 16:00    1
# 03/21/2012 08:40    1
# 12/28/2015 14:47    1
# 10/25/2018 11:59    1
# Name: spill_start_3, dtype: int64
#
#
# spill_stop_3:
# 12/10/2018 05:00    1
# 06/03/2016 20:00    1
# 10/30/2018 02:50    1
# 10/25/2018 17:30    1
# 06/02/2016 12:05    1
# 12/07/2016 07:00    1
# 11/23/2014 03:05    1
# 12/28/2015 15:25    1
# 01/24/2016 23:38    1
# 01/04/2016 19:00    1
# 03/21/2012 11:15    1
# 06/10/2013 13:00    1
# 10/12/2018 12:02    1
# 09/27/2016 15:00    1
# Name: spill_stop_3, dtype: int64
#
#
# hrs_3:
# (-0.0165, 1.553]    1295
# (1.553, 3.106]         2
# (3.106, 4.659]         2
# (4.659, 6.212]         3
# (6.212, 7.765]         1
# (7.765, 9.318]         0
# (9.318, 10.871]        0
# (10.871, 12.424]       0
# (12.424, 13.977]       0
# (13.977, 15.53]        2
# Name: hrs_3, dtype: int64
#
#
# gal_3:
# (-255.30100000000002, 25530.0]    1300
# (25530.0, 51060.0]                   3
# (51060.0, 76590.0]                   1
# (76590.0, 102120.0]                  0
# (102120.0, 127650.0]                 0
# (127650.0, 153180.0]                 0
# (153180.0, 178710.0]                 0
# (178710.0, 204240.0]                 0
# (204240.0, 229770.0]                 0
# (229770.0, 255300.0]                 1
# Name: gal_3, dtype: int64

# %% [markdown]
# _Let's rename the columns for clarity._

# %%
df = df.rename(index=str, columns={'inspkey':'inspection_key',
                                   'servno':'service_number',
                                   'reportdate':'report_date',
                                   'spill_st_name':'spill_street_name',
                                   'total_gal':'total_gallons',
                                   'galsret':'gallons_returned',
                                   'gal':'gallons_1',
                                   'spill_start':'spill_start_1',
                                   'spill_stop':'spill_stop_1',
                                   'hrs':'hours_1',
                                   'unitid':'unit_id_1',
                                   'unitid2':'unit_id_2',
                                   'earz_zone':'edwards_zone',
                                   'expr1029':'expr_1029',
                                   'pipediam':'pipe_diameter',
                                   'pipelen':'pipe_length',
                                   'pipetype':'pipe_type',
                                   'instyear':'installation_year',
                                   'dwndpth':'downstream_depth',
                                   'upsdpth':'upstream_depth',
                                   'rainfall_less3':'rainfall_less_3',
                                   'spill address': 'spill_address_full',
                                   'sewerassetexp':'sewer_asset_exp',
                                   'prevspill_24mos':'previous_spill_24mos',
                                   'unittype':'unit_type',
                                   'assettype':'asset_type',
                                   'lastclnd':'last_cleaned',
                                   'responsetime':'response_time',
                                   'responsedttm':'response_datetime',
                                   'public notice':'public_notice',
                                   'timeint':'time_int',
                                   'hrs_2':'hours_2',
                                   'gal_2':'gallons_2',
                                   'hrs_3':'hours_3',
                                   'gal_3':'gallons_3'
                                   })

# %%
df.head(4).T
# Out:
#                                                                       0  \
# sso_id                                                             6582
# inspection_key                                                   567722
# service_number                                                      NaN
# report_date                                                     3/10/19
# spill_address                                                      3200
# spill_street_name                                      THOUSAND OAKS DR
# total_gallons                                                      2100
# gallons_returned                                                   2100
# gallons_1                                                          2100
# spill_start_1                                      3/10/2019 1:16:00 PM
# spill_stop_1                                       3/10/2019 2:40:00 PM
# hours_1                                                             1.4
# cause                                                            Grease
# comments              Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                    CLEANED MAIN
# watershed                                                  SALADO CREEK
# unit_id_1                                                         66918
# unit_id_2                                                         66917
# discharge_to                                                     STREET
# discharge_route                                                    None
# council_district                                                    NaN
# ferguson                                                          172A2
# month                                                                 3
# year                                                               2019
# week                                                                 11
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                       16.55
# pipe_type                                                           PVC
# installation_year                                                  1997
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                3200 THOUSAND OAKS DR
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      0.45
# response_datetime                                             10-Mar-19
# public_notice                                                     False
# time_int                                                             24
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
#
#                                                                 1  \
# sso_id                                                       6583
# inspection_key                                             567723
# service_number                                                NaN
# report_date                                               3/10/19
# spill_address                                                6804
# spill_street_name                                     S FLORES ST
# total_gallons                                                  80
# gallons_returned                                                0
# gallons_1                                                      80
# spill_start_1                                3/10/2019 2:25:00 PM
# spill_stop_1                                 3/10/2019 3:45:00 PM
# hours_1                                                   1.33333
# cause                                                      Grease
# comments              Spill ContainedArea Cleaned and Disinfected
# actions                                              CLEANED MAIN
# watershed                                                DOS RIOS
# unit_id_1                                                   24250
# unit_id_2                                                   24193
# discharge_to                                           STORMDRAIN
# discharge_route                                              None
# council_district                                                3
# ferguson                                                    251A3
# month                                                           3
# year                                                         2019
# week                                                           11
# edwards_zone                                                    0
# expr_1029                                                     NaN
# pipe_diameter                                                   8
# pipe_length                                                   157
# pipe_type                                                     PVC
# installation_year                                            1988
# downstream_depth                                              NaN
# upstream_depth                                                NaN
# inches_no                                                     NaN
# rainfall_less_3                                               NaN
# spill_address_full                                  6804 S FLORES
# sewer_asset_exp                                               NaN
# num_spills_compkey                                              1
# num_spills_24mos                                                1
# previous_spill_24mos                                          NaN
# unit_type                                                 GRAVITY
# asset_type                                             Sewer Main
# last_cleaned                                                  NaN
# response_time                                                1.08
# response_datetime                                       10-Mar-19
# public_notice                                               False
# time_int                                                      120
# root_cause                                                    NaN
# steps_to_prevent                                              NaN
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
#
#                                                                       2  \
# sso_id                                                             6581
# inspection_key                                                   567714
# service_number                                                      NaN
# report_date                                                      3/9/19
# spill_address                                                       215
# spill_street_name                                       AUDREY ALENE DR
# total_gallons                                                        79
# gallons_returned                                                      0
# gallons_1                                                            10
# spill_start_1                                       3/9/2019 6:00:00 PM
# spill_stop_1                                        3/9/2019 7:30:00 PM
# hours_1                                                             1.5
# cause                                                        Structural
# comments              Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                    CLEANED MAIN
# watershed                                                      DOS RIOS
# unit_id_1                                                          2822
# unit_id_2                                                          3351
# discharge_to                                                      ALLEY
# discharge_route                                                    None
# council_district                                                      1
# ferguson                                                          190E4
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                         350
# pipe_type                                                            CP
# installation_year                                                  1955
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  215 Audrey Alene Dr
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      1.00
# response_datetime                                             09-Mar-19
# public_notice                                                     False
# time_int                                                             24
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                          03/10/2019 09:36
# spill_stop_2                                           03/10/2019 10:45
# hours_2                                                            1.15
# gallons_2                                                            69
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
#
#                                                                       3
# sso_id                                                             6584
# inspection_key                                                   567713
# service_number                                                      NaN
# report_date                                                      3/9/19
# spill_address                                                      3602
# spill_street_name                                        SE MILITARY DR
# total_gallons                                                        83
# gallons_returned                                                      0
# gallons_1                                                            83
# spill_start_1                                       3/9/2019 3:37:00 PM
# spill_stop_1                                        3/9/2019 5:00:00 PM
# hours_1                                                         1.38333
# cause                                                            Grease
# comments              Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                             NaN
# watershed                                                  SALADO CREEK
# unit_id_1                                                         92804
# unit_id_2                                                         92805
# discharge_to                                                   EASEMENT
# discharge_route                                                    None
# council_district                                                      3
# ferguson                                                          252C3
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                      213.91
# pipe_type                                                           PVC
# installation_year                                                  1983
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  3602 SE MILITARY DR
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      0.55
# response_datetime                                             09-Mar-19
# public_notice                                                     False
# time_int                                                            120
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0

# %% [markdown]
# ### Looking for the repeat offenders...

# %%
df.num_spills_24mos[df.num_spills_24mos > 1].value_counts()
# Out:
# 2.0     180
# 3.0      75
# 4.0      32
# 5.0      27
# 6.0      19
# 7.0      12
# 8.0       7
# 9.0       5
# 10.0      1
# 11.0      1
# 12.0      1
# 13.0      1
# Name: num_spills_24mos, dtype: int64

# %% [markdown]
# ### Location of the most frequent SSOs

# %%
df.spill_address_full[df.num_spills_24mos >= 7]
# Out:
# 33             SWISS OAKS 06606
# 40              6606 Swiss Oaks
# 41              6606 Swiss Oaks
# 47             SWISS OAKS 06606
# 73              1800 AUSTIN HWY
# 84      CHAPPIE JAMES WAY 00108
# 93      CHAPPIE JAMES WAY 00108
# 97      CHAPPIE JAMES WAY 00108
# 141     CHAPPIE JAMES WAY 00100
# 153            SWISS OAKS 06606
# 158     CHAPPIE JAMES WAY 00100
# 166     CHAPPIE JAMES WAY 00100
# 171            SWISS OAKS 06606
# 190            SWISS OAKS 06606
# 241        HARRY WURZBACH 01427
# 243            SWISS OAKS 06606
# 303     CHAPPIE JAMES WAY 00100
# 384     CHAPPIE JAMES WAY 00108
# 591              HOLBROOK 00902
# 593       ENTRANCE RD N E 10800
# 602           RITTIMAN RD 04034
# 727        ENTRANCE RD NE 10800
# 738       10800 N E Entrance Rd
# 751        ENTRANCE RD NE 10823
# 762        ENTRANCE RD NE 108/1
# 770        ENTRANCE RD NE 108/1
# 1654            CAGNON RD 06305
# 2394            CAGNON RD 066/1
# Name: spill_address_full, dtype: object

# %% [markdown]
# - [ ] **TODO:** Find a way to flesh out the address using regex to account for typos etc.
# - [ ] **TODO:** Maybe try using unit id's instead of addresses.
# - [ ] **TODO:** Drill down to only the top 3-5 locations.
# - [ ] **TODO:** Compare predictions between preventing SSO on the most frequents versus not preventing.
# - [ ] **TODO:** What is causing the spills on these top 3-5 locations?

# %%
df1 = df[(df.spill_address==10800) & (df.spill_street_name == 'ENTRANCE RD NE')]
df1.T
# Out:
#                                                         568  \
# sso_id                                                 6025
# inspection_key                                          NaN
# service_number                                  1.50063e+06
# report_date                                         9/26/16
# spill_address                                         10800
# spill_street_name                            ENTRANCE RD NE
# total_gallons                                         26300
# gallons_returned                                          0
# gallons_1                                             26300
# spill_start_1                          9/26/2016 7:50:00 AM
# spill_stop_1                           9/26/2016 4:36:00 PM
# hours_1                                             8.76667
# cause                                                   I/I
# comments                                                NaN
# actions                          Diluted By Heavy Rainwater
# watershed                                      SALADO CREEK
# unit_id_1                                             52742
# unit_id_2                                             52470
# discharge_to          CREEK BED - Spilled Into Salado Creek
# discharge_route                                SALADO CREEK
# council_district                                          9
# ferguson                                              171E6
# month                                                     9
# year                                                   2016
# week                                                     40
# edwards_zone                                              0
# expr_1029                                        RAIN EVENT
# pipe_diameter                                            12
# pipe_length                                          308.86
# pipe_type                                               PVC
# installation_year                                      1988
# downstream_depth                                        NaN
# upstream_depth                                          NaN
# inches_no                                              4.75
# rainfall_less_3                                        1.36
# spill_address_full                     ENTRANCE RD NE 108/1
# sewer_asset_exp                                         NaN
# num_spills_compkey                                        1
# num_spills_24mos                                          1
# previous_spill_24mos                                    NaN
# unit_type                                           GRAVITY
# asset_type                                       Sewer Main
# last_cleaned                                            NaN
# response_time                                          0.00
# response_datetime                                 26-Sep-16
# public_notice                                         False
# time_int                                                120
# root_cause                                       RAIN EVENT
# steps_to_prevent                         Capacity Project,
# spill_start_2                                           NaN
# spill_stop_2                                            NaN
# hours_2                                                   0
# gallons_2                                                 0
# spill_start_3                                           NaN
# spill_stop_3                                            NaN
# hours_3                                                   0
# gallons_3                                                 0
#
#                                                         593  \
# sso_id                                                 5984
# inspection_key                                          NaN
# service_number                                  1.44566e+06
# report_date                                         8/16/16
# spill_address                                         10800
# spill_street_name                            ENTRANCE RD NE
# total_gallons                                         12000
# gallons_returned                                        NaN
# gallons_1                                             12000
# spill_start_1                         8/16/2016 10:30:00 PM
# spill_stop_1                           8/17/2016 2:30:00 AM
# hours_1                                                   4
# cause                                                   I/I
# comments                                                NaN
# actions                         DILUTED BY HEAVY RAIN WATER
# watershed                                      SALADO CREEK
# unit_id_1                                             52470
# unit_id_2                                             52677
# discharge_to          CREEK BED - SPILLED INTO SALADO CREEK
# discharge_route                                SALADO CREEK
# council_district                                          9
# ferguson                                              171E6
# month                                                     8
# year                                                   2016
# week                                                     34
# edwards_zone                                              0
# expr_1029                                        RAIN EVENT
# pipe_diameter                                            12
# pipe_length                                          251.64
# pipe_type                                               PVC
# installation_year                                      1988
# downstream_depth                                        NaN
# upstream_depth                                          NaN
# inches_no                                              0.55
# rainfall_less_3                                        2.08
# spill_address_full                    ENTRANCE RD N E 10800
# sewer_asset_exp                                         NaN
# num_spills_compkey                                       13
# num_spills_24mos                                         13
# previous_spill_24mos                              18-Apr-16
# unit_type                                           GRAVITY
# asset_type                                       Sewer Main
# last_cleaned                                            NaN
# response_time                                          0.00
# response_datetime                                 16-Aug-16
# public_notice                                         False
# time_int                                                 12
# root_cause                                       RAIN EVENT
# steps_to_prevent                         Capacity Project,
# spill_start_2                                           NaN
# spill_stop_2                                            NaN
# hours_2                                                   0
# gallons_2                                                 0
# spill_start_3                                           NaN
# spill_stop_3                                            NaN
# hours_3                                                   0
# gallons_3                                                 0
#
#                                                      726  \
# sso_id                                              5854
# inspection_key                                       NaN
# service_number                               1.25265e+06
# report_date                                      4/18/16
# spill_address                                      10800
# spill_street_name                         ENTRANCE RD NE
# total_gallons                                       6650
# gallons_returned                                       0
# gallons_1                                           6650
# spill_start_1                      4/18/2016 11:02:00 AM
# spill_stop_1                        4/18/2016 1:15:00 PM
# hours_1                                          2.21667
# cause                                                I/I
# comments                                             NaN
# actions                       DILUTED BY HEAVY RAINWATER
# watershed                                   SALADO CREEK
# unit_id_1                                         930659
# unit_id_2                                         930653
# discharge_to          CREEK BED - SPILLED INTO MUD CREEK
# discharge_route                                     NONE
# council_district                                       9
# ferguson                                           171E5
# month                                                  4
# year                                                2016
# week                                                  17
# edwards_zone                                           0
# expr_1029                                     RAIN EVENT
# pipe_diameter                                         36
# pipe_length                                       277.51
# pipe_type                                            FRP
# installation_year                                   2015
# downstream_depth                                     NaN
# upstream_depth                                       NaN
# inches_no                                            1.7
# rainfall_less_3                                      0.6
# spill_address_full                  ENTRANCE RD NE 10800
# sewer_asset_exp                                      NaN
# num_spills_compkey                                     1
# num_spills_24mos                                       1
# previous_spill_24mos                                 NaN
# unit_type                                        OUTFALL
# asset_type                                    Sewer Main
# last_cleaned                                         NaN
# response_time                                       0.00
# response_datetime                              18-Apr-16
# public_notice                                      False
# time_int                                             120
# root_cause                                    RAIN EVENT
# steps_to_prevent                      Capacity Project,
# spill_start_2                                        NaN
# spill_stop_2                                         NaN
# hours_2                                                0
# gallons_2                                              0
# spill_start_3                                        NaN
# spill_stop_3                                         NaN
# hours_3                                                0
# gallons_3                                              0
#
#                                                         727  \
# sso_id                                                 5855
# inspection_key                                          NaN
# service_number                                  1.25315e+06
# report_date                                         4/18/16
# spill_address                                         10800
# spill_street_name                            ENTRANCE RD NE
# total_gallons                                         78000
# gallons_returned                                          0
# gallons_1                                             78000
# spill_start_1                          4/18/2016 2:20:00 PM
# spill_stop_1                          4/18/2016 11:00:00 PM
# hours_1                                             8.66667
# cause                                                   I/I
# comments                                                NaN
# actions                          DILUTED BY HEAVY RAINWATER
# watershed                                      SALADO CREEK
# unit_id_1                                             52470
# unit_id_2                                             52677
# discharge_to          CREEK BED - SPILLED INTO SALADO CREEK
# discharge_route                                        NONE
# council_district                                          9
# ferguson                                              171E6
# month                                                     4
# year                                                   2016
# week                                                     17
# edwards_zone                                              0
# expr_1029                                        RAIN EVENT
# pipe_diameter                                            12
# pipe_length                                          251.64
# pipe_type                                               PVC
# installation_year                                      1988
# downstream_depth                                        NaN
# upstream_depth                                          NaN
# inches_no                                               1.7
# rainfall_less_3                                         0.6
# spill_address_full                     ENTRANCE RD NE 10800
# sewer_asset_exp                                         NaN
# num_spills_compkey                                       12
# num_spills_24mos                                         12
# previous_spill_24mos                              24-Mar-16
# unit_type                                           GRAVITY
# asset_type                                       Sewer Main
# last_cleaned                                            NaN
# response_time                                          0.00
# response_datetime                                 18-Apr-16
# public_notice                                         False
# time_int                                                 12
# root_cause                                       RAIN EVENT
# steps_to_prevent                                  I/I Inv,
# spill_start_2                                           NaN
# spill_stop_2                                            NaN
# hours_2                                                   0
# gallons_2                                                 0
# spill_start_3                                           NaN
# spill_stop_3                                            NaN
# hours_3                                                   0
# gallons_3                                                 0
#
#                                                               738  \
# sso_id                                                       5838
# inspection_key                                             406517
# service_number                                                NaN
# report_date                                               3/24/16
# spill_address                                               10800
# spill_street_name                                  ENTRANCE RD NE
# total_gallons                                                 100
# gallons_returned                                                0
# gallons_1                                                     100
# spill_start_1                                3/24/2016 2:40:00 PM
# spill_stop_1                                 3/24/2016 2:55:00 PM
# hours_1                                                      0.25
# cause                                                       Other
# comments              Spill ContainedArea Cleaned and Disinfected
# actions                                              REMOVED PLUG
# watershed                                            SALADO CREEK
# unit_id_1                                                   52470
# unit_id_2                                                   52677
# discharge_to                                               GROUND
# discharge_route                                              None
# council_district                                                9
# ferguson                                                    171E6
# month                                                           3
# year                                                         2016
# week                                                           13
# edwards_zone                                                    0
# expr_1029                                                   OTHER
# pipe_diameter                                                  12
# pipe_length                                                251.64
# pipe_type                                                     PVC
# installation_year                                            1988
# downstream_depth                                              NaN
# upstream_depth                                                NaN
# inches_no                                                    0.37
# rainfall_less_3                                                 0
# spill_address_full                          10800 N E Entrance Rd
# sewer_asset_exp                                               NaN
# num_spills_compkey                                             11
# num_spills_24mos                                               11
# previous_spill_24mos                                    10-Feb-16
# unit_type                                                 GRAVITY
# asset_type                                             Sewer Main
# last_cleaned                                                  NaN
# response_time                                                0.00
# response_datetime                                       24-Mar-16
# public_notice                                               False
# time_int                                                       12
# root_cause                                                  OTHER
# steps_to_prevent                                            Other
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
#
#                                        767                   770  \
# sso_id                                5808                  5802
# inspection_key                         NaN                   NaN
# service_number                  1.1501e+06           1.14377e+06
# report_date                        1/23/16               1/19/16
# spill_address                        10800                 10800
# spill_street_name           ENTRANCE RD NE        ENTRANCE RD NE
# total_gallons                        24765                 39940
# gallons_returned                       NaN                     0
# gallons_1                              390                 11005
# spill_start_1         1/23/2016 2:58:00 PM  1/16/2016 1:44:00 PM
# spill_stop_1          1/23/2016 3:21:00 PM  1/16/2016 3:56:00 PM
# hours_1                           0.383333                   2.2
# cause                     Other - Capacity      Other - Capacity
# comments                               NaN                   NaN
# actions                       Cleaned Area          Cleaned Area
# watershed                     SALADO CREEK          SALADO CREEK
# unit_id_1                            52470                 52470
# unit_id_2                            52677                 52677
# discharge_to                        GROUND                GROUND
# discharge_route                       NONE                  NONE
# council_district                         9                     9
# ferguson                             171E6                 171E6
# month                                    1                     1
# year                                  2016                  2016
# week                                     4                     4
# edwards_zone                             0                     0
# expr_1029                            OTHER                 OTHER
# pipe_diameter                            0                    12
# pipe_length                            5.9                251.64
# pipe_type                                                    PVC
# installation_year                     1988                  1988
# downstream_depth                       NaN                   NaN
# upstream_depth                         NaN                   NaN
# inches_no                                0                     0
# rainfall_less_3                          0                     0
# spill_address_full    ENTRANCE RD NE 10800  ENTRANCE RD NE 108/1
# sewer_asset_exp                        NaN                   NaN
# num_spills_compkey                       2                     7
# num_spills_24mos                         2                     7
# previous_spill_24mos             19-Jan-16             11-Jan-16
# unit_type                          GRAVITY               GRAVITY
# asset_type                      Sewer Main            Sewer Main
# last_cleaned                           NaN                   NaN
# response_time                         0.00                  0.00
# response_datetime                23-Jan-16             16-Jan-16
# public_notice                        False                 False
# time_int                                12                    12
# root_cause                           OTHER                 OTHER
# steps_to_prevent        Capacity Project,     Capacity Project,
# spill_start_2             01/24/2016 13:37      01/17/2016 13:52
# spill_stop_2              01/24/2016 16:30      01/17/2016 16:26
# hours_2                                2.8                  2.57
# gallons_2                            17075                 28935
# spill_start_3             01/24/2016 22:10                   NaN
# spill_stop_3              01/24/2016 23:38                   NaN
# hours_3                               1.47                     0
# gallons_3                             7300                     0
#
#                                         773                   783  \
# sso_id                                 5806                  5794
# inspection_key                          NaN                   NaN
# service_number                  1.14444e+06            1.1353e+06
# report_date                         1/18/16                1/9/16
# spill_address                         10800                 10800
# spill_street_name            ENTRANCE RD NE        ENTRANCE RD NE
# total_gallons                          3000                139525
# gallons_returned                        700                   NaN
# gallons_1                              3000                 58125
# spill_start_1         1/18/2016 10:00:00 PM   1/9/2016 1:00:00 PM
# spill_stop_1          1/19/2016 12:30:00 AM   1/9/2016 5:15:00 PM
# hours_1                                 2.5                  4.25
# cause                      Other - Capacity      Other - Capacity
# comments                                NaN                   NaN
# actions                        Cleaned Area          Cleaned Area
# watershed                      SALADO CREEK          SALADO CREEK
# unit_id_1                             52470                 52470
# unit_id_2                               NaN                 52677
# discharge_to                         GROUND                GROUND
# discharge_route                        NONE                  NONE
# council_district                          9                     9
# ferguson                              171E6                 171E6
# month                                     1                     1
# year                                   2016                  2016
# week                                      4                     2
# edwards_zone                              0                     0
# expr_1029                             OTHER                 OTHER
# pipe_diameter                             0                    12
# pipe_length                             5.9                251.64
# pipe_type                                                     PVC
# installation_year                      1988                  1988
# downstream_depth                        NaN                   NaN
# upstream_depth                          NaN                   NaN
# inches_no                                 0                     0
# rainfall_less_3                           0                  0.06
# spill_address_full     ENTRANCE RD NE 10800  ENTRANCE RD NE 10823
# sewer_asset_exp                         NaN                   NaN
# num_spills_compkey                        1                     6
# num_spills_24mos                          1                     6
# previous_spill_24mos                    NaN             02-Jan-16
# unit_type                          STANDARD               GRAVITY
# asset_type                    Sewer Manhole            Sewer Main
# last_cleaned                            NaN                   NaN
# response_time                          0.00                  0.00
# response_datetime                 18-Jan-16             09-Jan-16
# public_notice                         False                  True
# time_int                                NaN                    12
# root_cause                            OTHER                 OTHER
# steps_to_prevent         Capacity Project,     Capacity Project,
# spill_start_2                           NaN      01/10/2016 13:20
# spill_stop_2                            NaN      01/11/2016 00:32
# hours_2                                   0                  11.2
# gallons_2                                 0                 81400
# spill_start_3                           NaN                   NaN
# spill_stop_3                            NaN                   NaN
# hours_3                                   0                     0
# gallons_3                                 0                     0
#
#                                                             792  \
# sso_id                                                     5786
# inspection_key                                              NaN
# service_number                                      1.12719e+06
# report_date                                              1/2/16
# spill_address                                             10800
# spill_street_name                                ENTRANCE RD NE
# total_gallons                                            267850
# gallons_returned                                            NaN
# gallons_1                                                120850
# spill_start_1                               1/2/2016 1:59:00 PM
# spill_stop_1                               1/3/2016 12:20:00 AM
# hours_1                                                   10.35
# cause                                                       I/I
# comments                                                    NaN
# actions                                            Cleaned Area
# watershed                                          SALADO CREEK
# unit_id_1                                                 52470
# unit_id_2                                                 52677
# discharge_to          CREEK BED - ( Spilled into Salado Creek )
# discharge_route                                    SALADO CREEK
# council_district                                              9
# ferguson                                                  171E6
# month                                                         1
# year                                                       2016
# week                                                          1
# edwards_zone                                                  0
# expr_1029                                                 OTHER
# pipe_diameter                                                12
# pipe_length                                              251.64
# pipe_type                                                   PVC
# installation_year                                          1988
# downstream_depth                                            NaN
# upstream_depth                                              NaN
# inches_no                                                  0.82
# rainfall_less_3                                            0.16
# spill_address_full                        10800 N E Entrance Rd
# sewer_asset_exp                                             NaN
# num_spills_compkey                                            5
# num_spills_24mos                                              5
# previous_spill_24mos                                  27-Dec-15
# unit_type                                               GRAVITY
# asset_type                                           Sewer Main
# last_cleaned                                                NaN
# response_time                                              1.27
# response_datetime                                     02-Jan-16
# public_notice                                              True
# time_int                                                     12
# root_cause                                                OTHER
# steps_to_prevent                             Capacity Project,
# spill_start_2                                  01/03/2016 12:45
# spill_stop_2                                   01/04/2016 02:00
# hours_2                                                   13.25
# gallons_2                                                147000
# spill_start_3                                               NaN
# spill_stop_3                                                NaN
# hours_3                                                       0
# gallons_3                                                     0
#
#                                         797  \
# sso_id                                 5779
# inspection_key                          NaN
# service_number                  1.12378e+06
# report_date                        12/27/15
# spill_address                         10800
# spill_street_name            ENTRANCE RD NE
# total_gallons                         25030
# gallons_returned                        NaN
# gallons_1                             22800
# spill_start_1         12/27/2015 3:25:00 PM
# spill_stop_1          12/27/2015 5:57:00 PM
# hours_1                             2.53333
# cause                                Debris
# comments                 12 inch sewer main
# actions                      MONITORED AREA
# watershed                      SALADO CREEK
# unit_id_1                             52470
# unit_id_2                             52677
# discharge_to                         GROUND
# discharge_route                        NONE
# council_district                          9
# ferguson                              171E6
# month                                    12
# year                                   2015
# week                                     53
# edwards_zone                              0
# expr_1029                             OTHER
# pipe_diameter                            12
# pipe_length                          251.64
# pipe_type                               PVC
# installation_year                      1988
# downstream_depth                        NaN
# upstream_depth                          NaN
# inches_no                              0.69
# rainfall_less_3                           0
# spill_address_full     10800 ENTRANCE RD NE
# sewer_asset_exp                         NaN
# num_spills_compkey                        4
# num_spills_24mos                          4
# previous_spill_24mos              24-Dec-15
# unit_type                           GRAVITY
# asset_type                       Sewer Main
# last_cleaned                            NaN
# response_time                          0.00
# response_datetime                 27-Dec-15
# public_notice                         False
# time_int                                 12
# root_cause                            OTHER
# steps_to_prevent         Capacity Project,
# spill_start_2              12/27/2015 17:57
# spill_stop_2               12/27/2015 18:30
# hours_2                                0.55
# gallons_2                               330
# spill_start_3              12/28/2015 14:47
# spill_stop_3               12/28/2015 15:25
# hours_3                                0.63
# gallons_3                              1900
#
#                                                            799  \
# sso_id                                                    5776
# inspection_key                                             NaN
# service_number                                     1.12302e+06
# report_date                                           12/24/15
# spill_address                                            10800
# spill_street_name                               ENTRANCE RD NE
# total_gallons                                            30750
# gallons_returned                                           NaN
# gallons_1                                                15000
# spill_start_1                            12/24/2015 2:00:00 PM
# spill_stop_1                             12/24/2015 4:30:00 PM
# hours_1                                                    2.5
# cause                                                   Debris
# comments                                    12 inch sewer main
# actions                                         MONITORED AREA
# watershed                                         SALADO CREEK
# unit_id_1                                                52470
# unit_id_2                                                52677
# discharge_to          CREEK BED  ( Spilled into Salado Creek )
# discharge_route                                   SALADO CREEK
# council_district                                             9
# ferguson                                                 171E6
# month                                                       12
# year                                                      2015
# week                                                        52
# edwards_zone                                                 0
# expr_1029                                                OTHER
# pipe_diameter                                               12
# pipe_length                                             251.64
# pipe_type                                                  PVC
# installation_year                                         1988
# downstream_depth                                           NaN
# upstream_depth                                             NaN
# inches_no                                                    0
# rainfall_less_3                                              0
# spill_address_full                          STARCREST DR 11601
# sewer_asset_exp                                            NaN
# num_spills_compkey                                           3
# num_spills_24mos                                             3
# previous_spill_24mos                                 19-Dec-15
# unit_type                                              GRAVITY
# asset_type                                          Sewer Main
# last_cleaned                                               NaN
# response_time                                             0.00
# response_datetime                                    24-Dec-15
# public_notice                                            False
# time_int                                                    12
# root_cause                                               OTHER
# steps_to_prevent                            Capacity Project,
# spill_start_2                                 12/24/2015 16:30
# spill_stop_2                                  12/24/2015 20:00
# hours_2                                                    3.5
# gallons_2                                                15750
# spill_start_3                                              NaN
# spill_stop_3                                               NaN
# hours_3                                                      0
# gallons_3                                                    0
#
#                                                                     802  \
# sso_id                                                             5775
# inspection_key                                                   388919
# service_number                                                      NaN
# report_date                                                    12/19/15
# spill_address                                                     10800
# spill_street_name                                        ENTRANCE RD NE
# total_gallons                                                     49110
# gallons_returned                                                      0
# gallons_1                                                         21600
# spill_start_1                                     12/19/2015 1:42:00 PM
# spill_stop_1                                      12/19/2015 4:00:00 PM
# hours_1                                                             2.3
# cause                                                            Debris
# comments              Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                  MONITORED AREA
# watershed                                                  SALADO CREEK
# unit_id_1                                                         52470
# unit_id_2                                                         52677
# discharge_to                   CREEK BED  ( Spilled into Salado Creek )
# discharge_route                                            SALADO CREEK
# council_district                                                      9
# ferguson                                                          171E6
# month                                                                12
# year                                                               2015
# week                                                                 51
# edwards_zone                                                          0
# expr_1029                                                        DEBRIS
# pipe_diameter                                                        12
# pipe_length                                                      251.64
# pipe_type                                                           PVC
# installation_year                                                  1988
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                             0
# rainfall_less_3                                                       0
# spill_address_full                                 10800 NE Entrance rd
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    2
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      1.30
# response_datetime                                             19-Dec-15
# public_notice                                                     False
# time_int                                                             12
# root_cause                                                       DEBRIS
# steps_to_prevent                                     Capacity Project,
# spill_start_2                                          12/20/2015 13:30
# spill_stop_2                                           12/20/2015 16:45
# hours_2                                                            3.25
# gallons_2                                                         27510
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
#
#                                                                     809
# sso_id                                                             4773
# inspection_key                                                   387768
# service_number                                                      NaN
# report_date                                                     12/6/15
# spill_address                                                     10800
# spill_street_name                                        ENTRANCE RD NE
# total_gallons                                                     24900
# gallons_returned                                                      0
# gallons_1                                                         24750
# spill_start_1                                      12/6/2015 2:00:00 PM
# spill_stop_1                                       12/6/2015 4:45:00 PM
# hours_1                                                            2.75
# cause                                                            Debris
# comments              Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                  MONITORED AREA
# watershed                                                  SALADO CREEK
# unit_id_1                                                         52470
# unit_id_2                                                         52677
# discharge_to                   CREEK BED  ( Spilled into Salado Creek )
# discharge_route                                            SALADO CREEK
# council_district                                                      9
# ferguson                                                          171E6
# month                                                                12
# year                                                               2015
# week                                                                 50
# edwards_zone                                                          0
# expr_1029                                                        DEBRIS
# pipe_diameter                                                        12
# pipe_length                                                      251.64
# pipe_type                                                           PVC
# installation_year                                                  1988
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                             0
# rainfall_less_3                                                       0
# spill_address_full                                 10800 NE Entrance Rd
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      0.00
# response_datetime                                             06-Dec-15
# public_notice                                                     False
# time_int                                                            120
# root_cause                                                       DEBRIS
# steps_to_prevent                                     Capacity Project,
# spill_start_2                                          12/06/2015 16:45
# spill_stop_2                                           12/06/2015 17:00
# hours_2                                                            0.25
# gallons_2                                                           150
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0

# %%
df[(df.spill_address_full=='CHAPPIE JAMES WAY 00108')].T
# Out:
#                                                        84  \
# sso_id                                               6499
# inspection_key                                        NaN
# service_number                                2.51675e+06
# report_date                                      10/24/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                     2448400
# gallons_returned                                        0
# gallons_1                                      2.4484e+06
# spill_start_1                       10/24/2018 1:50:00 PM
# spill_stop_1                        10/28/2018 1:29:00 PM
# hours_1                                             95.65
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                  10
# year                                                 2018
# week                                                   43
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.79
# rainfall_less_3                                      0.49
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                     10
# num_spills_24mos                                        9
# previous_spill_24mos                            15-Oct-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               24-Oct-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        93  \
# sso_id                                               6488
# inspection_key                                        NaN
# service_number                                2.50317e+06
# report_date                                      10/15/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      642250
# gallons_returned                                      NaN
# gallons_1                                          355750
# spill_start_1                       10/15/2018 2:48:00 PM
# spill_stop_1                        10/16/2018 8:45:00 AM
# hours_1                                             17.95
# cause                                                 I/I
# comments                                              NaN
# actions                        DILUTED BY HEAVY RAINWATER
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                  10
# year                                                 2018
# week                                                   42
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            1.37
# rainfall_less_3                                      0.04
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      9
# num_spills_24mos                                        8
# previous_spill_24mos                            10-Oct-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               15-Oct-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                            10/16/2018 16:55
# spill_stop_2                             10/17/2018 08:50
# hours_2                                             15.92
# gallons_2                                          286500
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        97  \
# sso_id                                               6485
# inspection_key                                        NaN
# service_number                                2.49964e+06
# report_date                                      10/10/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                        1500
# gallons_returned                                        0
# gallons_1                                            1500
# spill_start_1                       10/10/2018 8:58:00 AM
# spill_stop_1                        10/10/2018 8:58:00 AM
# hours_1                                                 0
# cause                                                 I/I
# comments                                              NaN
# actions                        DILUTED BY HEAVY RAINWATER
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                  10
# year                                                 2018
# week                                                   41
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                               0
# rainfall_less_3                                      1.54
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      8
# num_spills_24mos                                        7
# previous_spill_24mos                            22-Sep-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               10-Oct-18
# public_notice                                       False
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       110  \
# sso_id                                               6469
# inspection_key                                        NaN
# service_number                                2.47077e+06
# report_date                                       9/22/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      495500
# gallons_returned                                      NaN
# gallons_1                                          495500
# spill_start_1                        9/22/2018 1:05:00 PM
# spill_stop_1                        9/23/2018 10:45:00 AM
# hours_1                                           21.6667
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                   9
# year                                                 2018
# week                                                   38
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            1.86
# rainfall_less_3                                      0.56
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      7
# num_spills_24mos                                        6
# previous_spill_24mos                            16-Sep-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               22-Sep-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       127  \
# sso_id                                               6462
# inspection_key                                        NaN
# service_number                                2.45879e+06
# report_date                                       9/16/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                     1323125
# gallons_returned                                        0
# gallons_1                                     1.32312e+06
# spill_start_1                        9/16/2018 5:03:00 PM
# spill_stop_1                         9/18/2018 7:50:00 AM
# hours_1                                           38.7833
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                   9
# year                                                 2018
# week                                                   38
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.75
# rainfall_less_3                                      2.51
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      6
# num_spills_24mos                                        5
# previous_spill_24mos                            22-May-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               16-Sep-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       188  \
# sso_id                                               6393
# inspection_key                                        NaN
# service_number                                2.35836e+06
# report_date                                        7/9/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                       96200
# gallons_returned                                        0
# gallons_1                                           96200
# spill_start_1                         7/9/2018 4:00:00 PM
# spill_stop_1                                    7/10/2018
# hours_1                                                 8
# cause                                                 I/I
# comments                                              NaN
# actions                       Diluted by Heavy Rain Water
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   7
# year                                                 2018
# week                                                   28
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            2.54
# rainfall_less_3                                      1.32
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      9
# num_spills_24mos                                        6
# previous_spill_24mos                            20-Dec-17
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               09-Jul-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                      NaN
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       209  \
# sso_id                                               6370
# inspection_key                                        NaN
# service_number                                2.28821e+06
# report_date                                       5/22/18
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                        1000
# gallons_returned                                        0
# gallons_1                                            1000
# spill_start_1                        5/22/2018 1:45:00 PM
# spill_stop_1                         5/22/2018 1:45:00 PM
# hours_1                                                 0
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                            1467
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                      NONE
# council_district                                      NaN
# ferguson                                            228E6
# month                                                   5
# year                                                 2018
# week                                                   21
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                               0
# rainfall_less_3                                       0.2
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      5
# num_spills_24mos                                        5
# previous_spill_24mos                            28-Mar-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               22-May-18
# public_notice                                       False
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       384  \
# sso_id                                               6205
# inspection_key                                        NaN
# service_number                                1.90694e+06
# report_date                                        8/7/17
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      421881
# gallons_returned                                        0
# gallons_1                                          421881
# spill_start_1                        8/7/2017 11:11:00 AM
# spill_stop_1                          8/8/2017 8:10:00 AM
# hours_1                                           20.9833
# cause                                                 I/I
# comments                                              NaN
# actions                       Diluted By Heavy Rain Water
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   8
# year                                                 2017
# week                                                   32
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            3.31
# rainfall_less_3                                         0
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      7
# num_spills_24mos                                        7
# previous_spill_24mos                            31-May-17
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               07-Aug-17
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       407  \
# sso_id                                               6170
# inspection_key                                        NaN
# service_number                                1.80939e+06
# report_date                                       5/31/17
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                        1000
# gallons_returned                                        0
# gallons_1                                            1000
# spill_start_1                        5/31/2017 9:15:00 AM
# spill_stop_1                         5/31/2017 9:15:00 AM
# hours_1                                                 0
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   5
# year                                                 2017
# week                                                   22
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.21
# rainfall_less_3                                      0.78
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      6
# num_spills_24mos                                        6
# previous_spill_24mos                            26-Sep-16
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               31-May-17
# public_notice                                       False
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       504  \
# sso_id                                               6062
# inspection_key                                        NaN
# service_number                                1.58214e+06
# report_date                                       12/3/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                     1880100
# gallons_returned                                        0
# gallons_1                                          751000
# spill_start_1                        12/3/2016 9:24:00 AM
# spill_stop_1                         12/4/2016 9:00:00 AM
# hours_1                                              23.6
# cause                                                 I/I
# comments                                              NaN
# actions                       Diluted By Heavy Rain Water
# watershed                                      LEON CREEK
# unit_id_1                                          462766
# unit_id_2                                            1210
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        0
# ferguson                                            228D6
# month                                                  12
# year                                                 2016
# week                                                   49
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.18
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            3.84
# rainfall_less_3                                      0.66
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      1
# num_spills_24mos                                        1
# previous_spill_24mos                                  NaN
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.60
# response_datetime                               03-Dec-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                            12/05/2016 09:30
# spill_stop_2                             12/06/2016 08:05
# hours_2                                             22.58
# gallons_2                                      1.0825e+06
# spill_start_3                            12/06/2016 15:28
# spill_stop_3                             12/07/2016 07:00
# hours_3                                             15.53
# gallons_3                                           46600
#
#                                                       564  \
# sso_id                                               6021
# inspection_key                                        NaN
# service_number                                1.49978e+06
# report_date                                       9/26/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      780000
# gallons_returned                                        0
# gallons_1                                          780000
# spill_start_1                        9/26/2016 8:45:00 AM
# spill_stop_1                        9/27/2016 10:45:00 AM
# hours_1                                                26
# cause                                                 I/I
# comments                                              NaN
# actions                        Diluted By Heavy Rainwater
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   9
# year                                                 2016
# week                                                   40
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            4.75
# rainfall_less_3                                      1.36
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      5
# num_spills_24mos                                        5
# previous_spill_24mos                            21-Aug-16
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               26-Sep-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       590  \
# sso_id                                               5990
# inspection_key                                        NaN
# service_number                                1.45257e+06
# report_date                                       8/21/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      625000
# gallons_returned                                        0
# gallons_1                                          625000
# spill_start_1                        8/21/2016 3:40:00 PM
# spill_stop_1                                    8/22/2016
# hours_1                                           8.33333
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - SPILLED INTO LEON CREEK
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   8
# year                                                 2016
# week                                                   35
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                        24.5
# pipe_length                                          7.79
# pipe_type
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.63
# rainfall_less_3                                       0.9
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      4
# num_spills_24mos                                        4
# previous_spill_24mos                            31-May-16
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               21-Aug-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                      NaN
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       595  \
# sso_id                                               5983
# inspection_key                                        NaN
# service_number                                1.44422e+06
# report_date                                       8/15/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                      399000
# gallons_returned                                        0
# gallons_1                                          399000
# spill_start_1                        8/15/2016 3:00:00 PM
# spill_stop_1                        8/16/2016 12:30:00 AM
# hours_1                                               9.5
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                            1210
# unit_id_2                                           42319
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228E6
# month                                                   8
# year                                                 2016
# week                                                   34
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                          1335
# pipe_type                                             RCP
# installation_year                                    1965
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            1.42
# rainfall_less_3                                      0.66
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      1
# num_spills_24mos                                        1
# previous_spill_24mos                                  NaN
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               15-Aug-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       653  \
# sso_id                                               5922
# inspection_key                                        NaN
# service_number                                1.30694e+06
# report_date                                       5/31/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                     2453340
# gallons_returned                                        0
# gallons_1                                           75990
# spill_start_1                        5/31/2016 5:08:00 PM
# spill_stop_1                          6/1/2016 7:02:00 AM
# hours_1                                              13.9
# cause                                                 I/I
# comments                                              NaN
# actions                        DILUTED BY HEAVY RAINWATER
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - SPILLED INTO LEON CREEK
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   5
# year                                                 2016
# week                                                   23
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            1.84
# rainfall_less_3                                      2.41
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      3
# num_spills_24mos                                        3
# previous_spill_24mos                            16-May-16
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               31-May-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                            06/01/2016 14:30
# spill_stop_2                             06/06/2016 12:30
# hours_2                                               118
# gallons_2                                     2.37735e+06
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       695
# sso_id                                               5887
# inspection_key                                        NaN
# service_number                                1.29683e+06
# report_date                                       5/16/16
# spill_address                                         108
# spill_street_name                       CHAPPIE JAMES WAY
# total_gallons                                     1527175
# gallons_returned                                        0
# gallons_1                                          117475
# spill_start_1                       5/16/2016 10:44:00 AM
# spill_stop_1                         5/17/2016 9:28:00 AM
# hours_1                                             22.73
# cause                                                 I/I
# comments                                              NaN
# actions                        DILUTED BY HEAVY RAINWATER
# watershed                                      LEON CREEK
# unit_id_1                                            1187
# unit_id_2                                            1074
# discharge_to          CREEK BED - SPILLED INTO LEON CREEK
# discharge_route                                LEON CREEK
# council_district                                      NaN
# ferguson                                            228D6
# month                                                   5
# year                                                 2016
# week                                                   21
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          54
# pipe_length                                         17.61
# pipe_type                                             CSC
# installation_year                                    1983
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.52
# rainfall_less_3                                      0.99
# spill_address_full                CHAPPIE JAMES WAY 00108
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      2
# num_spills_24mos                                        2
# previous_spill_24mos                            11-May-16
# unit_type                                          SIPHON
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               16-May-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                            05/18/2016 06:55
# spill_stop_2                             05/20/2016 14:30
# hours_2                                             55.58
# gallons_2                                      1.4097e+06
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0

# %%
df[(df.spill_address_full=='SWISS OAKS 06606')].T
# Out:
#                                                        33  \
# sso_id                                               6551
# inspection_key                                        NaN
# service_number                                2.60565e+06
# report_date                                        1/6/19
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                       48000
# gallons_returned                                        0
# gallons_1                                           48000
# spill_start_1                        1/6/2019 10:00:00 PM
# spill_stop_1                          1/7/2019 2:00:00 AM
# hours_1                                                 4
# cause                                          Structural
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   1
# year                                                 2019
# week                                                    2
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             NaN
# rainfall_less_3                                       NaN
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                     11
# num_spills_24mos                                        9
# previous_spill_24mos                            26-Dec-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               06-Jan-19
# public_notice                                       False
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        47  \
# sso_id                                               6536
# inspection_key                                        NaN
# service_number                                2.58795e+06
# report_date                                      12/16/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                       16125
# gallons_returned                                      NaN
# gallons_1                                           16125
# spill_start_1                       12/16/2018 3:30:00 PM
# spill_stop_1                        12/17/2018 2:15:00 AM
# hours_1                                             10.75
# cause                                          Structural
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                  12
# year                                                 2018
# week                                                   51
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             NaN
# rainfall_less_3                                       NaN
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      8
# num_spills_24mos                                        7
# previous_spill_24mos                            07-Dec-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               16-Dec-18
# public_notice                                       False
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        56  \
# sso_id                                               6528
# inspection_key                                        NaN
# service_number                                2.57716e+06
# report_date                                       12/7/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                     1177800
# gallons_returned                                      NaN
# gallons_1                                          630000
# spill_start_1                        12/7/2018 6:30:00 PM
# spill_stop_1                         12/8/2018 5:00:00 AM
# hours_1                                              10.5
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                  12
# year                                                 2018
# week                                                   49
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             NaN
# rainfall_less_3                                       NaN
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      7
# num_spills_24mos                                        6
# previous_spill_24mos                            22-Nov-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               07-Dec-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                            12/08/2018 17:45
# spill_stop_2                             12/09/2018 03:30
# hours_2                                              9.75
# gallons_2                                          292500
# spill_start_3                            12/09/2018 14:09
# spill_stop_3                             12/10/2018 05:00
# hours_3                                             14.85
# gallons_3                                          255300
#
#                                                        68  \
# sso_id                                               6516
# inspection_key                                        NaN
# service_number                                2.55664e+06
# report_date                                      11/22/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      165000
# gallons_returned                                      NaN
# gallons_1                                          165000
# spill_start_1                       11/22/2018 2:00:00 PM
# spill_stop_1                        11/22/2018 7:30:00 PM
# hours_1                                               5.5
# cause                                          Structural
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                  11
# year                                                 2018
# week                                                   47
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             NaN
# rainfall_less_3                                       NaN
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      6
# num_spills_24mos                                        5
# previous_spill_24mos                            20-Sep-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               22-Nov-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       115  \
# sso_id                                               6466
# inspection_key                                        NaN
# service_number                                2.46636e+06
# report_date                                       9/20/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                    13304550
# gallons_returned                                        0
# gallons_1                                     1.33046e+07
# spill_start_1                        9/20/2018 9:45:00 AM
# spill_stop_1                        11/19/2018 1:30:00 AM
# hours_1                                            620.07
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2018
# week                                                   38
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.56
# rainfall_less_3                                         0
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      5
# num_spills_24mos                                        5
# previous_spill_24mos                            10-Sep-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               20-Sep-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       135  \
# sso_id                                               6455
# inspection_key                                        NaN
# service_number                                2.45716e+06
# report_date                                       9/14/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                     1309800
# gallons_returned                                      NaN
# gallons_1                                      1.3098e+06
# spill_start_1                        9/14/2018 9:14:00 AM
# spill_stop_1                         9/18/2018 5:30:00 AM
# hours_1                                           92.2667
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2018
# week                                                   37
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                           0
# pipe_length                                         16.29
# pipe_type
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.92
# rainfall_less_3                                      0.34
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      1
# num_spills_24mos                                        1
# previous_spill_24mos                                  NaN
# unit_type                                        JUNCTION
# asset_type                                  Sewer Manhole
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               14-Sep-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       143  \
# sso_id                                               6442
# inspection_key                                        NaN
# service_number                                2.45073e+06
# report_date                                       9/10/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      232500
# gallons_returned                                      NaN
# gallons_1                                          232500
# spill_start_1                        9/10/2018 2:15:00 PM
# spill_stop_1                         9/12/2018 5:00:00 AM
# hours_1                                             38.75
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2018
# week                                                   37
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.55
# rainfall_less_3                                      3.15
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      4
# num_spills_24mos                                        4
# previous_spill_24mos                            20-Feb-17
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               10-Sep-18
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       153  \
# sso_id                                               6428
# inspection_key                                        NaN
# service_number                                 2.4471e+06
# report_date                                        9/7/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      123300
# gallons_returned                                      NaN
# gallons_1                                          123300
# spill_start_1                         9/7/2018 6:45:00 AM
# spill_stop_1                         9/7/2018 12:00:00 PM
# hours_1                                              5.25
# cause                                                 I/I
# comments                                              NaN
# actions                       DILUTED BY HEAVY RAIN WATER
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2018
# week                                                   36
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             0.9
# rainfall_less_3                                      1.26
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                     10
# num_spills_24mos                                        9
# previous_spill_24mos                            12-Aug-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               07-Sep-18
# public_notice                                        True
# time_int                                              120
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        171  \
# sso_id                                                6413
# inspection_key                                         NaN
# service_number                                 2.40832e+06
# report_date                                        8/12/18
# spill_address                                         6606
# spill_street_name                               SWISS OAKS
# total_gallons                                        75000
# gallons_returned                                       NaN
# gallons_1                                            33750
# spill_start_1                         8/12/2018 4:15:00 PM
# spill_stop_1                          8/12/2018 6:30:00 PM
# hours_1                                               2.25
# cause                                                  I/I
# comments                                               NaN
# actions                        DILUTED BY HEAVY RAIN WATER
# watershed                                       LEON CREEK
# unit_id_1                                           903060
# unit_id_2                                           903059
# discharge_to          CREEK BED  - Spilled Into Leon Creek
# discharge_route                                 LEON CREEK
# council_district                                         6
# ferguson                                             208B8
# month                                                    8
# year                                                  2018
# week                                                    33
# edwards_zone                                             0
# expr_1029                                           GREASE
# pipe_diameter                                           66
# pipe_length                                          27.15
# pipe_type                                              FRP
# installation_year                                     2014
# downstream_depth                                       NaN
# upstream_depth                                         NaN
# inches_no                                             0.42
# rainfall_less_3                                        0.2
# spill_address_full                        SWISS OAKS 06606
# sewer_asset_exp                                        NaN
# num_spills_compkey                                       9
# num_spills_24mos                                         8
# previous_spill_24mos                             09-Jul-18
# unit_type                                          OUTFALL
# asset_type                                      Sewer Main
# last_cleaned                                           NaN
# response_time                                         0.25
# response_datetime                                12-Aug-18
# public_notice                                         True
# time_int                                               120
# root_cause                                          GREASE
# steps_to_prevent                                       NaN
# spill_start_2                             08/12/2018 22:30
# spill_stop_2                              08/13/2018 01:15
# hours_2                                               2.75
# gallons_2                                            41250
# spill_start_3                                          NaN
# spill_stop_3                                           NaN
# hours_3                                                  0
# gallons_3                                                0
#
#                                                       190  \
# sso_id                                               6395
# inspection_key                                        NaN
# service_number                                2.35755e+06
# report_date                                        7/9/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      135200
# gallons_returned                                        0
# gallons_1                                          135200
# spill_start_1                         7/9/2018 3:00:00 PM
# spill_stop_1                         7/10/2018 2:00:00 AM
# hours_1                                                11
# cause                                                 I/I
# comments                                              NaN
# actions                       Diluted by Heavy Rain Water
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   7
# year                                                 2018
# week                                                   28
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            2.54
# rainfall_less_3                                      1.32
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      8
# num_spills_24mos                                        7
# previous_spill_24mos                            28-Mar-18
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               09-Jul-18
# public_notice                                        True
# time_int                                              120
# root_cause                                     RAIN EVENT
# steps_to_prevent                                      NaN
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       243  \
# sso_id                                               6345
# inspection_key                                        NaN
# service_number                                2.20841e+06
# report_date                                       3/28/18
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      112200
# gallons_returned                                      NaN
# gallons_1                                           13200
# spill_start_1                        3/28/2018 6:14:00 AM
# spill_stop_1                         3/28/2018 7:42:00 AM
# hours_1                                           1.46667
# cause                                                 I/I
# comments                                              NaN
# actions                        Diluted By Heavy Rainwater
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   3
# year                                                 2018
# week                                                   13
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            3.51
# rainfall_less_3                                      0.18
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      7
# num_spills_24mos                                        7
# previous_spill_24mos                            07-Dec-17
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               28-Mar-18
# public_notice                                        True
# time_int                                              120
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                            03/28/2018 10:00
# spill_stop_2                             03/28/2018 15:30
# hours_2                                               5.5
# gallons_2                                           99000
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       311  \
# sso_id                                               6267
# inspection_key                                        NaN
# service_number                                2.07036e+06
# report_date                                       12/7/17
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                        8950
# gallons_returned                                      NaN
# gallons_1                                            8950
# spill_start_1                       12/7/2017 10:01:00 AM
# spill_stop_1                         12/7/2017 1:00:00 PM
# hours_1                                              2.98
# cause                                                 I/I
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                  12
# year                                                 2017
# week                                                   49
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            1.06
# rainfall_less_3                                         1
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      6
# num_spills_24mos                                        6
# previous_spill_24mos                            28-Sep-17
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               07-Dec-17
# public_notice                                       False
# time_int                                              120
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       344  \
# sso_id                                               6236
# inspection_key                                        NaN
# service_number                                1.98058e+06
# report_date                                       9/28/17
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                       27500
# gallons_returned                                      NaN
# gallons_1                                           27500
# spill_start_1                        9/28/2017 9:45:00 PM
# spill_stop_1                         9/29/2017 2:20:00 AM
# hours_1                                           4.58333
# cause                                               Other
# comments                                              NaN
# actions                                    MONITORED AREA
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2017
# week                                                   39
# edwards_zone                                            0
# expr_1029                                           OTHER
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                             0.1
# rainfall_less_3                                      2.11
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      5
# num_spills_24mos                                        5
# previous_spill_24mos                            17-Sep-17
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               28-Sep-17
# public_notice                                       False
# time_int                                              120
# root_cause                                          OTHER
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       359  \
# sso_id                                               6219
# inspection_key                                        NaN
# service_number                                1.94532e+06
# report_date                                        9/5/17
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                       21752
# gallons_returned                                        0
# gallons_1                                           21752
# spill_start_1                         9/4/2017 9:45:00 PM
# spill_stop_1                         9/5/2017 12:55:00 AM
# hours_1                                           3.16667
# cause                      Other - Cause To Be Determined
# comments                                              NaN
# actions                                    Monitored Area
# watershed                                      LEON CREEK
# unit_id_1                                          903060
# unit_id_2                                          903059
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            228B1
# month                                                   9
# year                                                 2017
# week                                                   36
# edwards_zone                                            0
# expr_1029                                           OTHER
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# ...
# pipe_diameter                                          66
# pipe_length                                         27.15
# pipe_type                                             FRP
# installation_year                                    2014
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                               0
# rainfall_less_3                                      0.97
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      2
# num_spills_24mos                                        2
# previous_spill_24mos                            16-May-16
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               01-Jun-17
# public_notice                                       False
# time_int                                              120
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       453  \
# sso_id                                               6127
# inspection_key                                        NaN
# service_number                                1.67092e+06
# report_date                                       2/20/17
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      622500
# gallons_returned                                        0
# gallons_1                                          622500
# spill_start_1                        2/20/2017 7:45:00 AM
# spill_stop_1                         2/21/2017 4:30:00 AM
# hours_1                                             20.75
# cause                                                 I/I
# comments                                              NaN
# actions                        DILUTED BY HEAVY RAINWATER
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            228B1
# month                                                   2
# year                                                 2017
# week                                                    8
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.63
# rainfall_less_3                                      1.51
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      3
# num_spills_24mos                                        3
# previous_spill_24mos                            05-Dec-16
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               20-Feb-17
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                       Capacity Project,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       501  \
# sso_id                                               6081
# inspection_key                                        NaN
# service_number                                1.58829e+06
# report_date                                       12/5/16
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      407500
# gallons_returned                                        0
# gallons_1                                          407500
# spill_start_1                        12/5/2016 8:00:00 AM
# spill_stop_1                         12/6/2016 7:40:00 AM
# hours_1                                           23.6667
# cause                                                 I/I
# comments                                              NaN
# actions                            Cleanup Is In Progress
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                  12
# year                                                 2016
# week                                                   50
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            0.27
# rainfall_less_3                                      5.52
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      2
# num_spills_24mos                                        2
# previous_spill_24mos                            26-Sep-16
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               05-Dec-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                       563  \
# sso_id                                               6020
# inspection_key                                        NaN
# service_number                                1.50544e+06
# report_date                                       9/26/16
# spill_address                                        6606
# spill_street_name                              SWISS OAKS
# total_gallons                                      693750
# gallons_returned                                        0
# gallons_1                                          693750
# spill_start_1                        9/26/2016 8:00:00 AM
# spill_stop_1                        9/27/2016 11:30:00 AM
# hours_1                                              27.5
# cause                                                 I/I
# comments                                              NaN
# actions                        Diluted By Heavy Rainwater
# watershed                                      LEON CREEK
# unit_id_1                                          903059
# unit_id_2                                           71380
# discharge_to          CREEK BED - Spilled Into Leon Creek
# discharge_route                                LEON CREEK
# council_district                                        6
# ferguson                                            208B8
# month                                                   9
# year                                                 2016
# week                                                   40
# edwards_zone                                            0
# expr_1029                                      RAIN EVENT
# pipe_diameter                                          42
# pipe_length                                          1301
# pipe_type                                             RCP
# installation_year                                    1973
# downstream_depth                                      NaN
# upstream_depth                                        NaN
# inches_no                                            4.75
# rainfall_less_3                                      1.36
# spill_address_full                       SWISS OAKS 06606
# sewer_asset_exp                                       NaN
# num_spills_compkey                                      1
# num_spills_24mos                                        1
# previous_spill_24mos                                  NaN
# unit_type                                         OUTFALL
# asset_type                                     Sewer Main
# last_cleaned                                          NaN
# response_time                                        0.00
# response_datetime                               26-Sep-16
# public_notice                                        True
# time_int                                              NaN
# root_cause                                     RAIN EVENT
# steps_to_prevent                                I/I Inv,
# spill_start_2                                         NaN
# spill_stop_2                                          NaN
# hours_2                                                 0
# gallons_2                                               0
# spill_start_3                                         NaN
# spill_stop_3                                          NaN
# hours_3                                                 0
# gallons_3                                               0
#
#                                                        696
# sso_id                                                5889
# inspection_key                                         NaN
# service_number                                 1.28665e+06
# report_date                                        5/16/16
# spill_address                                         6606
# spill_street_name                               SWISS OAKS
# total_gallons                                      1349550
# gallons_returned                                         0
# gallons_1                                      1.34955e+06
# spill_start_1                         5/16/2016 2:19:00 PM
# spill_stop_1                          5/20/2016 2:30:00 PM
# hours_1                                              96.18
# cause                                                  I/I
# comments                                               NaN
# actions                         DILUTED BY HEAVY RAINWATER
# watershed                                       LEON CREEK
# unit_id_1                                           903060
# unit_id_2                                           903059
# discharge_to          CREEK BED -  SPILLED INTO LEON CREEK
# discharge_route                                 LEON CREEK
# council_district                                         6
# ferguson                                             208B8
# month                                                    5
# year                                                  2016
# week                                                    21
# edwards_zone                                             0
# expr_1029                                       RAIN EVENT
# pipe_diameter                                            0
# pipe_length                                          16.29
# pipe_type
# installation_year                                     2014
# downstream_depth                                       NaN
# upstream_depth                                         NaN
# inches_no                                             0.52
# rainfall_less_3                                       0.99
# spill_address_full                        SWISS OAKS 06606
# sewer_asset_exp                                        NaN
# num_spills_compkey                                       1
# num_spills_24mos                                         1
# previous_spill_24mos                                   NaN
# unit_type                                          OUTFALL
# asset_type                                      Sewer Main
# last_cleaned                                           NaN
# response_time                                         0.18
# response_datetime                                16-May-16
# public_notice                                         True
# time_int                                               120
# root_cause                                      RAIN EVENT
# steps_to_prevent                                 I/I Inv,
# spill_start_2                                          NaN
# spill_stop_2                                           NaN
# hours_2                                                  0
# gallons_2                                                0
# spill_start_3                                          NaN
# spill_stop_3                                           NaN
# hours_3                                                  0
# gallons_3                                                0

# %%
df1[['spill_address_full', 'unit_id_1','unit_id_2', 'unit_type', 'asset_type']]
# Out:
#         spill_address_full unit_id_1 unit_id_2 unit_type     asset_type
# 568   ENTRANCE RD NE 108/1     52742     52470   GRAVITY     Sewer Main
# 593  ENTRANCE RD N E 10800     52470     52677   GRAVITY     Sewer Main
# 726   ENTRANCE RD NE 10800    930659    930653   OUTFALL     Sewer Main
# 727   ENTRANCE RD NE 10800     52470     52677   GRAVITY     Sewer Main
# 738  10800 N E Entrance Rd     52470     52677   GRAVITY     Sewer Main
# 767   ENTRANCE RD NE 10800     52470     52677   GRAVITY     Sewer Main
# 770   ENTRANCE RD NE 108/1     52470     52677   GRAVITY     Sewer Main
# 773   ENTRANCE RD NE 10800     52470       NaN  STANDARD  Sewer Manhole
# 783   ENTRANCE RD NE 10823     52470     52677   GRAVITY     Sewer Main
# 792  10800 N E Entrance Rd     52470     52677   GRAVITY     Sewer Main
# 797   10800 ENTRANCE RD NE     52470     52677   GRAVITY     Sewer Main
# 799     STARCREST DR 11601     52470     52677   GRAVITY     Sewer Main
# 802   10800 NE Entrance rd     52470     52677   GRAVITY     Sewer Main
# 809   10800 NE Entrance Rd     52470     52677   GRAVITY     Sewer Main

# %% [markdown]
# - [ ] **TODO:** Maybe we can do some kind of clustering to group problem areas.

# %%
missing_values_row(df).head(30)

# %%
# Decided to handle missing a different way, maybe
# some feature engineering or something...
# df = handle_missing_threshold(df)

# %%
count_val('ResponseTime')

# %%
df.columns

# %% [markdown]
# _Let's remove variables that do not add information._

# %%
df = remove_columns(df, columns=['INSPKEY',
                                 'SERVNO',
                                 'REPORTDATE',
                                 'FERGUSON',
                                 'Month',
                                 'Year',
                                 'Week',
                                 'EARZ_ZONE',
                                 'DWNDPTH',
                                 'UPSDPTH',
                                 'Inches_No',
                                 'RainFall_Less3',
                                 'SewerAssetExp',
                                 'UNITID',
                                 'UNITID2',
                                 'COUNCIL_DISTRICT',
                                 'INSTYEAR',
                                 'Public Notice',
                                 'TIMEINT',
                                 'HRS_2',
                                 'GAL_2',
                                 'HRS_3',
                                 'GAL_3',
                                 'SPILL_START_2',
                                 'SPILL_STOP_2',
                                 'SPILL_START_3',
                                 'SPILL_STOP_3',
                                 'SPILL ADDRESS',
                                 'SPILL_ADDRESS',
                                 'SPILL_ST_NAME',
                                ])

# %%
df.columns

# %%
df.shape

# %%
df = fill_with_unknown(df, 'DISCHARGE_ROUTE',
                      'ACTIONS',
                      'COMMENTS',
                      'DISCHARGE_TO',
                      'Expr1029',
                      'PIPETYPE',
                      'UNITTYPE',
                      'ASSETTYPE',
                      'Root_Cause',
                      'STEPS_TO_PREVENT',
                      )

# %%
df = fill_with_median(df, 'GALSRET',
                     'HRS',
                     'PIPEDIAM',
                     'PIPELEN',
                     )

# %%
count_val('ResponseTime')

# %%
count_val('ResponseDTTM')

# %%
df = remove_columns(df, columns=['ResponseTime',
                                 'ResponseDTTM',
                                 ])

# %%
df.shape

# %%
missing_values_col(df)

# %% [markdown]
# _Let's temporarily remove the columns that needs to be feature-engineered later._

# %%
df0 = remove_columns(df, columns=['PIPETYPE',
                                  'NUM_SPILLS_24MOS',
                                  'PREVSPILL_24MOS',
                                  'UNITTYPE',
                                  'LASTCLND',
                                 ])

# %%
missing_values_col(df0)

# %%
df0.head()

# %%
df0 = df0.rename(index=str, columns={"Expr1029": "EXPR1029", "Root_Cause": "ROOT_CAUSE"})

# %%
df0.head()

# %% [markdown]
# # ANALYZE

# %%
train = df0[:'2016']
test = df0['2016':]
print(train.nunique())
print(test.nunique())

# %%
df0.head()

# %%
df0.SPILL_START = pd.to_datetime(df0.SPILL_START,infer_datetime_format=True)
df0.SPILL_STOP = pd.to_datetime(df0.SPILL_STOP,infer_datetime_format=True)

# %%
df0.head()

# %%
df0 = df0.sort_values('SPILL_START')
df0 = df0.set_index('SPILL_START')
df0.head()

# %%
by_date = df0.groupby(['SPILL_START'])['TOTAL_GAL'].sum().reset_index()
by_date.plot(x='SPILL_START', y='TOTAL_GAL');

# %%
df0.groupby(['SPILL_START']).TOTAL_GAL.sum().head()

# %%
df0.resample('A').mean()

# %%
df.shape

# %%
df0.shape

# %%
df = df0.copy()

# %%
train = df[:'2016']
test = df['2017':]
print(train.nunique())
print(test.nunique())

# %%
missing_values_col(train)

# %%
missing_values_col(test)

# %%
overflow = train.resample('D').TOTAL_GAL.mean()

# %%
overflow

# %%
overflow.plot()

# %%
overflow.resample('M').mean().plot()

# %%
overflow.resample('Q').mean().plot()

# %%
overflow.rolling(5).mean().plot(figsize=(12, 4))

# %%
overflow.diff(periods=10).plot(figsize=(12, 4))

# %%
decomposition = sm.tsa.seasonal_decompose(overflow.dropna(), model='additive', freq=12)
fig = decomposition.plot()
plt.show()

# %%
pd.plotting.lag_plot(overflow)

# %%
df_corr = pd.concat([overflow.shift(1), overflow], axis=1)
df_corr.columns = ['t-1','t+1']
result = df_corr.corr()
print(result)
