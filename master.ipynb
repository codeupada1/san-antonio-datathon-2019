# %% [markdown]
# # PLAN
#
# - [ ] Acquisition
#     - [x] read the csv into a dataframe
# - [ ] Preparation
#     - [ ] no missing values
#     - [ ] drop columns that are not needed
#     - [x] change case to lower case
#     - [ ] make sure everything has right dtype
#     - [ ] normalize what needs to be normalized
#     - [x] rename columns for clarification
# - [ ] Exploration
#     - [ ] answer ALL questions raised
#     - [ ] visualize important findings
#     - [ ] decide what TODO items to keep
# - [ ] Modeling
#     - [ ] predict
# - [ ] Delivery
#     - [ ] report
#     - [ ] prezi slides
#     - [ ] website

# %% [markdown]
# # ENVIRONMENT

# %%
import os
import acquire
import pandas as pd

# data visualization 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import statsmodels.api as sm

from datetime import timedelta, datetime
from pylab import rcParams

# %% [markdown]
# # ACQUIRE

# %% [markdown]
# _Let's read in the data from the csv file and take a peek at te first five records._

# %%
df = acquire.read_data('saws-ssos.csv')

# %%
df.head()
# Out:
#    SSO_ID   INSPKEY  SERVNO REPORTDATE  SPILL_ADDRESS     SPILL_ST_NAME  \
# 0    6582  567722.0     NaN    3/10/19           3200  THOUSAND OAKS DR
# 1    6583  567723.0     NaN    3/10/19           6804       S FLORES ST
# 2    6581  567714.0     NaN     3/9/19            215   AUDREY ALENE DR
# 3    6584  567713.0     NaN     3/9/19           3602    SE MILITARY DR
# 4    6580  567432.0     NaN     3/6/19            100          PANSY LN
#
#    TOTAL_GAL  GALSRET     GAL           SPILL_START  ...  Root_Cause  \
# 0       2100   2100.0  2100.0  3/10/2019 1:16:00 PM  ...         NaN
# 1         80      0.0    80.0  3/10/2019 2:25:00 PM  ...         NaN
# 2         79      0.0    10.0   3/9/2019 6:00:00 PM  ...         NaN
# 3         83      0.0    83.0   3/9/2019 3:37:00 PM  ...         NaN
# 4         75      0.0    75.0   3/6/2019 9:40:00 AM  ...         NaN
#
#    STEPS_TO_PREVENT     SPILL_START_2      SPILL_STOP_2 HRS_2 GAL_2  \
# 0               NaN               NaN               NaN  0.00   0.0
# 1               NaN               NaN               NaN  0.00   0.0
# 2               NaN  03/10/2019 09:36  03/10/2019 10:45  1.15  69.0
# 3               NaN               NaN               NaN  0.00   0.0
# 4               NaN               NaN               NaN  0.00   0.0
#
#   SPILL_START_3 SPILL_STOP_3 HRS_3 GAL_3
# 0           NaN          NaN   0.0   0.0
# 1           NaN          NaN   0.0   0.0
# 2           NaN          NaN   0.0   0.0
# 3           NaN          NaN   0.0   0.0
# 4           NaN          NaN   0.0   0.0
#
# [5 rows x 57 columns]

# %% [markdown]
# # PREPARE

# %%
def missing_values_col(df):
    """
    This functions returns the total missing values and
    the percent missing values by column.
    """
    null_count = df.isnull().sum()
    null_percentage = (null_count / df.shape[0]) * 100
    empty_count = pd.Series(((df == ' ') | (df == '')).sum())
    empty_percentage = (empty_count / df.shape[0]) * 100
    nan_count = pd.Series(((df == 'nan') | (df == 'NaN')).sum())
    nan_percentage = (nan_count / df.shape[0]) * 100
    return pd.DataFrame({'num_missing': null_count, 'missing_percentage': null_percentage,
                         'num_empty': empty_count, 'empty_percentage': empty_percentage,
                         'nan_count': nan_count, 'nan_percentage': nan_percentage})


def missing_values_row(df):
    """
    This functions returns the total missing values and
    the percent missing values by row.
    """
    null_count = df.isnull().sum(axis=1)
    null_percentage = (null_count / df.shape[1]) * 100
    return pd.DataFrame({'num_missing': null_count, 'percentage': null_percentage})


def handle_missing_threshold(df, prop_required_column = .3, prop_required_row = .9):
    """
    This functions removes columns and rows whose
    count of missing values exceeds threshold.
    """
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    return df


def count_values(df):
    """
    This function counts the value of columns in a dataframe.
    """
    for col in df.columns:
        n = df[col].unique().shape[0]
        col_bins = min(n, 10)
        print(f"{col}:")
        if df[col].dtype in ['int64', 'float64'] and n > 10:
            print(df[col].value_counts(bins=col_bins, sort=False))
        else:
            print(df[col].value_counts())
        print("\n")

def remove_columns(df, columns):
    return df.drop(columns=columns)


def fill_with_zeroes(df, *cols):
    """
    This functions returns the column names as input and
    return the dataframe with the
    null values in those columns replace by 0.
    """
    for col in cols:
        df[col] = df[col].fillna(0)
    return df


def fill_with_median(df, *cols):
    """
    This function fills the NaN values with
    respective median values.
    """
    for col in cols:
        df[col] = df[col].fillna(df[col].median())
    return df


def fill_with_none(df, *cols):
    """
    This function fills the NaN values with
    'None' string value.
    """
    for col in cols:
        df[col] = df[col].fillna('None')
    return df

def fill_with_unknown(df, *cols):
    """
    This functions fills the NaN values with
    'Unknown' string value.
    """
    for col in cols:
        df[col] = df[col].fillna('Unknown')
    return df

def lowercase_columm(df, *columns):
    """
    This function returns a lowercase version of the column values.
    """
    for col in columns:
        df[col] = df[col].str.lower() 
    return df

# %% [markdown]
# _Let's convert the column to lowercase to make them easier to work with._

# %%
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#    sso_id   inspkey  servno reportdate  spill_address     spill_st_name  \
# 0    6582  567722.0     NaN    3/10/19           3200  THOUSAND OAKS DR
# 1    6583  567723.0     NaN    3/10/19           6804       S FLORES ST
# 2    6581  567714.0     NaN     3/9/19            215   AUDREY ALENE DR
# 3    6584  567713.0     NaN     3/9/19           3602    SE MILITARY DR
# 4    6580  567432.0     NaN     3/6/19            100          PANSY LN
#
#    total_gal  galsret     gal           spill_start  ...  root_cause  \
# 0       2100   2100.0  2100.0  3/10/2019 1:16:00 PM  ...         NaN
# 1         80      0.0    80.0  3/10/2019 2:25:00 PM  ...         NaN
# 2         79      0.0    10.0   3/9/2019 6:00:00 PM  ...         NaN
# 3         83      0.0    83.0   3/9/2019 3:37:00 PM  ...         NaN
# 4         75      0.0    75.0   3/6/2019 9:40:00 AM  ...         NaN
#
#    steps_to_prevent     spill_start_2      spill_stop_2 hrs_2 gal_2  \
# 0               NaN               NaN               NaN  0.00   0.0
# 1               NaN               NaN               NaN  0.00   0.0
# 2               NaN  03/10/2019 09:36  03/10/2019 10:45  1.15  69.0
# 3               NaN               NaN               NaN  0.00   0.0
# 4               NaN               NaN               NaN  0.00   0.0
#
#   spill_start_3 spill_stop_3 hrs_3 gal_3
# 0           NaN          NaN   0.0   0.0
# 1           NaN          NaN   0.0   0.0
# 2           NaN          NaN   0.0   0.0
# 3           NaN          NaN   0.0   0.0
# 4           NaN          NaN   0.0   0.0
#
# [5 rows x 57 columns]

# %% [markdown]
# _Let's take a look at the missing values._

# %%
missing_values_col(df)
# Out:
#                     num_missing  missing_percentage  num_empty  \
# sso_id                        0            0.000000          0
# inspkey                     797           25.039271          0
# servno                     2715           85.296890          0
# reportdate                    0            0.000000          0
# spill_address                 0            0.000000          0
# spill_st_name                 0            0.000000          0
# total_gal                     0            0.000000          0
# galsret                     475           14.923029          0
# gal                           0            0.000000          0
# spill_start                   0            0.000000          0
# spill_stop                    0            0.000000          0
# hrs                           3            0.094251          0
# cause                         0            0.000000          0
# comments                    533           16.745209          0
# actions                       8            0.251335          0
# watershed                     0            0.000000          0
# unitid                        4            0.125668          0
# unitid2                     244            7.665724          0
# discharge_to                  4            0.125668          0
# discharge_route             827           25.981778          0
# council_district            322           10.116243          0
# ferguson                     30            0.942507          0
# month                         0            0.000000          0
# year                          0            0.000000          0
# week                          0            0.000000          0
# earz_zone                  1318           41.407477          0
# expr1029                      7            0.219918          0
# pipediam                    190            5.969211          0
# pipelen                     190            5.969211          0
# pipetype                    190            5.969211         47
# instyear                    118            3.707194          0
# dwndpth                    3183          100.000000          0
# upsdpth                    3183          100.000000          0
# inches_no                   487           15.300031          0
# rainfall_less3              542           17.027961          0
# spill address                43            1.350927          0
# sewerassetexp              3026           95.067546          0
# num_spills_compkey            0            0.000000          0
# num_spills_24mos           1677           52.686145          0
# prevspill_24mos            2582           81.118442          0
# unittype                     17            0.534087          9
# assettype                     2            0.062834          0
# lastclnd                   2082           65.409991          0
# responsetime               1934           60.760289          0
# responsedttm               1934           60.760289          0
# public notice                 0            0.000000          0
# timeint                    2393           75.180647          0
# root_cause                    7            0.219918          0
# steps_to_prevent           1737           54.571159          0
# spill_start_2              3097           97.298146          0
# spill_stop_2               3097           97.298146          0
# hrs_2                      1874           58.875275          0
# gal_2                      1873           58.843858          0
# spill_start_3              3169           99.560163          0
# spill_stop_3               3169           99.560163          0
# hrs_3                      1878           59.000943          0
# gal_3                      1878           59.000943          0
#
#                     empty_percentage  nan_count  nan_percentage
# sso_id                      0.000000          0             0.0
# inspkey                     0.000000          0             0.0
# servno                      0.000000          0             0.0
# reportdate                  0.000000          0             0.0
# spill_address               0.000000          0             0.0
# spill_st_name               0.000000          0             0.0
# total_gal                   0.000000          0             0.0
# galsret                     0.000000          0             0.0
# gal                         0.000000          0             0.0
# spill_start                 0.000000          0             0.0
# spill_stop                  0.000000          0             0.0
# hrs                         0.000000          0             0.0
# cause                       0.000000          0             0.0
# comments                    0.000000          0             0.0
# actions                     0.000000          0             0.0
# watershed                   0.000000          0             0.0
# unitid                      0.000000          0             0.0
# unitid2                     0.000000          0             0.0
# discharge_to                0.000000          0             0.0
# discharge_route             0.000000          0             0.0
# council_district            0.000000          0             0.0
# ferguson                    0.000000          0             0.0
# month                       0.000000          0             0.0
# year                        0.000000          0             0.0
# week                        0.000000          0             0.0
# earz_zone                   0.000000          0             0.0
# expr1029                    0.000000          0             0.0
# pipediam                    0.000000          0             0.0
# pipelen                     0.000000          0             0.0
# pipetype                    1.476594          0             0.0
# instyear                    0.000000          0             0.0
# dwndpth                     0.000000          0             0.0
# upsdpth                     0.000000          0             0.0
# inches_no                   0.000000          0             0.0
# rainfall_less3              0.000000          0             0.0
# spill address               0.000000          0             0.0
# sewerassetexp               0.000000          0             0.0
# num_spills_compkey          0.000000          0             0.0
# num_spills_24mos            0.000000          0             0.0
# prevspill_24mos             0.000000          0             0.0
# unittype                    0.282752          0             0.0
# assettype                   0.000000          0             0.0
# lastclnd                    0.000000          0             0.0
# responsetime                0.000000          0             0.0
# responsedttm                0.000000          0             0.0
# public notice               0.000000          0             0.0
# timeint                     0.000000          0             0.0
# root_cause                  0.000000          0             0.0
# steps_to_prevent            0.000000          0             0.0
# spill_start_2               0.000000          0             0.0
# spill_stop_2                0.000000          0             0.0
# hrs_2                       0.000000          0             0.0
# gal_2                       0.000000          0             0.0
# spill_start_3               0.000000          0             0.0
# spill_stop_3                0.000000          0             0.0
# hrs_3                       0.000000          0             0.0
# gal_3                       0.000000          0             0.0

# %% [markdown]
# _Let's look at a few of the rows._

# %%
df.head(7).T
# Out:
#                                                                     0  \
# sso_id                                                           6582
# inspkey                                                        567722
# servno                                                            NaN
# reportdate                                                    3/10/19
# spill_address                                                    3200
# spill_st_name                                        THOUSAND OAKS DR
# total_gal                                                        2100
# galsret                                                          2100
# gal                                                              2100
# spill_start                                      3/10/2019 1:16:00 PM
# spill_stop                                       3/10/2019 2:40:00 PM
# hrs                                                               1.4
# cause                                                          Grease
# comments            Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                  CLEANED MAIN
# watershed                                                SALADO CREEK
# unitid                                                          66918
# unitid2                                                         66917
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                  NaN
# ferguson                                                        172A2
# month                                                               3
# year                                                             2019
# week                                                               11
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                         16.55
# pipetype                                                          PVC
# instyear                                                         1997
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                   3200 THOUSAND OAKS DR
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.45
# responsedttm                                                10-Mar-19
# public notice                                                   False
# timeint                                                            24
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                               1  \
# sso_id                                                     6583
# inspkey                                                  567723
# servno                                                      NaN
# reportdate                                              3/10/19
# spill_address                                              6804
# spill_st_name                                       S FLORES ST
# total_gal                                                    80
# galsret                                                       0
# gal                                                          80
# spill_start                                3/10/2019 2:25:00 PM
# spill_stop                                 3/10/2019 3:45:00 PM
# hrs                                                     1.33333
# cause                                                    Grease
# comments            Spill ContainedArea Cleaned and Disinfected
# actions                                            CLEANED MAIN
# watershed                                              DOS RIOS
# unitid                                                    24250
# unitid2                                                   24193
# discharge_to                                         STORMDRAIN
# discharge_route                                            None
# council_district                                              3
# ferguson                                                  251A3
# month                                                         3
# year                                                       2019
# week                                                         11
# earz_zone                                                     0
# expr1029                                                    NaN
# pipediam                                                      8
# pipelen                                                     157
# pipetype                                                    PVC
# instyear                                                   1988
# dwndpth                                                     NaN
# upsdpth                                                     NaN
# inches_no                                                   NaN
# rainfall_less3                                              NaN
# spill address                                     6804 S FLORES
# sewerassetexp                                               NaN
# num_spills_compkey                                            1
# num_spills_24mos                                              1
# prevspill_24mos                                             NaN
# unittype                                                GRAVITY
# assettype                                            Sewer Main
# lastclnd                                                    NaN
# responsetime                                               1.08
# responsedttm                                          10-Mar-19
# public notice                                             False
# timeint                                                     120
# root_cause                                                  NaN
# steps_to_prevent                                            NaN
# spill_start_2                                               NaN
# spill_stop_2                                                NaN
# hrs_2                                                         0
# gal_2                                                         0
# spill_start_3                                               NaN
# spill_stop_3                                                NaN
# hrs_3                                                         0
# gal_3                                                         0
#
#                                                                     2  \
# sso_id                                                           6581
# inspkey                                                        567714
# servno                                                            NaN
# reportdate                                                     3/9/19
# spill_address                                                     215
# spill_st_name                                         AUDREY ALENE DR
# total_gal                                                          79
# galsret                                                             0
# gal                                                                10
# spill_start                                       3/9/2019 6:00:00 PM
# spill_stop                                        3/9/2019 7:30:00 PM
# hrs                                                               1.5
# cause                                                      Structural
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                    DOS RIOS
# unitid                                                           2822
# unitid2                                                          3351
# discharge_to                                                    ALLEY
# discharge_route                                                  None
# council_district                                                    1
# ferguson                                                        190E4
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                           350
# pipetype                                                           CP
# instyear                                                         1955
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     215 Audrey Alene Dr
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     1.00
# responsedttm                                                09-Mar-19
# public notice                                                   False
# timeint                                                            24
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                        03/10/2019 09:36
# spill_stop_2                                         03/10/2019 10:45
# hrs_2                                                            1.15
# gal_2                                                              69
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     3  \
# sso_id                                                           6584
# inspkey                                                        567713
# servno                                                            NaN
# reportdate                                                     3/9/19
# spill_address                                                    3602
# spill_st_name                                          SE MILITARY DR
# total_gal                                                          83
# galsret                                                             0
# gal                                                                83
# spill_start                                       3/9/2019 3:37:00 PM
# spill_stop                                        3/9/2019 5:00:00 PM
# hrs                                                           1.38333
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                           NaN
# watershed                                                SALADO CREEK
# unitid                                                          92804
# unitid2                                                         92805
# discharge_to                                                 EASEMENT
# discharge_route                                                  None
# council_district                                                    3
# ferguson                                                        252C3
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                        213.91
# pipetype                                                          PVC
# instyear                                                         1983
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     3602 SE MILITARY DR
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.55
# responsedttm                                                09-Mar-19
# public notice                                                   False
# timeint                                                           120
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     4  \
# sso_id                                                           6580
# inspkey                                                        567432
# servno                                                            NaN
# reportdate                                                     3/6/19
# spill_address                                                     100
# spill_st_name                                                PANSY LN
# total_gal                                                          75
# galsret                                                             0
# gal                                                                75
# spill_start                                       3/6/2019 9:40:00 AM
# spill_stop                                        3/6/2019 9:55:00 AM
# hrs                                                              0.25
# cause                                                      Structural
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                SALADO CREEK
# unitid                                                          61141
# unitid2                                                         49543
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                    2
# ferguson                                                        192A7
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                           12
# pipelen                                                         291.9
# pipetype                                                           CP
# instyear                                                         1952
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                            100 PANSY LN
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  2
# num_spills_24mos                                                    2
# prevspill_24mos                                             15-Dec-18
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.00
# responsedttm                                                06-Mar-19
# public notice                                                   False
# timeint                                                             3
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     5  \
# sso_id                                                           6579
# inspkey                                                        567274
# servno                                                            NaN
# reportdate                                                     3/5/19
# spill_address                                                    3200
# spill_st_name                                          S HACKBERRY ST
# total_gal                                                         250
# galsret                                                             0
# gal                                                               250
# spill_start                                       3/5/2019 2:22:00 PM
# spill_stop                                        3/5/2019 2:32:00 PM
# hrs                                                          0.166667
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                    DOS RIOS
# unitid                                                          38907
# unitid2                                                         26117
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                    3
# ferguson                                                        231C6
# month                                                               3
# year                                                             2019
# week                                                               10
# earz_zone                                                           0
# expr1029                                                          NaN
# pipediam                                                            8
# pipelen                                                           315
# pipetype                                                           RL
# instyear                                                         1992
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                     3200 S Hackberry St
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  2
# num_spills_24mos                                                    2
# prevspill_24mos                                             11-Apr-17
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.00
# responsedttm                                                05-Mar-19
# public notice                                                   False
# timeint                                                            12
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0
#
#                                                                     6
# sso_id                                                           6577
# inspkey                                                        567046
# servno                                                            NaN
# reportdate                                                     3/2/19
# spill_address                                                    9910
# spill_st_name                                            SUGARLOAF DR
# total_gal                                                          73
# galsret                                                             0
# gal                                                                73
# spill_start                                       3/2/2019 1:42:00 PM
# spill_stop                                        3/2/2019 2:55:00 PM
# hrs                                                           1.21667
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                 MEDIO CREEK
# unitid                                                          85120
# unitid2                                                         85363
# discharge_to                                         DRAINAGE CULVERT
# discharge_route                                                  None
# council_district                                                    4
# ferguson                                                        207A6
# month                                                               3
# year                                                             2019
# week                                                                9
# earz_zone                                                           0
# expr1029                                                       GREASE
# pipediam                                                            8
# pipelen                                                        264.47
# pipetype                                                          PVC
# instyear                                                         1985
# dwndpth                                                           NaN
# upsdpth                                                           NaN
# inches_no                                                         NaN
# rainfall_less3                                                    NaN
# spill address                                       9910 Sugarloaf Dr
# sewerassetexp                                                     NaN
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# prevspill_24mos                                                   NaN
# unittype                                                      GRAVITY
# assettype                                                  Sewer Main
# lastclnd                                                          NaN
# responsetime                                                     0.73
# responsedttm                                                02-Mar-19
# public notice                                                   False
# timeint                                                           120
# root_cause                                                     GREASE
# steps_to_prevent                                       Increase FCS,
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hrs_2                                                               0
# gal_2                                                               0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hrs_3                                                               0
# gal_3                                                               0

# %% [markdown]
# _Now let's take a peek into the value counts of the columns._

# %%
count_values(df)
# Out:
# sso_id:
# (-5.5840000000000005, 659.3]    310
# (659.3, 1317.6]                  38
# (1317.6, 1975.9]                326
# (1975.9, 2634.2]                644
# (2634.2, 3292.5]                587
# (3292.5, 3950.8]                464
# (3950.8, 4609.1]                  0
# (4609.1, 5267.4]                  6
# (5267.4, 5925.7]                157
# (5925.7, 6584.0]                651
# Name: sso_id, dtype: int64
#
#
# inspkey:
# (3724.564, 60631.5]     541
# (60631.5, 116975.0]     372
# (116975.0, 173318.5]    392
# (173318.5, 229662.0]    246
# (229662.0, 286005.5]    134
# (286005.5, 342349.0]    174
# (342349.0, 398692.5]    118
# (398692.5, 455036.0]    125
# (455036.0, 511379.5]    151
# (511379.5, 567723.0]    133
# Name: inspkey, dtype: int64
#
#
# servno:
# (274101.378, 515352.1]     18
# (515352.1, 754214.2]       14
# (754214.2, 993076.3]       72
# (993076.3, 1231938.4]      38
# (1231938.4, 1470800.5]    101
# (1470800.5, 1709662.6]     62
# (1709662.6, 1948524.7]     20
# (1948524.7, 2187386.8]     17
# (2187386.8, 2426248.9]     31
# (2426248.9, 2665111.0]     95
# Name: servno, dtype: int64
#
#
# reportdate:
# 5/25/13     27
# 5/19/16     23
# 9/26/16     22
# 6/2/16      20
# 2/3/10      17
# 9/8/10      16
# 12/3/16     15
# 8/7/17      13
# 10/24/15    10
# 3/28/18     10
# 9/7/10       9
# 5/23/15      8
# 5/16/16      8
# 4/25/15      8
# 4/17/10      8
# 9/9/18       8
# 1/15/10      8
# 2/4/10       7
# 5/24/15      7
# 2/20/17      7
# 3/20/12      7
# 6/14/15      7
# 5/17/15      7
# 9/16/18      7
# 6/25/14      7
# 9/15/18      6
# 1/16/10      6
# 9/22/18      6
# 3/4/10       6
# 7/9/18       6
#             ..
# 11/30/11     1
# 11/5/17      1
# 7/1/10       1
# 1/19/12      1
# 1/21/11      1
# 3/23/09      1
# 7/2/14       1
# 9/23/12      1
# 4/2/13       1
# 9/17/18      1
# 7/31/14      1
# 12/29/13     1
# 4/24/12      1
# 6/16/13      1
# 6/17/17      1
# 4/19/18      1
# 4/12/13      1
# 4/18/17      1
# 6/8/16       1
# 5/26/17      1
# 7/14/10      1
# 12/7/15      1
# 1/2/10       1
# 12/31/17     1
# 3/2/11       1
# 8/15/10      1
# 8/25/11      1
# 8/1/14       1
# 4/30/11      1
# 10/23/14     1
# Name: reportdate, Length: 1878, dtype: int64
#
#
# spill_address:
# (-29.622, 2962.1]     1693
# (2962.1, 5924.2]       551
# (5924.2, 8886.3]       476
# (8886.3, 11848.4]      243
# (11848.4, 14810.5]     128
# (14810.5, 17772.6]      31
# (17772.6, 20734.7]      13
# (20734.7, 23696.8]      32
# (23696.8, 26658.9]      12
# (26658.9, 29621.0]       4
# Name: spill_address, dtype: int64
#
#
# spill_st_name:
# HOLBROOK                42
# CAGNON RD               27
# CHAPPIE JAMES WAY       25
# SWISS OAKS              24
# IH 10 W                 23
# AUSTIN HWY              23
# NACOGDOCHES RD          21
# CULEBRA RD              20
# THOUSAND OAKS           20
# DONALDSON AVE           18
# ENTRANCE RD NE          17
# BANDERA RD              17
# HARRY WURZBACH          17
# LOOP 410 NW             17
# PLEASANTON RD           16
# JONES MALTSBERGER RD    15
# MISSION RD              15
# WURZBACH RD             15
# AVONDALE AVE            15
# MARBACH RD              14
# FLORES ST S             14
# YOLANDA                 14
# NEER AVE                13
# COMMERCE ST W           13
# PIEDMONT AVE            13
# BLANCO RD               12
# US HWY 281 N            12
# SAN PEDRO AVE           11
# MILITARY DR W           11
# BROADWAY                11
#                         ..
# PLUMERIA                 1
# HICKS AVE                1
# CANARIO                  1
# SONTERRA BLVD            1
# MOUNTAIN TOP             1
# PYLE                     1
# PIPERS BLF               1
# SAN AUGUSTINE S          1
# ELMENDORF N E            1
# CONTOUR DR W             1
# GOLDEN CROWN             1
# ROUND RIDGE              1
# SKYLINE BLVD             1
# WOODWARD                 1
# FOUR COLONIES            1
# MORNING OAK              1
# DAVY CROCKETT DR         1
# PIPERS FIELD             1
# AUGUSTA                  1
# BOLING BROOK             1
# MAVERICK CLIMB           1
# AULDINE DR               1
# BENDING ELMS             1
# N ALAMO ST               1
# MISSION RDG              1
# BRAUN BEND               1
# PAESANOS PKWY            1
# GORMAN ST                1
# ORSINGER LN              1
# SUNLIT BROOK             1
# Name: spill_st_name, Length: 1509, dtype: int64
#
#
# total_gal:
# (-13303.550000000001, 1330455.9]    3169
# (1330455.9, 2660910.8]                 9
# (2660910.8, 3991365.7]                 2
# (3991365.7, 5321820.6]                 1
# (5321820.6, 6652275.5]                 1
# (6652275.5, 7982730.4]                 0
# (7982730.4, 9313185.3]                 0
# (9313185.3, 10643640.2]                0
# (10643640.2, 11974095.1]               0
# (11974095.1, 13304550.0]               1
# Name: total_gal, dtype: int64
#
#
# galsret:
# (-2385.1510000000003, 238515.0]    2698
# (238515.0, 477030.0]                  5
# (477030.0, 715545.0]                  3
# (715545.0, 954060.0]                  0
# (954060.0, 1192575.0]                 0
# (1192575.0, 1431090.0]                1
# (1431090.0, 1669605.0]                0
# (1669605.0, 1908120.0]                0
# (1908120.0, 2146635.0]                0
# (2146635.0, 2385150.0]                1
# Name: galsret, dtype: int64
#
#
# gal:
# (-13303.550000000001, 1330455.9]    3175
# (1330455.9, 2660910.8]                 3
# (2660910.8, 3991365.7]                 2
# (3991365.7, 5321820.6]                 1
# (5321820.6, 6652275.5]                 1
# (6652275.5, 7982730.4]                 0
# (7982730.4, 9313185.3]                 0
# (9313185.3, 10643640.2]                0
# (10643640.2, 11974095.1]               0
# (11974095.1, 13304550.0]               1
# Name: gal, dtype: int64
#
#
# spill_start:
# 9/8/2010 6:58:00 AM       2
# 9/26/2016 8:00:00 AM      2
# 7/1/2011 12:30:00 PM      2
# 9/8/2010 4:00:00 AM       2
# 5/25/2013 1:00:00 PM      2
# 6/2/2016 6:30:00 AM       2
# 2/20/2009 2:30:00 PM      2
# 2/3/2010 3:00:00 PM       2
# 9/22/2010 1:30:00 PM      2
# 5/25/2013 7:00:00 AM      2
# 2/1/2012 1:30:00 PM       2
# 5/11/2009 3:00:00 PM      2
# 5/25/2013 12:00:00 PM     2
# 5/25/2013 9:00:00 AM      2
# 2/25/2010 3:00:00 PM      2
# 5/19/2016 11:00:00 AM     2
# 4/17/2010 11:30:00 AM     2
# 6/2/2016 5:15:00 AM       2
# 7/17/2009 7:55:00 PM      2
# 7/9/2018 3:00:00 PM       2
# 9/8/2010 11:00:00 AM      2
# 2/3/2010 10:00:00 AM      2
# 8/7/2017 9:30:00 AM       2
# 4/10/2010 1:00:00 PM      2
# 6/28/2010 11:00:00 AM     2
# 4/29/2010 9:00:00 PM      2
# 8/7/2017 1:30:00 PM       2
# 9/10/2018 4:20:00 PM      2
# 2/13/2011 11:30:00 AM     2
# 3/25/2010 9:30:00 AM      2
#                          ..
# 10/7/2009 1:46:00 PM      1
# 2/9/2014 1:32:00 PM       1
# 10/31/2013 9:09:00 AM     1
# 2/13/2019 5:28:00 AM      1
# 10/21/2016 10:45:00 AM    1
# 9/28/2010 2:00:00 PM      1
# 9/29/2012 7:30:00 PM      1
# 2/3/2010 8:00:00 AM       1
# 5/26/2014 11:53:00 AM     1
# 2/20/2018 8:54:00 AM      1
# 5/16/2016 8:10:00 AM      1
# 2/9/2012 6:00:00 PM       1
# 12/9/2015 8:34:00 AM      1
# 6/19/2015 12:25:00 PM     1
# 3/4/2010 9:30:00 AM       1
# 1/24/2011 4:00:00 PM      1
# 3/3/2010 2:00:00 PM       1
# 1/31/2019 10:35:00 AM     1
# 7/22/2009 7:00:00 AM      1
# 4/19/2011 2:45:00 PM      1
# 1/29/2012 8:15:00 PM      1
# 5/19/2016 9:13:00 AM      1
# 8/22/2017 7:55:00 PM      1
# 6/1/2009 8:00:00 AM       1
# 3/14/2018 4:00:00 PM      1
# 12/21/2012 12:16:00 PM    1
# 8/19/2014 6:56:00 AM      1
# 10/26/2016 10:05:00 AM    1
# 1/23/2019 1:42:00 PM      1
# 5/6/2016 7:52:00 PM       1
# Name: spill_start, Length: 3152, dtype: int64
#
#
# spill_stop:
# 9/26/2016 11:00:00 AM     4
# 5/25/2013 3:30:00 PM      4
# 9/8/2010 11:30:00 AM      3
# 9/26/2016 3:45:00 PM      3
# 5/24/2015 2:45:00 AM      3
# 1/24/2011 5:00:00 PM      2
# 9/26/2016 5:00:00 PM      2
# 7/30/2009 3:30:00 PM      2
# 3/21/2012 11:15:00 AM     2
# 7/11/2012 12:15:00 PM     2
# 2/20/2017 8:30:00 AM      2
# 5/26/2010 10:00:00 PM     2
# 2/3/2010 4:30:00 PM       2
# 6/6/2010 8:00:00 PM       2
# 5/11/2016 8:00:00 AM      2
# 7/17/2009 8:10:00 PM      2
# 10/25/2011 11:00:00 AM    2
# 10/30/2011 1:45:00 PM     2
# 6/25/2014 2:30:00 PM      2
# 9/26/2016 1:00:00 PM      2
# 2/14/2011 1:30:00 PM      2
# 9/26/2016 10:30:00 AM     2
# 1/13/2011 9:00:00 AM      2
# 1/11/2012 1:30:00 PM      2
# 9/8/2010 8:30:00 PM       2
# 4/25/2015 1:20:00 PM      2
# 4/22/2016 11:00:00 PM     2
# 1/26/2010 10:00:00 PM     2
# 2/9/2013 5:00:00 PM       2
# 1/27/2010 11:00:00 AM     2
#                          ..
# 4/24/2016 7:30:00 PM      1
# 7/26/2012 8:00:00 PM      1
# 2/3/2010 5:30:00 PM       1
# 7/9/2017 11:59:00 PM      1
# 3/26/2010 11:00:00 PM     1
# 2/26/2012 3:40:00 PM      1
# 5/19/2016 11:15:00 AM     1
# 10/22/2017                1
# 2/23/2015 1:45:00 PM      1
# 9/15/2010 11:00:00 PM     1
# 7/23/2014 7:30:00 PM      1
# 8/17/2017 6:00:00 PM      1
# 5/2/2009 1:00:00 AM       1
# 11/12/2017 9:40:00 PM     1
# 2/25/2015 3:30:00 PM      1
# 6/22/2016 1:50:00 AM      1
# 9/5/2018 12:50:00 PM      1
# 1/25/2010 3:00:00 PM      1
# 5/10/2012 11:00:00 PM     1
# 4/19/2016 5:00:00 AM      1
# 1/27/2018 1:40:00 PM      1
# 7/23/2010 3:40:00 PM      1
# 5/27/2010 8:00:00 PM      1
# 9/8/2010 1:00:00 PM       1
# 11/6/2009 1:30:00 PM      1
# 9/24/2018 12:43:00 PM     1
# 6/3/2016 6:30:00 PM       1
# 6/23/2018 6:30:00 PM      1
# 2/19/2018 4:45:00 PM      1
# 9/27/2010 11:15:00 AM     1
# Name: spill_stop, Length: 3133, dtype: int64
#
#
# hrs:
# (-1.797, 179.6]     3176
# (179.6, 359.2]         1
# (359.2, 538.8]         0
# (538.8, 718.4]         1
# (718.4, 898.0]         1
# (898.0, 1077.6]        0
# (1077.6, 1257.2]       0
# (1257.2, 1436.8]       0
# (1436.8, 1616.4]       0
# (1616.4, 1796.0]       1
# Name: hrs, dtype: int64
#
#
# cause:
# Grease                                                  956
# Debris                                                  479
# I/I                                                     465
# Debris/Rock                                             254
# Structural                                              244
# Rags                                                    236
# Break In Main                                           164
# Contractor                                               91
# Break in Main                                            68
# Lift Station                                             42
# Vandalism                                                38
# Other                                                    29
# Lift Station Power Out                                   29
# Roots                                                    28
# Lift Station Pump Out                                    21
# Other - Capacity                                          5
# Equipment Failure                                         5
# Plug In Main                                              4
# Break In By-Pass Line                                     3
# By-pass Pump Failure                                      3
# By-Pass Equip Failure                                     2
# Human Error                                               2
# Other - Spill Was Caused By A Surcharging Sewer Main      1
# Contractor - Contractor Damaged 8 inch Force Main         1
# Protruding Lateral                                        1
# Other - Cause To Be Determined                            1
# Broken ARV                                                1
# Lateral Repair                                            1
# Other - Obstruction In Main                               1
# Under Investigation                                       1
# By-Pass Pump Failure                                      1
# Other - Cleanout Cap Broken By Vehicular Traffic          1
# Other - Gate Valve                                        1
# Structural - Spilled From Broken Lateral                  1
# Other - Mechanical                                        1
# Structural - Broken Force Main                            1
# Lift Station - Due To Power Failure And I/I               1
# Name: cause, dtype: int64
#
#
# comments:
#  APPLIED  HTH                                                                                                          518
# APPLIED HTH                                                                                                            513
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                                      391
# Area cleaned and disinfected                                                                                           112
# Spill ContainedReturned to SystemArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                    106
# CLEANED MAIN                                                                                                            84
# REPAIRED MAIN - HTH                                                                                                     80
#  APPLIED  HTH, REPAIRED MAIN                                                                                            64
# Spill ContainedArea Cleaned and Disinfected                                                                             54
# AREA CLEANED AND DISINFECTED                                                                                            49
# Area Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,                                                      49
# Area Cleaned and Disinfected                                                                                            46
# REPAIRED MAIN                                                                                                           28
# Spill ContainedReturned to SystemArea Cleaned and Disinfected                                                           24
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O,                                                       22
# Spill Contained                                                                                                         21
# MONITORED AREA - HTH                                                                                                    21
# MONITORED AREA                                                                                                          20
# CLEANED AREA                                                                                                            19
# Spill ContainedReturned to System                                                                                       13
#  AREA CLEANED AND DISINFECTED                                                                                           11
# Diluted by heavy rain water                                                                                             10
# Spill ContainedFlushed Area with H2O, Unstopped Main,                                                                    8
# SPILL CONTAINED                                                                                                          6
# Spill ContainedReturned to SystemArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main, Unstopped Main,       6
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main, Unstopped Main,                         6
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Repaired Main,                                         5
# Spill ContainedReturned to SystemFlushed Area with H2O, Unstopped Main,                                                  4
# DILUTED BY HEAVY RAIN WATER                                                                                              4
# APPLIED  HTH                                                                                                             4
#                                                                                                                       ...
# Spill ContainedReturned to SystemArea Cleaned and Disinfected Flushed Area with H2O, Unstopped Main,                     1
#  Area cleaned and disinfected/main repaired                                                                              1
# ADJUSTED PUMPS - HEAVY RAIN                                                                                              1
# APPLIED HTH-RESTORED POWER TO LS187                                                                                      1
# BY/PASS PUMP/RUN OVER(CONTRACTOR)                                                                                        1
# RE-DIRECTED BY-PASS TUBING                                                                                               1
# Spill ContainedArea Cleaned and DisinfectedFlushed Area with H2O, Unstopped Main,  8 inch sewer main                     1
# Resealed 54" siphon boxes                                                                                                1
# APPLIED HTH - REPLACED BY-PASS HOSE                                                                                      1
# APPLIE HTH                                                                                                               1
#  REMOVED 1" X 8" X 12" BOARD FROM MAIN                                                                                   1
# REPAIRED COLLAPSED LATERAL-HTH                                                                                           1
# Spill Contained Area Cleaned and Disinfected                                                                             1
# APPLIED HTH-RESTORED POWER TO LS200                                                                                      1
# CLEANED AND MONITORED                                                                                                    1
# REPAIRED MAIN BREAK / HTH                                                                                                1
# CONSTRUCTED DAM                                                                                                          1
# REPAIRED A/R VALVE ON MAIN/HTH                                                                                           1
# HTH / REPAIRED FORCE MAIN AT LS #163                                                                                     1
# REPAIRED 8" FORCE MAIN @L/S 300                                                                                          1
# Area Cleaned and Disinfected\nRepaired main                                                                              1
# APPLIED HTH/DILUTED BY RAIN                                                                                              1
# REMOVED PLUG FROM MAIN                                                                                                   1
# Lift station 199 overflow due to heavy rain                                                                              1
# Repaired main broken by Contractor                                                                                       1
# 2nd start Time:6/6/12 7:15 to 6/6/12 15:45-Spilled into Huebner Crk - Large rocks                                        1
# REPLACED LATERAL                                                                                                         1
# REPAIRED MAIN / HTH                                                                                                      1
# PUMPED OUT/ REPLACED W/FRESH H20                                                                                         1
# CONTRACTOR LEFT MANHOLES UNBOLTED DURING HEAVY RAIN                                                                      1
# Name: comments, Length: 331, dtype: int64
#
#
# actions:
# CLEANED MAIN                                                                                                                1927
# REPAIRED MAIN                                                                                                                307
# DILUTED BY HEAVY RAIN WATER                                                                                                  116
# MONITORED AREA                                                                                                                93
# APPLIED HTH                                                                                                                   71
# DILUTED BY HEAVY RAINWATER                                                                                                    66
# CLEANED AREA                                                                                                                  52
# REPAIRED LATERAL                                                                                                              41
# CLEANED LATERAL                                                                                                               37
# RESTORED POWER                                                                                                                32
# DILUTED BY RAIN WATER                                                                                                         30
# REPAIRED PUMP                                                                                                                 27
# Diluted By Heavy Rainwater                                                                                                    24
# Cleaned Main                                                                                                                  24
# REPAIRED FORCE MAIN                                                                                                           23
# Diluted By Heavy Rain Water                                                                                                   19
# Diluted by Heavy Rainwater                                                                                                    15
# UNSTOPPED MAIN                                                                                                                13
# SET BARRICADES                                                                                                                12
# REPAIRED BROKEN MAIN                                                                                                          11
# REPAIRED HYDRORANGER                                                                                                          10
# DILUTED BY HEAVY RAINFALL                                                                                                      9
# REPAIRED A/R VALVE                                                                                                             8
#  CLEANED MAIN                                                                                                                  7
# Diluted by Heavy Rain Water                                                                                                    7
# WORK ORDER TO REPAIR MAIN                                                                                                      7
# DILUTED WITH RAIN WATER                                                                                                        7
# REPAIRED COLLAPSED MAIN                                                                                                        6
# REPAIRED BY-PASS LINE                                                                                                          6
# Cleaned Area                                                                                                                   5
#                                                                                                                             ...
# REPAIRED BY-PASS PUMP                                                                                                          1
#  Diluted By Heavy Rain Water                                                                                                   1
# CLEANUP IS ONGOING                                                                                                             1
#  The leaking section of galvanized pipe was replaced.                                                                          1
# APPLIED HTH - REPAIR CONTRACTED OUT                                                                                            1
# Honeywagon Pumped and Hauled Until Flow Receded                                                                                1
# OPENED NEARBY F/H                                                                                                              1
# Repaired Faulty Equipment                                                                                                      1
# REPAIRED 54" SIPHON MAIN                                                                                                       1
# RESET MANHOLE COVER                                                                                                            1
# MONITORED LIFT STATION                                                                                                         1
# RE-OPENED WEIR GATE                                                                                                            1
# CLEANED AND DISINFECTED AREA                                                                                                   1
# BOLTED MANHOLE LID DOWN                                                                                                        1
# REPAIRED BROKEN FORCE MAIN                                                                                                     1
# POOL WAS BEING DRAINED                                                                                                         1
# CONNECTED CNTRL SWITCH@LIFT STATION                                                                                            1
# Diluted by Fresh Water From Water Main Break                                                                                   1
# REPAIRED FITTING ON FORCE MAIN                                                                                                 1
# REMOVED PLUG FROM MAIN                                                                                                         1
# TURNED OFF AIR RELEASE VALVE                                                                                                   1
# Replaced Ball Valve and Vinyl Hose on Pump #1 - LS #225                                                                        1
# Replaced Broken Discharge Pipe on Gravity Line                                                                                 1
# APPLIE HTH                                                                                                                     1
# APPLIED HTH & REPAIRED PUMP                                                                                                    1
#  Honeywagon Pumped And Hauled Until Flow Receded And Power Was Restored To The Lift Station - Diluted By Heavy Rainwater       1
# Bypass pumping has been installed at the site                                                                                  1
# REPAIRED WATER MAIN                                                                                                            1
# REPAIRED PUMP ON BY PASS                                                                                                       1
# UNSTOPPED LATERAL                                                                                                              1
# Name: actions, Length: 148, dtype: int64
#
#
# watershed:
# DOS RIOS             1572
# SALADO CREEK          790
# LEON CREEK            668
# MEDIO CREEK           146
# CCMA (Subscriber)       4
# Salado Creek            1
# Dos Rios                1
# Leon Creek              1
# Name: watershed, dtype: int64
#
#
# unitid:
# 52470     15
# LS200     14
# 1187      13
# LS199     12
# 903059    12
# 1210      10
# LS188     10
# 47822     10
# 903060    10
# 62085     10
# LS201      8
# 11989      8
# 29988      8
# 424896     8
# 46546      7
# 499638     7
# 1465       7
# LS225      7
# LS011      7
# 31744      7
# LS192      7
# LS191      7
# 14942      7
# 9566       6
# 31088      6
# 50312      6
# 47312      6
# 48128      6
# 79943      6
# 26187      6
#           ..
# 96889      1
# 92919      1
# 17231      1
# 20804      1
# 87338      1
# 100504     1
# 10870      1
# 48456      1
# 82652      1
#  83336     1
# 97764      1
# 453487     1
# 91798      1
# 16622      1
# 97780      1
# 11792      1
# 24234      1
# 57087      1
# 74452      1
# 437183     1
# 63615      1
# 50970      1
# 46178      1
# 4580       1
# 92360      1
# 52906      1
# 13438      1
# 2804       1
# 27776      1
# 90395      1
# Name: unitid, Length: 2399, dtype: int64
#
#
# unitid2:
# 52677     13
# 1074      13
# 71380     12
# 903059    10
# 922726     9
# 46546      9
# 62088      9
# 16276      8
# 79942      8
# 424898     8
# 499663     8
# 13724      7
# 47428      7
# 1464       7
# 8715       6
# 27616      6
# 48516      6
# 48236      6
# 46257      6
# 14332      6
# 42319      6
# 50379      6
# 69866      6
# 34495      5
# 85709      5
# 47427      5
# 2386       5
# 15795      5
# 47824      5
# 52815      5
#           ..
# 16293      1
# 60229      1
# 89089      1
# 66795      1
# 4794       1
# 17225      1
# 42155      1
# 17407      1
# 58207      1
# 50969      1
# 47557      1
# 418397     1
# 35721      1
# 92146      1
# 97451      1
# 83593      1
# 539616     1
# 455033     1
# 70345      1
# 2779       1
# 7872       1
# 86036      1
# 44744      1
# 436264     1
# 99215      1
# 30332      1
# 100097     1
# 90407      1
# 79097      1
# 78948      1
# Name: unitid2, Length: 2247, dtype: int64
#
#
# discharge_to:
# STREET                                                                                         805
# DRAINAGE CULVERT                                                                               564
# GROUND                                                                                         536
# STORMDRAIN                                                                                     433
# CREEK BED                                                                                      240
# ALLEY                                                                                          177
# EASEMENT                                                                                        71
# CREEK BED - Spilled Into Leon Creek                                                             50
# CREEK BED - Spilled Into Salado Creek                                                           31
# CREEK BED - SPILLED INTO SALADO CREEK                                                           15
# CREEK BED - Spilled into Salado Creek                                                           12
# DRAINAGE CULVERT - Over The Edwards Aquifer Transition Zone                                      9
# GROUND - Over The Edwards Aquifer Recharge Zone                                                  9
# DRAINAGE CULVERT - Over The Edwards Aquifer Recharge Zone                                        6
# CREEK BED - Spilled into Leon Creek                                                              6
# CREEK BED ( Spilled into Salado Creek )                                                          6
# CREEK BED - SPILLED INTO LEON CREEK                                                              5
# CREEK BED - Spilled Into Alazan Creek                                                            5
# CREEK BED - Spilled Into Indian Creek                                                            4
# CREEK BED  ( Spilled into Salado Creek )                                                         4
# CREEK BED-SALADO CRK                                                                             4
# CREEK BED - Spilled Into Leon Creek - Over The Edwards Aquifer Contributing Zone                 4
# CREEK BED ( Spilled Into Salado Creek )                                                          4
# STREET - Over The Edwards Aquifer Recharge Zone                                                  3
# STORMDRAIN - Over The Edwards Aquifer Transition Zone                                            3
# GROUND - Over The Edwards Aquifer Contributing Zone                                              3
# CREEK BED  ( Spilled into Alazan Creek )                                                         3
# GROUND - Over The Edwards Aquifer Transition Zone                                                3
# CREEK BED - SALADO CREEK                                                                         3
# STORMDRAIN - Over The Edwards Aquifer Contributing Zone                                          3
#                                                                                               ...
# DRAINAGE CULVERT ( SPILLED INTO WALZEM CREEK )                                                   1
# Spilled Into SALADO CREEK BED                                                                    1
# GROUND (Spilled Over Edwards Aquifer Transition Zone )                                           1
# GROUND - Over The Edwards Aqifer Reharge Zone                                                    1
# DRAINAGE CULVERT - SPILLED INTO A POND VIA CULVERT                                               1
# CREEK BED ( SPILLED INO LEON CREEK )                                                             1
# STORMDRAIN - Over Edwards Aquifer Contributing Within The Transition Zone                        1
# DRAINAGE CULVERT - SPILLED INTO INDIAN CREEK                                                     1
# STORMDRAIN - Over The Edwards Auifer Transition Zone                                             1
# STREET - Over The Edwards Aquifer Contributing Zone Within The Transition Zone                   1
# CREEK BED - Spilled Into Dry Creek Bed Of Mudd Crk - Over The Edwards Aquifer Recharge Zone      1
# CREEK BED - Spilled into the Dry Potranco Creek                                                  1
# CREEK BED - Spilled Into Salado Creek - Over the Edwards Aquifer Transition Zone                 1
# DRAINAGE CULVERT - Over The Edwards Recharge Zone                                                1
# GROUND - Spilled From Customer`s Cleanout                                                        1
# CREEK BED ( Spilled into Indian Creek)                                                           1
# STORMDRAIN - Then entered the San Antonio River                                                  1
# GROUND - Spill Ran Through Golf Course Into Nearby Surface Pond                                  1
# CREEK BED  - Spilled Into Leon Creek                                                             1
# CREEK BED OF MARTINEZ CRK                                                                        1
# CREEK BED Spilled into Mud Creek                                                                 1
# CREEK BED - Spilled Into Mudd Creek - Over The Edwards Aquifer Recharge Zone                     1
# CREEK BEDSpilled into Mud Creek                                                                  1
# CREEK BED - DRY MUDD CREEK                                                                       1
# CREEK BED - SPILLED INTO ZARZAMORA CREEK                                                         1
# CREEK BED - SPILLED INTO MUD CREEK                                                               1
# DRAINAGE CULVERT - Some of spill entered Woodlawn Lake                                           1
# CREEK BED - Spilled Into Panther Springs Creek                                                   1
# DRAINAGE CULVERT - Spilled into Zarzamora Creek                                                  1
# STORMDRAIN ( Spilled into San Antonio River )                                                    1
# Name: discharge_to, Length: 171, dtype: int64
#
#
# discharge_route:
# None                         1527
# NONE                          406
# SALADO CREEK                  117
# LEON CREEK                     94
# ALAZAN CREEK                   31
# ZARZAMORA CREEK                21
# SAN ANTONIO RIVER              20
# INDIAN CREEK                   18
# HUEBNER CREEK                  11
# MUDD CREEK                     10
# ROSILLO CREEK                  10
# OLMOS CREEK                     9
# MARTINEZ CREEK                  8
# SAN PEDRO CREEK                 7
# WALZEM CREEK                    7
# WOODLAWN LAKE                   6
# DRAINAGE CREEK                  6
# SIX MILE CREEK                  5
# HARLANDALE CREEK                5
# BEITEL CREEK                    5
# APACHE CREEK                    5
# ELM CREEK                       4
# SELMA CREEK                     2
# MEDIO CREEK                     2
# POTRANCO CREEK                  2
# RITTIMAN CREEK                  2
# PANTHER SPRINGS CREEK           2
# CULEBRA CREEK                   2
# LORENCE CREEK                   2
# COMANCHE CREEK                  1
# MAYBERRY CREEK                  1
# SALADO CREEK-SALADO CREEK       1
# ELMENDORF LAKE                  1
# MILLERS POND                    1
# WEST ELM CREEK                  1
# MEDINA RIVER                    1
# ELM WATERHOLE CREEK             1
# EL DORADO LAKE                  1
# SALADO CREEK TRIBUTARY          1
# Name: discharge_route, dtype: int64
#
#
# council_district:
# (-0.011, 1.0]    477
# (1.0, 2.0]       335
# (2.0, 3.0]       329
# (3.0, 4.0]       273
# (4.0, 5.0]       214
# (5.0, 6.0]       210
# (6.0, 7.0]       287
# (7.0, 8.0]       223
# (8.0, 9.0]       232
# (9.0, 10.0]      281
# Name: council_district, dtype: int64
#
#
# ferguson:
# 208B8    22
# 651B4    19
# 192C4    19
# 581C7    18
# 615D2    17
# 210A5    16
# 171E6    16
# 192D7    15
# 616A2    15
# 582D8    15
# 209D2    14
# 582B5    14
# 209A5    12
# 228D6    12
# 228E6    12
# 651B5    12
# 192A8    12
# 192E7    12
# 248C3    12
# 582B6    12
# 646B5    12
# 231E8    11
# 581F4    11
# 584D3    11
# 583E6    11
# 171E5    10
# 171B5    10
# 231C7    10
# 210B5    10
# 615B3     9
#          ..
# 682F7     1
# 252D6     1
# 715D7     1
# 212D2     1
# 515A7     1
# 550B6     1
# 616F2     1
# 193E5     1
# 614A5     1
# 649A3     1
# 552F7     1
# 189B5     1
# 186A6     1
# 577E1     1
# 270E3     1
# 616F7     1
# 552F2     1
# 227E8     1
# 583E5     1
# 483D7     1
# 226F1     1
# 752C2     1
# 211D7     1
# 584F5     1
# 231B6     1
# 211C8     1
# 613F6     1
# 168B6     1
# 251E5     1
# 188D8     1
# Name: ferguson, Length: 1400, dtype: int64
#
#
# month:
# (0.988, 2.1]    683
# (2.1, 3.2]      253
# (3.2, 4.3]      240
# (4.3, 5.4]      333
# (5.4, 6.5]      245
# (6.5, 7.6]      159
# (7.6, 8.7]      209
# (8.7, 9.8]      305
# (9.8, 10.9]     264
# (10.9, 12.0]    492
# Name: month, dtype: int64
#
#
# year:
# (2008.989, 2010.0]    921
# (2010.0, 2011.0]      354
# (2011.0, 2012.0]      374
# (2012.0, 2013.0]      282
# (2013.0, 2014.0]      196
# (2014.0, 2015.0]      263
# (2015.0, 2016.0]      304
# (2016.0, 2017.0]      193
# (2017.0, 2018.0]      259
# (2018.0, 2019.0]       37
# Name: year, dtype: int64
#
#
# week:
# (0.947, 6.2]    459
# (6.2, 11.4]     333
# (11.4, 16.6]    276
# (16.6, 21.8]    365
# (21.8, 27.0]    344
# (27.0, 32.2]    204
# (32.2, 37.4]    274
# (37.4, 42.6]    311
# (42.6, 47.8]    279
# (47.8, 53.0]    338
# Name: week, dtype: int64
#
#
# earz_zone:
# 0.0    1747
# 5.0      67
# 1.0      16
# 3.0      16
# 4.0      12
# 2.0       7
# Name: earz_zone, dtype: int64
#
#
# expr1029:
# STRUCTURAL           1237
# GREASE                610
# DEBRIS                443
# RAIN EVENT            353
# CONTRACTOR            164
# LIFT STATION          125
# OTHER                  61
# RAIN EVENT             48
# VANDALISM              48
# VANDALISM              24
# ROOTS                  22
# LIFT STATION           15
# I/I                    12
# CONTRACTOR              8
# BY PASS PUMP LEAK       3
# OTHER                   1
# Grease                  1
# Debris                  1
# Name: expr1029, dtype: int64
#
#
# pipediam:
# (-0.067, 6.6]     187
# (6.6, 13.2]      2411
# (13.2, 19.8]      115
# (19.8, 26.4]       78
# (26.4, 33.0]       26
# (33.0, 39.6]       24
# (39.6, 46.2]       36
# (46.2, 52.8]       53
# (52.8, 59.4]       45
# (59.4, 66.0]       18
# Name: pipediam, dtype: int64
#
#
# pipelen:
# (-11.69, 1168.935]       2944
# (1168.935, 2337.87]        31
# (2337.87, 3506.805]         8
# (3506.805, 4675.74]         5
# (4675.74, 5844.675]         1
# (5844.675, 7013.61]         1
# (7013.61, 8182.545]         0
# (8182.545, 9351.48]         1
# (9351.48, 10520.415]        0
# (10520.415, 11689.35]       2
# Name: pipelen, dtype: int64
#
#
# pipetype:
# PVC         968
# VCP         908
# CT          280
# HDPE        215
# CP          191
# RCP         162
# CAS          68
# DIP          63
#              47
# RL           35
# FRP          26
# CSC          14
# XXX           7
# AC            5
# SMARTLID      2
# BR            1
# PICK BAR      1
# Name: pipetype, dtype: int64
#
#
# instyear:
# (1890.8990000000001, 2709.0]    3049
# (2709.0, 3519.0]                   0
# (3519.0, 4329.0]                   0
# (4329.0, 5139.0]                   0
# (5139.0, 5949.0]                   0
# (5949.0, 6759.0]                   0
# (6759.0, 7569.0]                   0
# (7569.0, 8379.0]                   0
# (8379.0, 9189.0]                   0
# (9189.0, 9999.0]                  16
# Name: instyear, dtype: int64
#
#
# dwndpth:
# Series([], Name: dwndpth, dtype: int64)
#
#
# upsdpth:
# Series([], Name: upsdpth, dtype: int64)
#
#
# inches_no:
# (-0.010870000000000001, 0.987]    2301
# (0.987, 1.974]                     149
# (1.974, 2.961]                     128
# (2.961, 3.948]                      58
# (3.948, 4.935]                      32
# (4.935, 5.922]                       0
# (5.922, 6.909]                       1
# (6.909, 7.896]                       0
# (7.896, 8.883]                       0
# (8.883, 9.87]                       27
# Name: inches_no, dtype: int64
#
#
# rainfall_less3:
# (-0.0133, 1.227]    2232
# (1.227, 2.454]       247
# (2.454, 3.681]       106
# (3.681, 4.908]        33
# (4.908, 6.135]        11
# (6.135, 7.362]         5
# (7.362, 8.589]         0
# (8.589, 9.816]         0
# (9.816, 11.043]        2
# (11.043, 12.27]        5
# Name: rainfall_less3, dtype: int64
#
#
# spill address:
# SWISS OAKS 06606                                                19
# CHAPPIE JAMES WAY 00108                                         15
# HOLBROOK 00668                                                  10
# HARRY WURZBACH 01427                                             9
# MOREY RD 05410                                                   8
# CAGNON RD 055/1                                                  7
# STARCREST DR 114/1                                               7
# CHAPPIE JAMES WAY 00100                                          7
# THOUSAND OAKS 03947                                              7
# YOLANDA 00111                                                    7
# CAGNON RD 06785                                                  7
# NEW VALLEY HI DR 00874                                           6
# IRA LEE RD 00302                                                 6
# US HWY 90 W 10102                                                6
# HOLBROOK 00700                                                   6
# CULEBRA RD 02627                                                 5
# MARTINEZ LOSOYA 01612                                            5
# AVONDALE AVE 00755                                               5
# CENTO DR 00642                                                   5
# CAGNON RD 067/1                                                  5
# KIM VALLEY DR 05802                                              5
# QUINTANA RD 07703                                                5
# CAGNON RD 06305                                                  5
# FIVE IRON 11335                                                  5
# POTRANCO RD 09765                                                5
# YOLANDA 00107                                                    4
# MANOR DR 00908                                                   4
# ROSE VALLEY 06102                                                4
# ENTRANCE RD NE 10800                                             4
# NEW VALLEY HI DR 008/1                                           4
#                                                                 ..
# 25545 Two Spgs - Over The Edwards Aquifer Contributing Zone      1
# 171 E Amber Place                                                1
# 10402 WALNUT CREST                                               1
# INGRAM RD 06844                                                  1
# Hunt Ln 1200                                                     1
# LOMBRANO ST 01253                                                1
# 9800 WURZBACH RD - OVER THE EDWARDS AQUIFER RECHARGE ZONE        1
# LOOP 410 NW 074/1                                                1
# RAY ELLISON BLVD 09603                                           1
# 5243 VILLAGE GLEN DR                                             1
# Janis Rae 126                                                    1
# 1215 Pasadena In Rear Of Address                                 1
# 2006 RIO SAMBA - Over The Edwards Aquifer Recharge Zone          1
# WETMORE KNOLL 03830                                              1
# 4727 COMMERCE ST W FROM CLEAN-OUT IN FRONT OF H&R BLOCK          1
# 6418 Eckhert RD                                                  1
# 207 W High Ave                                                   1
# 2606 Wagonwheel                                                  1
# STORY LN 00105                                                   1
# 7431 ELDERBERRY - (OVER THE EDWARDS AQUIFER TRANSITION ZONE)     1
# 122 JANIS RAE                                                    1
# 125 San Gabriel S                                                1
# 450 S Acme Rd                                                    1
# 3807 VALENCIA PT (Over the Edwards Aquifer Recharge Zone)        1
# 143 Richland Hills                                               1
# CANARIO ST 011/1                                                 1
# 532 W Mayfield Blvd                                              1
# 7302 Westshire In Back                                           1
# 710 NW 36th st                                                   1
# 123 PAMELA                                                       1
# Name: spill address, Length: 2800, dtype: int64
#
#
# sewerassetexp:
# 04-Feb-13    38
# 28-May-13    14
# 18-Nov-11    12
# 13-May-13    11
# 12-Aug-13    10
# 15-Apr-13     9
# 20-May-13     8
# 01-Mar-11     7
# 07-Jun-13     7
# 09-Oct-09     6
# 25-Mar-13     6
# 03-Nov-11     4
# 17-Jun-13     4
# 24-Jun-13     3
# 22-Jul-13     3
# 15-May-13     3
# 25-Oct-11     2
# 08-Jul-13     1
# 13-Feb-13     1
# 18-Aug-11     1
# 01-Jul-13     1
# 28-Aug-12     1
# 28-Jun-11     1
# 09-Sep-13     1
# 12-Mar-13     1
# 27-Jun-13     1
# 19-Jul-13     1
# Name: sewerassetexp, dtype: int64
#
#
# num_spills_compkey:
# (0.979, 3.0]    2840
# (3.0, 5.0]       179
# (5.0, 7.0]        80
# (7.0, 9.0]        35
# (9.0, 11.0]        9
# (11.0, 13.0]      28
# (13.0, 15.0]       0
# (15.0, 17.0]       2
# (17.0, 19.0]       4
# (19.0, 21.0]       6
# Name: num_spills_compkey, dtype: int64
#
#
# num_spills_24mos:
# (0.987, 2.2]    1325
# (2.2, 3.4]        75
# (3.4, 4.6]        32
# (4.6, 5.8]        27
# (5.8, 7.0]        31
# (7.0, 8.2]         7
# (8.2, 9.4]         5
# (9.4, 10.6]        1
# (10.6, 11.8]       1
# (11.8, 13.0]       2
# Name: num_spills_24mos, dtype: int64
#
#
# prevspill_24mos:
# 26-Sep-16    11
# 19-May-16    10
# 25-May-13     7
# 17-May-15     6
# 02-Jun-16     6
# 16-May-16     6
# 25-Apr-15     5
# 28-Mar-18     5
# 09-Jul-18     5
# 20-Feb-17     5
# 17-Apr-10     5
# 03-Dec-16     5
# 11-May-16     5
# 07-Aug-17     4
# 08-Sep-10     4
# 22-Sep-18     4
# 26-Oct-09     3
# 03-Feb-10     3
# 05-Dec-16     3
# 23-May-15     3
# 25-Jun-14     3
# 04-Nov-14     3
# 15-Jan-10     3
# 24-Oct-15     3
# 07-Sep-10     3
# 31-May-16     3
# 09-Oct-11     3
# 15-Aug-16     3
# 19-Jun-15     3
# 24-Apr-15     3
#              ..
# 14-Jul-12     1
# 14-Aug-18     1
# 02-Aug-09     1
# 07-Feb-09     1
# 04-Aug-12     1
# 07-Jan-09     1
# 04-Jun-13     1
# 10-Sep-08     1
# 22-Jan-13     1
# 25-May-15     1
# 19-May-10     1
# 21-Apr-16     1
# 30-Apr-13     1
# 02-Feb-11     1
# 06-Oct-09     1
# 03-Sep-10     1
# 16-May-09     1
# 02-Sep-10     1
# 05-May-13     1
# 06-Jan-11     1
# 06-Jun-11     1
# 22-Jun-15     1
# 22-Sep-13     1
# 13-Mar-11     1
# 16-Dec-18     1
# 05-Sep-11     1
# 11-Jun-08     1
# 04-Mar-10     1
# 14-Jul-09     1
# 24-Apr-10     1
# Name: prevspill_24mos, Length: 442, dtype: int64
#
#
# unittype:
# GRAVITY       2508
# OUTFALL        222
# SIPHON         144
# ABOVE           83
# LATERAL         57
# SUBMERSED       51
# FORCE           44
# STANDARD        29
#                  9
# A/R              6
# OUT SIPHON       2
# JUNCTION         2
# IN SIPHON        2
# TANKHOLDIN       2
# PMPCENTSP        2
# OTHER            1
# SLUDGE           1
# PMPSUBM          1
# Name: unittype, dtype: int64
#
#
# assettype:
# Sewer Main               2925
# Sewer Lift Station        108
# Sewer Service Line         62
# Sewer Manhole              34
# Sewer Liftstation          30
# Sewer Valve                 7
# Sewer Treatment Plant       3
# Sewer Pump                  3
# Sewer Node                  3
# Plant Equipment             2
# Sewer Miscellaneous         1
# Bypass                      1
# Sewer Force Main            1
# BYPASS LINE                 1
# Name: assettype, dtype: int64
#
#
# lastclnd:
# 23-Sep-09    6
# 11-May-12    5
# 22-Aug-09    5
# 22-Oct-09    5
# 18-Apr-09    4
# 23-Nov-09    4
# 29-Feb-12    4
# 19-Jun-13    4
# 07-Jan-10    4
# 07-Dec-09    4
# 01-Jun-10    4
# 20-Oct-09    4
# 28-Dec-09    4
# 25-Nov-09    4
# 19-Feb-10    3
# 22-Nov-13    3
# 03-Oct-11    3
# 09-Aug-10    3
# 17-Mar-11    3
# 25-Mar-11    3
# 17-Dec-09    3
# 24-Jun-09    3
# 10-Oct-09    3
# 08-Apr-10    3
# 19-Oct-11    3
# 19-Nov-12    3
# 12-Aug-10    3
# 21-Sep-10    3
# 04-Oct-10    3
# 17-Oct-13    3
#             ..
# 02-Oct-09    1
# 12-Aug-11    1
# 22-Aug-12    1
# 28-Nov-12    1
# 23-Jun-14    1
# 02-May-11    1
# 05-Apr-10    1
# 15-Sep-12    1
# 28-Dec-12    1
# 21-Aug-11    1
# 15-Jun-10    1
# 02-Jul-10    1
# 10-Apr-11    1
# 18-Feb-12    1
# 03-Apr-10    1
# 09-Jan-13    1
# 09-Jul-12    1
# 18-Aug-10    1
# 19-Sep-10    1
# 24-Aug-11    1
# 05-May-11    1
# 29-Dec-13    1
# 29-Mar-12    1
# 10-Aug-13    1
# 01-Jul-13    1
# 29-Sep-09    1
# 09-Sep-09    1
# 17-Nov-11    1
# 10-Mar-15    1
# 04-May-14    1
# Name: lastclnd, Length: 796, dtype: int64
#
#
# responsetime:
# 0.00      374
# 0.50       19
# 0.60       17
# 0.78       17
# 0.43       16
# 0.58       16
# 0.45       16
# 0.55       15
# 0.25       15
# 0.42       15
# 0.53       14
# 0.62       14
# 0.85       13
# 0.67       13
# 0.65       13
# 0.70       12
# 0.63       12
# 0.83       12
# 0.40       12
# 0.37       12
# 0.57       12
# 0.68       12
# 0.28       12
# 0.52       11
# 0.48       11
# 0.47       11
# 0.75       11
# 0.23       11
# 0.18       10
# 0.08       10
#          ...
# 2.50        1
# 1.60        1
# 4.17        1
# 1.90        1
# 2.40        1
# 2.65        1
# 1.65        1
# 6.68        1
# -0.13       1
# -14.72      1
# -0.25       1
# 3.55        1
# 2.18        1
# 5.03        1
# 3.73        1
# 8.53        1
# 1.05        1
# 4.72        1
# 4.10        1
# 3.95        1
# 7.10        1
# -12.00      1
# 1.68        1
# 3.62        1
# 3.40        1
# 1.98        1
# 2.43        1
# 3.93        1
# 4.33        1
# 15.12       1
# Name: responsetime, Length: 209, dtype: int64
#
#
# responsedttm:
# 26-Sep-16    23
# 19-May-16    23
# 02-Jun-16    20
# 03-Dec-16    15
# 07-Aug-17    13
# 28-Mar-18    10
# 24-Oct-15    10
# 14-Jun-15     9
# 24-May-15     8
# 16-May-16     8
# 23-May-15     8
# 17-May-15     8
# 09-Sep-18     8
# 25-Apr-15     8
# 20-Feb-17     7
# 16-Sep-18     7
# 15-Sep-18     6
# 25-Jun-14     6
# 18-Apr-16     6
# 21-Aug-16     6
# 09-Jul-18     6
# 22-Sep-18     6
# 11-May-16     5
# 31-May-16     5
# 19-Jun-15     5
# 04-Sep-18     5
# 03-Jun-16     5
# 10-Mar-15     5
# 10-Sep-18     5
# 05-Dec-16     4
#              ..
# 27-Mar-17     1
# 01-Aug-17     1
# 17-Sep-18     1
# 03-Jul-18     1
# 12-Jun-14     1
# 31-Dec-13     1
# 13-Nov-14     1
# 07-Feb-15     1
# 07-Apr-15     1
# 27-Jan-15     1
# 09-Aug-16     1
# 02-Feb-19     1
# 10-Mar-17     1
# 23-Oct-14     1
# 25-Feb-15     1
# 31-Oct-15     1
# 26-Feb-14     1
# 09-Dec-17     1
# 30-Jan-17     1
# 01-May-15     1
# 26-Sep-17     1
# 22-Jul-15     1
# 05-Dec-18     1
# 23-Jan-17     1
# 05-Oct-18     1
# 09-Jun-14     1
# 06-Jul-18     1
# 31-May-17     1
# 14-May-14     1
# 26-Apr-15     1
# Name: responsedttm, Length: 780, dtype: int64
#
#
# public notice:
# False    3031
# True      152
# Name: public notice, dtype: int64
#
#
# timeint:
# 120.0    321
# 12.0     169
# 24.0     165
# 6.0       63
# 3.0       37
# 60.0      23
# 1.0       12
# Name: timeint, dtype: int64
#
#
# root_cause:
# STRUCTURAL           1237
# GREASE                610
# DEBRIS                443
# RAIN EVENT            353
# CONTRACTOR            164
# LIFT STATION          125
# OTHER                  61
# RAIN EVENT             48
# VANDALISM              48
# VANDALISM              24
# ROOTS                  22
# LIFT STATION           15
# I/I                    12
# CONTRACTOR              8
# BY PASS PUMP LEAK       3
# OTHER                   1
# Grease                  1
# Debris                  1
# Name: root_cause, dtype: int64
#
#
# steps_to_prevent:
# Increase FCS,         470
# Point Repair,         280
# Design Request,       201
# Other                 195
# I/I Inv,              144
# Capacity Project,     114
# Bolt down,             24
# ED/COM,                11
# RPC,                    7
# Name: steps_to_prevent, dtype: int64
#
#
# spill_start_2:
# 06/02/2016 20:00    2
# 09/16/2018 15:05    1
# 06/03/2016 19:26    1
# 06/01/2016 14:30    1
# 10/15/2018 10:00    1
# 08/29/2018 09:07    1
# 09/30/2012 13:00    1
# 06/02/2016 08:40    1
# 10/31/2015 07:45    1
# 09/21/2018 14:00    1
# 06/07/2013 17:30    1
# 03/28/2018 10:00    1
# 03/20/2012 09:00    1
# 04/30/2015 20:07    1
# 04/25/2015 12:10    1
# 05/29/2015 13:25    1
# 11/09/2016 07:45    1
# 03/10/2019 09:36    1
# 01/18/2017 11:20    1
# 05/31/2015 16:00    1
# 04/25/2015 10:00    1
# 01/03/2016 12:45    1
# 05/31/2016 17:02    1
# 01/04/2016 10:05    1
# 04/25/2015 15:24    1
# 11/02/2013 09:47    1
# 05/19/2016 11:21    1
# 09/23/2018 14:42    1
# 04/25/2015 05:31    1
# 02/23/2018 12:37    1
#                    ..
# 01/10/2016 13:20    1
# 12/05/2016 09:30    1
# 05/12/2016 00:00    1
# 04/26/2016 19:19    1
# 11/07/2014 08:30    1
# 09/05/2018 11:45    1
# 12/08/2018 17:45    1
# 01/31/2016 22:45    1
# 11/21/2014 17:50    1
# 12/24/2015 16:30    1
# 11/28/2015 14:45    1
# 03/25/2014 16:15    1
# 07/24/2018 13:30    1
# 03/05/2017 16:05    1
# 09/26/2016 22:15    1
# 04/07/2018 09:17    1
# 04/25/2017 10:45    1
# 02/18/2018 11:10    1
# 08/28/2012 07:30    1
# 08/01/2018 09:43    1
# 01/24/2016 13:37    1
# 12/27/2015 17:57    1
# 11/30/2018 11:35    1
# 09/16/2018 08:03    1
# 03/28/2018 21:45    1
# 05/31/2016 22:05    1
# 06/02/2018 09:18    1
# 03/28/2018 18:28    1
# 05/18/2016 06:55    1
# 09/23/2018 10:51    1
# Name: spill_start_2, Length: 85, dtype: int64
#
#
# spill_stop_2:
# 03/29/2018 02:45    1
# 06/01/2016 07:20    1
# 12/08/2018 00:00    1
# 06/01/2015 02:30    1
# 06/04/2016 00:00    1
# 08/29/2018 09:07    1
# 06/02/2018 10:49    1
# 03/29/2018 03:00    1
# 05/16/2016 12:00    1
# 05/31/2016 23:45    1
# 04/25/2017 15:00    1
# 06/02/2016 23:30    1
# 05/26/2013 18:00    1
# 09/16/2018 20:00    1
# 04/30/2015 21:10    1
# 12/24/2015 20:00    1
# 06/03/2016 14:10    1
# 12/06/2015 17:00    1
# 09/17/2018 04:00    1
# 06/06/2012 15:45    1
# 11/21/2014 19:30    1
# 02/23/2018 21:40    1
# 05/29/2015 16:41    1
# 04/26/2016 20:10    1
# 10/24/2015 12:15    1
# 12/11/2018 11:57    1
# 10/01/2012 04:00    1
# 11/01/2015 00:42    1
# 11/28/2015 21:30    1
# 12/09/2018 03:30    1
#                    ..
# 06/07/2013 18:30    1
# 09/27/2016 07:30    1
# 11/09/2016 13:00    1
# 02/18/2018 12:00    1
# 12/06/2016 08:05    1
# 05/12/2016 07:15    1
# 05/20/2016 14:30    1
# 05/15/2012 10:15    1
# 11/30/2015 01:40    1
# 03/10/2019 10:45    1
# 12/27/2015 18:30    1
# 01/17/2016 16:26    1
# 11/02/2013 10:45    1
# 04/07/2018 11:00    1
# 04/25/2015 20:45    1
# 06/03/2016 11:23    1
# 04/25/2015 18:10    1
# 06/03/2016 04:22    1
# 12/06/2016 03:40    1
# 01/04/2016 10:30    1
# 08/26/2016 10:30    1
# 09/21/2018 21:45    1
# 07/24/2018 14:30    1
# 05/16/2016 14:40    1
# 04/25/2015 11:41    1
# 08/01/2018 10:05    1
# 04/25/2015 23:30    1
# 09/23/2018 22:57    1
# 10/16/2018 03:00    1
# 01/18/2017 14:25    1
# Name: spill_stop_2, Length: 86, dtype: int64
#
#
# hrs_2:
# (-0.119, 11.8]    1291
# (11.8, 23.6]        15
# (23.6, 35.4]         0
# (35.4, 47.2]         1
# (47.2, 59.0]         1
# (59.0, 70.8]         0
# (70.8, 82.6]         0
# (82.6, 94.4]         0
# (94.4, 106.2]        0
# (106.2, 118.0]       1
# Name: hrs_2, dtype: int64
#
#
# gal_2:
# (-2377.351, 237735.0]     1300
# (237735.0, 475470.0]         5
# (475470.0, 713205.0]         1
# (713205.0, 950940.0]         0
# (950940.0, 1188675.0]        1
# (1188675.0, 1426410.0]       2
# (1426410.0, 1664145.0]       0
# (1664145.0, 1901880.0]       0
# (1901880.0, 2139615.0]       0
# (2139615.0, 2377350.0]       1
# Name: gal_2, dtype: int64
#
#
# spill_start_3:
# 12/09/2018 14:09    1
# 06/02/2016 12:00    1
# 10/12/2018 08:00    1
# 06/03/2016 16:00    1
# 10/25/2018 11:59    1
# 01/24/2016 22:10    1
# 06/10/2013 11:30    1
# 12/28/2015 14:47    1
# 03/21/2012 08:40    1
# 09/27/2016 13:30    1
# 11/22/2014 22:05    1
# 10/29/2018 21:20    1
# 12/06/2016 15:28    1
# 01/04/2016 16:55    1
# Name: spill_start_3, dtype: int64
#
#
# spill_stop_3:
# 06/03/2016 20:00    1
# 12/10/2018 05:00    1
# 03/21/2012 11:15    1
# 01/04/2016 19:00    1
# 12/28/2015 15:25    1
# 06/02/2016 12:05    1
# 10/30/2018 02:50    1
# 01/24/2016 23:38    1
# 10/25/2018 17:30    1
# 11/23/2014 03:05    1
# 09/27/2016 15:00    1
# 06/10/2013 13:00    1
# 12/07/2016 07:00    1
# 10/12/2018 12:02    1
# Name: spill_stop_3, dtype: int64
#
#
# hrs_3:
# (-0.0165, 1.553]    1295
# (1.553, 3.106]         2
# (3.106, 4.659]         2
# (4.659, 6.212]         3
# (6.212, 7.765]         1
# (7.765, 9.318]         0
# (9.318, 10.871]        0
# (10.871, 12.424]       0
# (12.424, 13.977]       0
# (13.977, 15.53]        2
# Name: hrs_3, dtype: int64
#
#
# gal_3:
# (-255.30100000000002, 25530.0]    1300
# (25530.0, 51060.0]                   3
# (51060.0, 76590.0]                   1
# (76590.0, 102120.0]                  0
# (102120.0, 127650.0]                 0
# (127650.0, 153180.0]                 0
# (153180.0, 178710.0]                 0
# (178710.0, 204240.0]                 0
# (204240.0, 229770.0]                 0
# (229770.0, 255300.0]                 1
# Name: gal_3, dtype: int64

# %% [markdown]
# _Let's rename the columns for clarity._

# %%
df = df.rename(index=str, columns={'inspkey':'inspection_key',
                                   'servno':'service_number',
                                   'reportdate':'report_date',
                                   'spill_st_name':'spill_street_name',
                                   'total_gal':'total_gallons',
                                   'galsret':'gallons_returned',
                                   'gal':'gallons_1',
                                   'spill_start':'spill_start_1',
                                   'spill_stop':'spill_stop_1',
                                   'hrs':'hours_1',
                                   'unitid':'unit_id_1',
                                   'unitid2':'unit_id_2',
                                   'earz_zone':'edwards_zone',
                                   'expr1029':'expr_1029',
                                   'pipediam':'pipe_diameter',
                                   'pipelen':'pipe_length',
                                   'pipetype':'pipe_type',
                                   'instyear':'installation_year',
                                   'dwndpth':'downstream_depth',
                                   'upsdpth':'upstream_depth',
                                   'rainfall_less3':'rainfall_less_3',
                                   'spill address': 'spill_address_full',
                                   'sewerassetexp':'sewer_asset_exp',
                                   'prevspill_24mos':'previous_spill_24mos',
                                   'unittype':'unit_type',
                                   'assettype':'asset_type',
                                   'lastclnd':'last_cleaned',
                                   'responsetime':'response_time',
                                   'responsedttm':'response_datetime',
                                   'public notice':'public_notice',
                                   'timeint':'time_int',
                                   'hrs_2':'hours_2',
                                   'gal_2':'gallons_2',
                                   'hrs_3':'hours_3',
                                   'gal_3':'gallons_3'
                                   })

# %%
df.head(4).T
# Out:
#                                                                       0  \
# sso_id                                                             6582
# inspection_key                                                   567722
# service_number                                                      NaN
# report_date                                                     3/10/19
# spill_address                                                      3200
# spill_street_name                                      THOUSAND OAKS DR
# total_gallons                                                      2100
# gallons_returned                                                   2100
# gallons_1                                                          2100
# spill_start_1                                      3/10/2019 1:16:00 PM
# spill_stop_1                                       3/10/2019 2:40:00 PM
# hours_1                                                             1.4
# cause                                                            Grease
# comments              Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                    CLEANED MAIN
# watershed                                                  SALADO CREEK
# unit_id_1                                                         66918
# unit_id_2                                                         66917
# discharge_to                                                     STREET
# discharge_route                                                    None
# council_district                                                    NaN
# ferguson                                                          172A2
# month                                                                 3
# year                                                               2019
# week                                                                 11
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                       16.55
# pipe_type                                                           PVC
# installation_year                                                  1997
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                3200 THOUSAND OAKS DR
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      0.45
# response_datetime                                             10-Mar-19
# public_notice                                                     False
# time_int                                                             24
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
#
#                                                                 1  \
# sso_id                                                       6583
# inspection_key                                             567723
# service_number                                                NaN
# report_date                                               3/10/19
# spill_address                                                6804
# spill_street_name                                     S FLORES ST
# total_gallons                                                  80
# gallons_returned                                                0
# gallons_1                                                      80
# spill_start_1                                3/10/2019 2:25:00 PM
# spill_stop_1                                 3/10/2019 3:45:00 PM
# hours_1                                                   1.33333
# cause                                                      Grease
# comments              Spill ContainedArea Cleaned and Disinfected
# actions                                              CLEANED MAIN
# watershed                                                DOS RIOS
# unit_id_1                                                   24250
# unit_id_2                                                   24193
# discharge_to                                           STORMDRAIN
# discharge_route                                              None
# council_district                                                3
# ferguson                                                    251A3
# month                                                           3
# year                                                         2019
# week                                                           11
# edwards_zone                                                    0
# expr_1029                                                     NaN
# pipe_diameter                                                   8
# pipe_length                                                   157
# pipe_type                                                     PVC
# installation_year                                            1988
# downstream_depth                                              NaN
# upstream_depth                                                NaN
# inches_no                                                     NaN
# rainfall_less_3                                               NaN
# spill_address_full                                  6804 S FLORES
# sewer_asset_exp                                               NaN
# num_spills_compkey                                              1
# num_spills_24mos                                                1
# previous_spill_24mos                                          NaN
# unit_type                                                 GRAVITY
# asset_type                                             Sewer Main
# last_cleaned                                                  NaN
# response_time                                                1.08
# response_datetime                                       10-Mar-19
# public_notice                                               False
# time_int                                                      120
# root_cause                                                    NaN
# steps_to_prevent                                              NaN
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
#
#                                                                       2  \
# sso_id                                                             6581
# inspection_key                                                   567714
# service_number                                                      NaN
# report_date                                                      3/9/19
# spill_address                                                       215
# spill_street_name                                       AUDREY ALENE DR
# total_gallons                                                        79
# gallons_returned                                                      0
# gallons_1                                                            10
# spill_start_1                                       3/9/2019 6:00:00 PM
# spill_stop_1                                        3/9/2019 7:30:00 PM
# hours_1                                                             1.5
# cause                                                        Structural
# comments              Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                    CLEANED MAIN
# watershed                                                      DOS RIOS
# unit_id_1                                                          2822
# unit_id_2                                                          3351
# discharge_to                                                      ALLEY
# discharge_route                                                    None
# council_district                                                      1
# ferguson                                                          190E4
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                         350
# pipe_type                                                            CP
# installation_year                                                  1955
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  215 Audrey Alene Dr
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      1.00
# response_datetime                                             09-Mar-19
# public_notice                                                     False
# time_int                                                             24
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                          03/10/2019 09:36
# spill_stop_2                                           03/10/2019 10:45
# hours_2                                                            1.15
# gallons_2                                                            69
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
#
#                                                                       3
# sso_id                                                             6584
# inspection_key                                                   567713
# service_number                                                      NaN
# report_date                                                      3/9/19
# spill_address                                                      3602
# spill_street_name                                        SE MILITARY DR
# total_gallons                                                        83
# gallons_returned                                                      0
# gallons_1                                                            83
# spill_start_1                                       3/9/2019 3:37:00 PM
# spill_stop_1                                        3/9/2019 5:00:00 PM
# hours_1                                                         1.38333
# cause                                                            Grease
# comments              Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                             NaN
# watershed                                                  SALADO CREEK
# unit_id_1                                                         92804
# unit_id_2                                                         92805
# discharge_to                                                   EASEMENT
# discharge_route                                                    None
# council_district                                                      3
# ferguson                                                          252C3
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                      213.91
# pipe_type                                                           PVC
# installation_year                                                  1983
# downstream_depth                                                    NaN
# upstream_depth                                                      NaN
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  3602 SE MILITARY DR
# sewer_asset_exp                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# previous_spill_24mos                                                NaN
# unit_type                                                       GRAVITY
# asset_type                                                   Sewer Main
# last_cleaned                                                        NaN
# response_time                                                      0.55
# response_datetime                                             09-Mar-19
# public_notice                                                     False
# time_int                                                            120
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0

# %% [markdown]
# ## _Let's make copies of the original dataframe before dropping some columns and rows to cover scenarios where we uncover more information about the variables._

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()

# %% [markdown]
# _Let's work with df1..._
#
# _Let's remove columns that do not add information._

# %%
df1 = remove_columns(df1, columns=['sso_id',
                                   'inspection_key',
                                   'service_number',
                                   'downstream_depth',
                                   'upstream_depth',
                                   'sewer_asset_exp',
                                   'previous_spill_24mos',
                                   'response_time',
                                   'response_datetime',
                                   'time_int'
                                ])
df1.head(4).T
# Out:
#                                                                     0  \
# report_date                                                   3/10/19
# spill_address                                                    3200
# spill_street_name                                    THOUSAND OAKS DR
# total_gallons                                                    2100
# gallons_returned                                                 2100
# gallons_1                                                        2100
# spill_start_1                                    3/10/2019 1:16:00 PM
# spill_stop_1                                     3/10/2019 2:40:00 PM
# hours_1                                                           1.4
# cause                                                          Grease
# comments            Spill ContainedReturned to SystemArea Cleaned ...
# actions                                                  CLEANED MAIN
# watershed                                                SALADO CREEK
# unit_id_1                                                       66918
# unit_id_2                                                       66917
# discharge_to                                                   STREET
# discharge_route                                                  None
# council_district                                                  NaN
# ferguson                                                        172A2
# month                                                               3
# year                                                             2019
# week                                                               11
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                     16.55
# pipe_type                                                         PVC
# installation_year                                                1997
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                              3200 THOUSAND OAKS DR
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     GRAVITY
# asset_type                                                 Sewer Main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hours_2                                                             0
# gallons_2                                                           0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0
#
#                                                               1  \
# report_date                                             3/10/19
# spill_address                                              6804
# spill_street_name                                   S FLORES ST
# total_gallons                                                80
# gallons_returned                                              0
# gallons_1                                                    80
# spill_start_1                              3/10/2019 2:25:00 PM
# spill_stop_1                               3/10/2019 3:45:00 PM
# hours_1                                                 1.33333
# cause                                                    Grease
# comments            Spill ContainedArea Cleaned and Disinfected
# actions                                            CLEANED MAIN
# watershed                                              DOS RIOS
# unit_id_1                                                 24250
# unit_id_2                                                 24193
# discharge_to                                         STORMDRAIN
# discharge_route                                            None
# council_district                                              3
# ferguson                                                  251A3
# month                                                         3
# year                                                       2019
# week                                                         11
# edwards_zone                                                  0
# expr_1029                                                   NaN
# pipe_diameter                                                 8
# pipe_length                                                 157
# pipe_type                                                   PVC
# installation_year                                          1988
# inches_no                                                   NaN
# rainfall_less_3                                             NaN
# spill_address_full                                6804 S FLORES
# num_spills_compkey                                            1
# num_spills_24mos                                              1
# unit_type                                               GRAVITY
# asset_type                                           Sewer Main
# last_cleaned                                                NaN
# public_notice                                             False
# root_cause                                                  NaN
# steps_to_prevent                                            NaN
# spill_start_2                                               NaN
# spill_stop_2                                                NaN
# hours_2                                                       0
# gallons_2                                                     0
# spill_start_3                                               NaN
# spill_stop_3                                                NaN
# hours_3                                                       0
# gallons_3                                                     0
#
#                                                                     2  \
# report_date                                                    3/9/19
# spill_address                                                     215
# spill_street_name                                     AUDREY ALENE DR
# total_gallons                                                      79
# gallons_returned                                                    0
# gallons_1                                                          10
# spill_start_1                                     3/9/2019 6:00:00 PM
# spill_stop_1                                      3/9/2019 7:30:00 PM
# hours_1                                                           1.5
# cause                                                      Structural
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                  CLEANED MAIN
# watershed                                                    DOS RIOS
# unit_id_1                                                        2822
# unit_id_2                                                        3351
# discharge_to                                                    ALLEY
# discharge_route                                                  None
# council_district                                                    1
# ferguson                                                        190E4
# month                                                               3
# year                                                             2019
# week                                                               10
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                       350
# pipe_type                                                          CP
# installation_year                                                1955
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                                215 Audrey Alene Dr
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     GRAVITY
# asset_type                                                 Sewer Main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                        03/10/2019 09:36
# spill_stop_2                                         03/10/2019 10:45
# hours_2                                                          1.15
# gallons_2                                                          69
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0
#
#                                                                     3
# report_date                                                    3/9/19
# spill_address                                                    3602
# spill_street_name                                      SE MILITARY DR
# total_gallons                                                      83
# gallons_returned                                                    0
# gallons_1                                                          83
# spill_start_1                                     3/9/2019 3:37:00 PM
# spill_stop_1                                      3/9/2019 5:00:00 PM
# hours_1                                                       1.38333
# cause                                                          Grease
# comments            Spill ContainedArea Cleaned and DisinfectedFlu...
# actions                                                           NaN
# watershed                                                SALADO CREEK
# unit_id_1                                                       92804
# unit_id_2                                                       92805
# discharge_to                                                 EASEMENT
# discharge_route                                                  None
# council_district                                                    3
# ferguson                                                        252C3
# month                                                               3
# year                                                             2019
# week                                                               10
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                    213.91
# pipe_type                                                         PVC
# installation_year                                                1983
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                                3602 SE MILITARY DR
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     GRAVITY
# asset_type                                                 Sewer Main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hours_2                                                             0
# gallons_2                                                           0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0

# %% [markdown]
# _Let's make the fields lowercase as well..._

# %%
df1 = lowercase_columm(df1, 'spill_street_name',
                 'spill_address_full',
                 'unit_type',
                 'asset_type',
                 'cause',
                 'comments',
                 'actions',
                 'watershed',
                 'discharge_to',
                 'discharge_route',
                 'pipe_type'
                )
df1.head(4).T
# Out:
#                                                                     0  \
# report_date                                                   3/10/19
# spill_address                                                    3200
# spill_street_name                                    thousand oaks dr
# total_gallons                                                    2100
# gallons_returned                                                 2100
# gallons_1                                                        2100
# spill_start_1                                    3/10/2019 1:16:00 PM
# spill_stop_1                                     3/10/2019 2:40:00 PM
# hours_1                                                           1.4
# cause                                                          grease
# comments            spill containedreturned to systemarea cleaned ...
# actions                                                  cleaned main
# watershed                                                salado creek
# unit_id_1                                                       66918
# unit_id_2                                                       66917
# discharge_to                                                   street
# discharge_route                                                  none
# council_district                                                  NaN
# ferguson                                                        172A2
# month                                                               3
# year                                                             2019
# week                                                               11
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                     16.55
# pipe_type                                                         pvc
# installation_year                                                1997
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                              3200 thousand oaks dr
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     gravity
# asset_type                                                 sewer main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hours_2                                                             0
# gallons_2                                                           0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0
#
#                                                               1  \
# report_date                                             3/10/19
# spill_address                                              6804
# spill_street_name                                   s flores st
# total_gallons                                                80
# gallons_returned                                              0
# gallons_1                                                    80
# spill_start_1                              3/10/2019 2:25:00 PM
# spill_stop_1                               3/10/2019 3:45:00 PM
# hours_1                                                 1.33333
# cause                                                    grease
# comments            spill containedarea cleaned and disinfected
# actions                                            cleaned main
# watershed                                              dos rios
# unit_id_1                                                 24250
# unit_id_2                                                 24193
# discharge_to                                         stormdrain
# discharge_route                                            none
# council_district                                              3
# ferguson                                                  251A3
# month                                                         3
# year                                                       2019
# week                                                         11
# edwards_zone                                                  0
# expr_1029                                                   NaN
# pipe_diameter                                                 8
# pipe_length                                                 157
# pipe_type                                                   pvc
# installation_year                                          1988
# inches_no                                                   NaN
# rainfall_less_3                                             NaN
# spill_address_full                                6804 s flores
# num_spills_compkey                                            1
# num_spills_24mos                                              1
# unit_type                                               gravity
# asset_type                                           sewer main
# last_cleaned                                                NaN
# public_notice                                             False
# root_cause                                                  NaN
# steps_to_prevent                                            NaN
# spill_start_2                                               NaN
# spill_stop_2                                                NaN
# hours_2                                                       0
# gallons_2                                                     0
# spill_start_3                                               NaN
# spill_stop_3                                                NaN
# hours_3                                                       0
# gallons_3                                                     0
#
#                                                                     2  \
# report_date                                                    3/9/19
# spill_address                                                     215
# spill_street_name                                     audrey alene dr
# total_gallons                                                      79
# gallons_returned                                                    0
# gallons_1                                                          10
# spill_start_1                                     3/9/2019 6:00:00 PM
# spill_stop_1                                      3/9/2019 7:30:00 PM
# hours_1                                                           1.5
# cause                                                      structural
# comments            spill containedarea cleaned and disinfectedflu...
# actions                                                  cleaned main
# watershed                                                    dos rios
# unit_id_1                                                        2822
# unit_id_2                                                        3351
# discharge_to                                                    alley
# discharge_route                                                  none
# council_district                                                    1
# ferguson                                                        190E4
# month                                                               3
# year                                                             2019
# week                                                               10
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                       350
# pipe_type                                                          cp
# installation_year                                                1955
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                                215 audrey alene dr
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     gravity
# asset_type                                                 sewer main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                        03/10/2019 09:36
# spill_stop_2                                         03/10/2019 10:45
# hours_2                                                          1.15
# gallons_2                                                          69
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0
#
#                                                                     3
# report_date                                                    3/9/19
# spill_address                                                    3602
# spill_street_name                                      se military dr
# total_gallons                                                      83
# gallons_returned                                                    0
# gallons_1                                                          83
# spill_start_1                                     3/9/2019 3:37:00 PM
# spill_stop_1                                      3/9/2019 5:00:00 PM
# hours_1                                                       1.38333
# cause                                                          grease
# comments            spill containedarea cleaned and disinfectedflu...
# actions                                                           NaN
# watershed                                                salado creek
# unit_id_1                                                       92804
# unit_id_2                                                       92805
# discharge_to                                                 easement
# discharge_route                                                  none
# council_district                                                    3
# ferguson                                                        252C3
# month                                                               3
# year                                                             2019
# week                                                               10
# edwards_zone                                                        0
# expr_1029                                                         NaN
# pipe_diameter                                                       8
# pipe_length                                                    213.91
# pipe_type                                                         pvc
# installation_year                                                1983
# inches_no                                                         NaN
# rainfall_less_3                                                   NaN
# spill_address_full                                3602 se military dr
# num_spills_compkey                                                  1
# num_spills_24mos                                                    1
# unit_type                                                     gravity
# asset_type                                                 sewer main
# last_cleaned                                                      NaN
# public_notice                                                   False
# root_cause                                                        NaN
# steps_to_prevent                                                  NaN
# spill_start_2                                                     NaN
# spill_stop_2                                                      NaN
# hours_2                                                             0
# gallons_2                                                           0
# spill_start_3                                                     NaN
# spill_stop_3                                                      NaN
# hours_3                                                             0
# gallons_3                                                           0

# %% [markdown]
# _Creating a new address column with a better format._

# %%
df1[['spill_street_address']] = df1[['spill_address']]
rows = list(df1.index)
for row in rows:
    df1.spill_street_address[row] = str(df1.spill_address[row]) + ' ' + df1.spill_street_name[row]
df1.head(4).T
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                                                       0  \
# report_date                                                     3/10/19
# spill_address                                                      3200
# spill_street_name                                      thousand oaks dr
# total_gallons                                                      2100
# gallons_returned                                                   2100
# gallons_1                                                          2100
# spill_start_1                                      3/10/2019 1:16:00 PM
# spill_stop_1                                       3/10/2019 2:40:00 PM
# hours_1                                                             1.4
# cause                                                            grease
# comments              spill containedreturned to systemarea cleaned ...
# actions                                                    cleaned main
# watershed                                                  salado creek
# unit_id_1                                                         66918
# unit_id_2                                                         66917
# discharge_to                                                     street
# discharge_route                                                    none
# council_district                                                    NaN
# ferguson                                                          172A2
# month                                                                 3
# year                                                               2019
# week                                                                 11
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                       16.55
# pipe_type                                                           pvc
# installation_year                                                  1997
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                3200 thousand oaks dr
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                              3200 thousand oaks dr
#
#                                                                 1  \
# report_date                                               3/10/19
# spill_address                                                6804
# spill_street_name                                     s flores st
# total_gallons                                                  80
# gallons_returned                                                0
# gallons_1                                                      80
# spill_start_1                                3/10/2019 2:25:00 PM
# spill_stop_1                                 3/10/2019 3:45:00 PM
# hours_1                                                   1.33333
# cause                                                      grease
# comments              spill containedarea cleaned and disinfected
# actions                                              cleaned main
# watershed                                                dos rios
# unit_id_1                                                   24250
# unit_id_2                                                   24193
# discharge_to                                           stormdrain
# discharge_route                                              none
# council_district                                                3
# ferguson                                                    251A3
# month                                                           3
# year                                                         2019
# week                                                           11
# edwards_zone                                                    0
# expr_1029                                                     NaN
# pipe_diameter                                                   8
# pipe_length                                                   157
# pipe_type                                                     pvc
# installation_year                                            1988
# inches_no                                                     NaN
# rainfall_less_3                                               NaN
# spill_address_full                                  6804 s flores
# num_spills_compkey                                              1
# num_spills_24mos                                                1
# unit_type                                                 gravity
# asset_type                                             sewer main
# last_cleaned                                                  NaN
# public_notice                                               False
# root_cause                                                    NaN
# steps_to_prevent                                              NaN
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
# spill_street_address                             6804 s flores st
#
#                                                                       2  \
# report_date                                                      3/9/19
# spill_address                                                       215
# spill_street_name                                       audrey alene dr
# total_gallons                                                        79
# gallons_returned                                                      0
# gallons_1                                                            10
# spill_start_1                                       3/9/2019 6:00:00 PM
# spill_stop_1                                        3/9/2019 7:30:00 PM
# hours_1                                                             1.5
# cause                                                        structural
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                    cleaned main
# watershed                                                      dos rios
# unit_id_1                                                          2822
# unit_id_2                                                          3351
# discharge_to                                                      alley
# discharge_route                                                    none
# council_district                                                      1
# ferguson                                                          190E4
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                         350
# pipe_type                                                            cp
# installation_year                                                  1955
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  215 audrey alene dr
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                          03/10/2019 09:36
# spill_stop_2                                           03/10/2019 10:45
# hours_2                                                            1.15
# gallons_2                                                            69
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                215 audrey alene dr
#
#                                                                       3
# report_date                                                      3/9/19
# spill_address                                                      3602
# spill_street_name                                        se military dr
# total_gallons                                                        83
# gallons_returned                                                      0
# gallons_1                                                            83
# spill_start_1                                       3/9/2019 3:37:00 PM
# spill_stop_1                                        3/9/2019 5:00:00 PM
# hours_1                                                         1.38333
# cause                                                            grease
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                             NaN
# watershed                                                  salado creek
# unit_id_1                                                         92804
# unit_id_2                                                         92805
# discharge_to                                                   easement
# discharge_route                                                    none
# council_district                                                      3
# ferguson                                                          252C3
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                      213.91
# pipe_type                                                           pvc
# installation_year                                                  1983
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# spill_address_full                                  3602 se military dr
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                3602 se military dr

# %%
df1 = df1.drop(columns=['spill_address_full', 'spill_address', 'spill_street_name'])
df1.head(4).T
# Out:
#                                                                       0  \
# report_date                                                     3/10/19
# total_gallons                                                      2100
# gallons_returned                                                   2100
# gallons_1                                                          2100
# spill_start_1                                      3/10/2019 1:16:00 PM
# spill_stop_1                                       3/10/2019 2:40:00 PM
# hours_1                                                             1.4
# cause                                                            grease
# comments              spill containedreturned to systemarea cleaned ...
# actions                                                    cleaned main
# watershed                                                  salado creek
# unit_id_1                                                         66918
# unit_id_2                                                         66917
# discharge_to                                                     street
# discharge_route                                                    none
# council_district                                                    NaN
# ferguson                                                          172A2
# month                                                                 3
# year                                                               2019
# week                                                                 11
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                       16.55
# pipe_type                                                           pvc
# installation_year                                                  1997
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                              3200 thousand oaks dr
#
#                                                                 1  \
# report_date                                               3/10/19
# total_gallons                                                  80
# gallons_returned                                                0
# gallons_1                                                      80
# spill_start_1                                3/10/2019 2:25:00 PM
# spill_stop_1                                 3/10/2019 3:45:00 PM
# hours_1                                                   1.33333
# cause                                                      grease
# comments              spill containedarea cleaned and disinfected
# actions                                              cleaned main
# watershed                                                dos rios
# unit_id_1                                                   24250
# unit_id_2                                                   24193
# discharge_to                                           stormdrain
# discharge_route                                              none
# council_district                                                3
# ferguson                                                    251A3
# month                                                           3
# year                                                         2019
# week                                                           11
# edwards_zone                                                    0
# expr_1029                                                     NaN
# pipe_diameter                                                   8
# pipe_length                                                   157
# pipe_type                                                     pvc
# installation_year                                            1988
# inches_no                                                     NaN
# rainfall_less_3                                               NaN
# num_spills_compkey                                              1
# num_spills_24mos                                                1
# unit_type                                                 gravity
# asset_type                                             sewer main
# last_cleaned                                                  NaN
# public_notice                                               False
# root_cause                                                    NaN
# steps_to_prevent                                              NaN
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
# spill_street_address                             6804 s flores st
#
#                                                                       2  \
# report_date                                                      3/9/19
# total_gallons                                                        79
# gallons_returned                                                      0
# gallons_1                                                            10
# spill_start_1                                       3/9/2019 6:00:00 PM
# spill_stop_1                                        3/9/2019 7:30:00 PM
# hours_1                                                             1.5
# cause                                                        structural
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                    cleaned main
# watershed                                                      dos rios
# unit_id_1                                                          2822
# unit_id_2                                                          3351
# discharge_to                                                      alley
# discharge_route                                                    none
# council_district                                                      1
# ferguson                                                          190E4
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                         350
# pipe_type                                                            cp
# installation_year                                                  1955
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                          03/10/2019 09:36
# spill_stop_2                                           03/10/2019 10:45
# hours_2                                                            1.15
# gallons_2                                                            69
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                215 audrey alene dr
#
#                                                                       3
# report_date                                                      3/9/19
# total_gallons                                                        83
# gallons_returned                                                      0
# gallons_1                                                            83
# spill_start_1                                       3/9/2019 3:37:00 PM
# spill_stop_1                                        3/9/2019 5:00:00 PM
# hours_1                                                         1.38333
# cause                                                            grease
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                             NaN
# watershed                                                  salado creek
# unit_id_1                                                         92804
# unit_id_2                                                         92805
# discharge_to                                                   easement
# discharge_route                                                    none
# council_district                                                      3
# ferguson                                                          252C3
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                      213.91
# pipe_type                                                           pvc
# installation_year                                                  1983
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                3602 se military dr

# %% [markdown]
# # EXPLORE

# %% [markdown]
# ### Looking for the repeat offenders...

# %%
df1.num_spills_24mos[df1.num_spills_24mos > 1].value_counts()
# Out:
# 2.0     180
# 3.0      75
# 4.0      32
# 5.0      27
# 6.0      19
# 7.0      12
# 8.0       7
# 9.0       5
# 10.0      1
# 11.0      1
# 12.0      1
# 13.0      1
# Name: num_spills_24mos, dtype: int64

# %% [markdown]
# ### Location of the most frequent SSOs

# %%
df1.spill_street_address[df1.num_spills_24mos >= 7]
# Out:
# 33            6606 swiss oaks
# 40            6606 swiss oaks
# 41            6606 swiss oaks
# 47            6606 swiss oaks
# 73            1800 austin hwy
# 84      108 chappie james way
# 93      108 chappie james way
# 97      108 chappie james way
# 141     108 chappie james way
# 153           6606 swiss oaks
# 158     108 chappie james way
# 166     108 chappie james way
# 171           6606 swiss oaks
# 190           6606 swiss oaks
# 241       1427 harry wurzbach
# 243           6606 swiss oaks
# 303     100 chappie james way
# 384     108 chappie james way
# 591              700 holbrook
# 593      10800 entrance rd ne
# 602              700 holbrook
# 727      10800 entrance rd ne
# 738      10800 entrance rd ne
# 751      10823 entrance rd ne
# 762      10700 entrance rd ne
# 770      10800 entrance rd ne
# 1654           6305 cagnon rd
# 2394           6305 cagnon rd
# Name: spill_street_address, dtype: object

# %% [markdown]
# - [ ] **TODO:** Find a way to flesh out the address using regex to account for typos etc.
# - [ ] **TODO:** Maybe try using unit id's instead of addresses.
# - [ ] **TODO:** Drill down to only the top 3-5 locations.
# - [ ] **TODO:** Compare predictions between preventing SSO on the most frequents versus not preventing.
# - [ ] **TODO:** What is causing the spills on these top 3-5 locations?

# %%
df1.head(4).T
# Out:
#                                                                       0  \
# report_date                                                     3/10/19
# total_gallons                                                      2100
# gallons_returned                                                   2100
# gallons_1                                                          2100
# spill_start_1                                      3/10/2019 1:16:00 PM
# spill_stop_1                                       3/10/2019 2:40:00 PM
# hours_1                                                             1.4
# cause                                                            grease
# comments              spill containedreturned to systemarea cleaned ...
# actions                                                    cleaned main
# watershed                                                  salado creek
# unit_id_1                                                         66918
# unit_id_2                                                         66917
# discharge_to                                                     street
# discharge_route                                                    none
# council_district                                                    NaN
# ferguson                                                          172A2
# month                                                                 3
# year                                                               2019
# week                                                                 11
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                       16.55
# pipe_type                                                           pvc
# installation_year                                                  1997
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                              3200 thousand oaks dr
#
#                                                                 1  \
# report_date                                               3/10/19
# total_gallons                                                  80
# gallons_returned                                                0
# gallons_1                                                      80
# spill_start_1                                3/10/2019 2:25:00 PM
# spill_stop_1                                 3/10/2019 3:45:00 PM
# hours_1                                                   1.33333
# cause                                                      grease
# comments              spill containedarea cleaned and disinfected
# actions                                              cleaned main
# watershed                                                dos rios
# unit_id_1                                                   24250
# unit_id_2                                                   24193
# discharge_to                                           stormdrain
# discharge_route                                              none
# council_district                                                3
# ferguson                                                    251A3
# month                                                           3
# year                                                         2019
# week                                                           11
# edwards_zone                                                    0
# expr_1029                                                     NaN
# pipe_diameter                                                   8
# pipe_length                                                   157
# pipe_type                                                     pvc
# installation_year                                            1988
# inches_no                                                     NaN
# rainfall_less_3                                               NaN
# num_spills_compkey                                              1
# num_spills_24mos                                                1
# unit_type                                                 gravity
# asset_type                                             sewer main
# last_cleaned                                                  NaN
# public_notice                                               False
# root_cause                                                    NaN
# steps_to_prevent                                              NaN
# spill_start_2                                                 NaN
# spill_stop_2                                                  NaN
# hours_2                                                         0
# gallons_2                                                       0
# spill_start_3                                                 NaN
# spill_stop_3                                                  NaN
# hours_3                                                         0
# gallons_3                                                       0
# spill_street_address                             6804 s flores st
#
#                                                                       2  \
# report_date                                                      3/9/19
# total_gallons                                                        79
# gallons_returned                                                      0
# gallons_1                                                            10
# spill_start_1                                       3/9/2019 6:00:00 PM
# spill_stop_1                                        3/9/2019 7:30:00 PM
# hours_1                                                             1.5
# cause                                                        structural
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                    cleaned main
# watershed                                                      dos rios
# unit_id_1                                                          2822
# unit_id_2                                                          3351
# discharge_to                                                      alley
# discharge_route                                                    none
# council_district                                                      1
# ferguson                                                          190E4
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                         350
# pipe_type                                                            cp
# installation_year                                                  1955
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                          03/10/2019 09:36
# spill_stop_2                                           03/10/2019 10:45
# hours_2                                                            1.15
# gallons_2                                                            69
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                215 audrey alene dr
#
#                                                                       3
# report_date                                                      3/9/19
# total_gallons                                                        83
# gallons_returned                                                      0
# gallons_1                                                            83
# spill_start_1                                       3/9/2019 3:37:00 PM
# spill_stop_1                                        3/9/2019 5:00:00 PM
# hours_1                                                         1.38333
# cause                                                            grease
# comments              spill containedarea cleaned and disinfectedflu...
# actions                                                             NaN
# watershed                                                  salado creek
# unit_id_1                                                         92804
# unit_id_2                                                         92805
# discharge_to                                                   easement
# discharge_route                                                    none
# council_district                                                      3
# ferguson                                                          252C3
# month                                                                 3
# year                                                               2019
# week                                                                 10
# edwards_zone                                                          0
# expr_1029                                                           NaN
# pipe_diameter                                                         8
# pipe_length                                                      213.91
# pipe_type                                                           pvc
# installation_year                                                  1983
# inches_no                                                           NaN
# rainfall_less_3                                                     NaN
# num_spills_compkey                                                    1
# num_spills_24mos                                                      1
# unit_type                                                       gravity
# asset_type                                                   sewer main
# last_cleaned                                                        NaN
# public_notice                                                     False
# root_cause                                                          NaN
# steps_to_prevent                                                    NaN
# spill_start_2                                                       NaN
# spill_stop_2                                                        NaN
# hours_2                                                               0
# gallons_2                                                             0
# spill_start_3                                                       NaN
# spill_stop_3                                                        NaN
# hours_3                                                               0
# gallons_3                                                             0
# spill_street_address                                3602 se military dr

# %%
df1[['spill_street_address', 'unit_id_1','unit_id_2', 'unit_type', 'asset_type']].head(15)
# Out:
#      spill_street_address unit_id_1 unit_id_2 unit_type          asset_type
# 0   3200 thousand oaks dr     66918     66917   gravity          sewer main
# 1        6804 s flores st     24250     24193   gravity          sewer main
# 2     215 audrey alene dr      2822      3351   gravity          sewer main
# 3     3602 se military dr     92804     92805   gravity          sewer main
# 4            100 pansy ln     61141     49543   gravity          sewer main
# 5     3200 s hackberry st     38907     26117   gravity          sewer main
# 6       9910 sugarloaf dr     85120     85363   gravity          sewer main
# 7       3507 piedmont ave     26128     24334   gravity          sewer main
# 8              349 alicia     47292     47293   gravity          sewer main
# 9    1502 w mistletoe ave     14241     14896   gravity          sewer main
# 10           5 trophy rdg     58914     61251   gravity          sewer main
# 11        4100 culebra rd     34430     47275   gravity          sewer main
# 12    25903 turquoise sky    353828     73051   gravity          sewer main
# 13       116 golden crown     97780     97779   gravity          sewer main
# 14  3023 thousand oaks dr    334582       NaN   lateral  sewer service line

# %% [markdown]
# - [ ] **TODO:** Maybe we can do some kind of clustering to group problem areas.

# %%
df.unit_id_1.value_counts()[df.unit_id_1.value_counts() > 7]
# Out:
# 52470     15
# LS200     14
# 1187      13
# LS199     12
# 903059    12
# 1210      10
# LS188     10
# 47822     10
# 903060    10
# 62085     10
# LS201      8
# 11989      8
# 29988      8
# 424896     8
# Name: unit_id_1, dtype: int64

# %%
df.unit_id_2.value_counts()[df.unit_id_2.value_counts() > 7]
# Out:
# 52677     13
# 1074      13
# 71380     12
# 903059    10
# 922726     9
# 46546      9
# 62088      9
# 16276      8
# 79942      8
# 424898     8
# 499663     8
# Name: unit_id_2, dtype: int64

# %%
df1.spill_street_address.value_counts()
# Out:
# 6606 swiss oaks          24
# 108 chappie james way    20
# 700 holbrook             16
# 10800 entrance rd ne     14
# 6305 cagnon rd           13
# 23500 ih 10 w            12
# 1427 harry wurzbach      12
# 6785 cagnon rd           12
# 1800 austin hwy          12
# 668 holbrook             10
# 10102 us hwy 90 w         9
# 3847 thousand oaks        8
# 409 cheryl dr e           7
# 10762 pleasanton rd       7
# 1043 kentucky ave         7
# 7930 flores st s          7
# 3714 neer ave             7
# 11400 starcrest dr        6
# 902 holbrook              6
# 6102 rose valley          6
# 1300 elmendorf n          6
# 1114 onslow               6
# 5410 morey rd             6
# 1703 donaldson ave        6
# 2627 culebra rd           6
# 111 yolanda               6
# 8600 mission pkwy         6
# 5802 kim valley dr        6
# 107 yolanda               5
# 1612 martinez losoya      5
#                          ..
# 12500 john barry          1
# 5314 randolph blvd        1
# 3033 goliad rd            1
# 6600 merry oaks dr        1
# 310 commerce st w         1
# 5800 medina base rd       1
# 458 e vestal place        1
# 8330 potranco rd          1
# 5100 john d ryan          1
# 9403 wurzbach rd          1
# 16500 state hwy 16        1
# 400 roslyn ave            1
# 4903 benham               1
# 4215 fondren              1
# 5430 havencrest dr        1
# 13823 parksite woods      1
# 21302 encino commons      1
# 114 hearne                1
# 135 reichert              1
# 119 stella                1
# 7301 pipers blf           1
# 23102 woodlawn rdg        1
# 13136 los espanada        1
# 427 odell st              1
# 1300 ervin                1
# 506 mcilvaine             1
# 6900 brownleaf dr         1
# 500 oblate                1
# 3635 candleglenn          1
# 818 patton                1
# Name: spill_street_address, Length: 2479, dtype: int64
